# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/riiid-test-answer-prediction/example_sample_submission.csv
# /kaggle/input/riiid-test-answer-prediction/example_test.csv
# /kaggle/input/riiid-test-answer-prediction/questions.csv
# /kaggle/input/riiid-test-answer-prediction/train.csv
# /kaggle/input/riiid-test-answer-prediction/lectures.csv
# /kaggle/input/riiid-test-answer-prediction/riiideducation/competition.cpython-37m-x86_64-linux-gnu.so
# /kaggle/input/riiid-test-answer-prediction/riiideducation/__init__.py

# %%
from sklearn.model_selection import train_test_split
import optuna
import lightgbm as lgb
from sklearn.metrics import roc_auc_score

# %%
import riiideducation
env = riiideducation.make_env()
iter_test = env.iter_test()

# %% [markdown]
# # Data

# %%
used_data_types_dict = {
    'timestamp': 'int64',
    'user_id': 'int32',
    'content_id': 'int16',
    'answered_correctly': 'int8',
    'prior_question_elapsed_time': 'float16',
    'prior_question_had_explanation': 'boolean'
}

train_df = pd.read_csv('/kaggle/input/riiid-test-answer-prediction/train.csv',
                       usecols = used_data_types_dict.keys(),
                       dtype=used_data_types_dict,
                       index_col = 0,
                       nrows=70**6)

print(train_df.dtypes)
print(train_df.shape)
train_df.head()
# Out:
# /opt/conda/lib/python3.7/site-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# user_id                             int32
# content_id                          int16
# answered_correctly                   int8
# prior_question_elapsed_time       float16
# prior_question_had_explanation    boolean
# dtype: object
# (101230332, 5)
#            user_id  content_id  answered_correctly  \
# timestamp
# 0              115        5692                   1
# 56943          115        5716                   1
# 118363         115         128                   1
# 131167         115        7860                   1
# 137965         115        7922                   1
#
#            prior_question_elapsed_time  prior_question_had_explanation
# timestamp
# 0                                  NaN                            <NA>
# 56943                          36992.0                           False
# 118363                         55008.0                           False
# 131167                         19008.0                           False
# 137965                         11000.0                           False

# %%
test_df = pd.read_csv("/kaggle/input/riiid-test-answer-prediction/example_test.csv")

print(test_df.shape)
test_df.head()
# Out:
# (104, 11)
#    row_id  group_num    timestamp     user_id  content_id  content_type_id  \
# 0       0          0            0   275030867        5729                0
# 1       1          0  13309898705   554169193       12010                0
# 2       2          0   4213672059  1720860329         457                0
# 3       3          0  62798072960   288641214       13262                0
# 4       4          0  10585422061  1728340777        6119                0
#
#    task_container_id  prior_question_elapsed_time  \
# 0                  0                          NaN
# 1               4427                      19000.0
# 2                240                      17000.0
# 3                266                      23000.0
# 4                162                      72400.0
#
#   prior_question_had_explanation prior_group_answers_correct  \
# 0                            NaN                          []
# 1                           True                         NaN
# 2                           True                         NaN
# 3                           True                         NaN
# 4                           True                         NaN
#
#   prior_group_responses
# 0                    []
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
submission_df = pd.read_csv("/kaggle/input/riiid-test-answer-prediction/example_sample_submission.csv")

print(submission_df.shape)
submission_df.head()
# Out:
# (104, 3)
#    row_id  answered_correctly  group_num
# 0       0                 0.5          0
# 1       1                 0.5          0
# 2       2                 0.5          0
# 3       3                 0.5          0
# 4       4                 0.5          0

# %% [markdown]
# # Feature Engineering

# %%
features_df = train_df.iloc[:int(9/10 * len(train_df))]
train_df = train_df.iloc[int(9/10 * len(train_df)):]

# %%
print(features_df.dtypes)
print(features_df.shape)
features_df.head()
# Out:
# user_id                             int32
# content_id                          int16
# answered_correctly                   int8
# prior_question_elapsed_time       float16
# prior_question_had_explanation    boolean
# dtype: object
# (91107298, 5)
#            user_id  content_id  answered_correctly  \
# timestamp
# 0              115        5692                   1
# 56943          115        5716                   1
# 118363         115         128                   1
# 131167         115        7860                   1
# 137965         115        7922                   1
#
#            prior_question_elapsed_time  prior_question_had_explanation
# timestamp
# 0                                  NaN                            <NA>
# 56943                          36992.0                           False
# 118363                         55008.0                           False
# 131167                         19008.0                           False
# 137965                         11000.0                           False

# %%
print(train_df.dtypes)
print(train_df.shape)
train_df.head()
# Out:
# user_id                             int32
# content_id                          int16
# answered_correctly                   int8
# prior_question_elapsed_time       float16
# prior_question_had_explanation    boolean
# dtype: object
# (10123034, 5)
#                user_id  content_id  answered_correctly  \
# timestamp
# 8231964660  1933715875       11259                   0
# 8232002976  1933715875        4957                   1
# 8232096407  1933715875        5113                   1
# 8232119872  1933715875        4699                   1
# 8232142930  1933715875       11430                   1
#
#             prior_question_elapsed_time  prior_question_had_explanation
# timestamp
# 8231964660                      13000.0                            True
# 8232002976                      44000.0                            True
# 8232096407                      22000.0                            True
# 8232119872                          inf                            True
# 8232142930                       9000.0                            True

# %%
train_questions_only_df = features_df[features_df['answered_correctly']!=-1]

grouped_by_user_df = train_questions_only_df.groupby('user_id')

user_answers_df = grouped_by_user_df.agg({'answered_correctly': ['mean', 'count','std','median','skew']}).copy()

user_answers_df.columns = ['mean_user_accuracy', 
                           'questions_answered', 
                           'std_user_accuracy', 
                           'median_user_accuracy', 
                           'skew_user_accuracy']

print(user_answers_df.dtypes)
print(user_answers_df.shape)
user_answers_df.head()
# Out:
# mean_user_accuracy      float64
# questions_answered        int64
# std_user_accuracy       float64
# median_user_accuracy    float64
# skew_user_accuracy      float64
# dtype: object
# (354308, 5)
#          mean_user_accuracy  questions_answered  std_user_accuracy  \
# user_id
# 115                0.695652                  46           0.465215
# 124                0.233333                  30           0.430183
# 2746               0.578947                  19           0.507257
# 5382               0.672000                 125           0.471374
# 8623               0.642202                 109           0.481566
#
#          median_user_accuracy  skew_user_accuracy
# user_id
# 115                       1.0           -0.879359
# 124                       0.0            1.328338
# 2746                      1.0           -0.347892
# 5382                      1.0           -0.741648
# 8623                      1.0           -0.601619

# %%
grouped_by_content_df = train_questions_only_df.groupby('content_id')

content_answers_df = grouped_by_content_df.agg({'answered_correctly': ['mean', 'count','std','median','skew']}).copy()

content_answers_df.columns = ['mean_accuracy', 
                              'question_asked', 
                              'std_accuracy', 
                              'median_accuracy', 
                              'skew_accuracy']

print(content_answers_df.dtypes)
print(content_answers_df.shape)
content_answers_df.head()
# Out:
# mean_accuracy      float64
# question_asked       int64
# std_accuracy       float64
# median_accuracy    float64
# skew_accuracy      float64
# dtype: object
# (13519, 5)
#             mean_accuracy  question_asked  std_accuracy  median_accuracy  \
# content_id
# 0                0.908595            6236      0.288207              1.0
# 1                0.891682            6684      0.310805              1.0
# 2                0.554656           40499      0.497010              1.0
# 3                0.779348           20734      0.414696              1.0
# 4                0.613226           28549      0.487020              1.0
#
#             skew_accuracy
# content_id
# 0               -2.836339
# 1               -2.521185
# 2               -0.219949
# 3               -1.347371
# 4               -0.465009

# %%
del features_df
del grouped_by_user_df
del grouped_by_content_df

# %%
features = [
    'mean_user_accuracy', 
    'questions_answered',
    'std_user_accuracy', 
    'median_user_accuracy',
    'skew_user_accuracy',
    'mean_accuracy', 
    'question_asked',
    'std_accuracy', 
    'median_accuracy',
    'prior_question_elapsed_time', 
    'prior_question_had_explanation',
    'skew_accuracy'
]

target = 'answered_correctly'

# %%
train_df = train_df[train_df[target] != -1]

print(train_df.dtypes)
print(train_df.shape)
train_df.head()
# Out:
# user_id                             int32
# content_id                          int16
# answered_correctly                   int8
# prior_question_elapsed_time       float16
# prior_question_had_explanation    boolean
# dtype: object
# (9926951, 5)
#                user_id  content_id  answered_correctly  \
# timestamp
# 8231964660  1933715875       11259                   0
# 8232002976  1933715875        4957                   1
# 8232096407  1933715875        5113                   1
# 8232119872  1933715875        4699                   1
# 8232142930  1933715875       11430                   1
#
#             prior_question_elapsed_time  prior_question_had_explanation
# timestamp
# 8231964660                      13000.0                            True
# 8232002976                      44000.0                            True
# 8232096407                      22000.0                            True
# 8232119872                          inf                            True
# 8232142930                       9000.0                            True

# %%
train_df = train_df.merge(user_answers_df, how='left', on='user_id')
train_df = train_df.merge(content_answers_df, how='left', on='content_id')

print(train_df.dtypes)
print(train_df.shape)
train_df.head()
# Out:
# user_id                             int32
# content_id                          int16
# answered_correctly                   int8
# prior_question_elapsed_time       float16
# prior_question_had_explanation    boolean
# mean_user_accuracy                float64
# questions_answered                float64
# std_user_accuracy                 float64
# median_user_accuracy              float64
# skew_user_accuracy                float64
# mean_accuracy                     float64
# question_asked                    float64
# std_accuracy                      float64
# median_accuracy                   float64
# skew_accuracy                     float64
# dtype: object
# (9926951, 15)
#       user_id  content_id  answered_correctly  prior_question_elapsed_time  \
# 0  1933715875       11259                   0                      13000.0
# 1  1933715875        4957                   1                      44000.0
# 2  1933715875        5113                   1                      22000.0
# 3  1933715875        4699                   1                          inf
# 4  1933715875       11430                   1                       9000.0
#
#    prior_question_had_explanation  mean_user_accuracy  questions_answered  \
# 0                            True            0.779843              5219.0
# 1                            True            0.779843              5219.0
# 2                            True            0.779843              5219.0
# 3                            True            0.779843              5219.0
# 4                            True            0.779843              5219.0
#
#    std_user_accuracy  median_user_accuracy  skew_user_accuracy  mean_accuracy  \
# 0           0.414392                   1.0           -1.351136       0.532146
# 1           0.414392                   1.0           -1.351136       0.584772
# 2           0.414392                   1.0           -1.351136       0.603571
# 3           0.414392                   1.0           -1.351136       0.694888
# 4           0.414392                   1.0           -1.351136       0.765869
#
#    question_asked  std_accuracy  median_accuracy  skew_accuracy
# 0          1291.0      0.499159              1.0      -0.128999
# 1          2548.0      0.492858              1.0      -0.344273
# 2          1960.0      0.489280              1.0      -0.423795
# 3          2504.0      0.460547              1.0      -0.847011
# 4          1922.0      0.423565              1.0      -1.256695

# %% [markdown]
# # Preprocess

# %%
train_df['prior_question_had_explanation'] = train_df['prior_question_had_explanation'].fillna(value=False).astype(bool)
train_df = train_df.fillna(value=0.5)

print(train_df.isnull().sum())
# Out:
# user_id                           0
# content_id                        0
# answered_correctly                0
# prior_question_elapsed_time       0
# prior_question_had_explanation    0
# mean_user_accuracy                0
# questions_answered                0
# std_user_accuracy                 0
# median_user_accuracy              0
# skew_user_accuracy                0
# mean_accuracy                     0
# question_asked                    0
# std_accuracy                      0
# median_accuracy                   0
# skew_accuracy                     0
# dtype: int64

# %%
train_df = train_df[features + [target]]
train_df = train_df.replace([np.inf, -np.inf], np.nan)
train_df = train_df.fillna(0.5)

print(train_df.isnull().sum())
# Out:
# mean_user_accuracy                0
# questions_answered                0
# std_user_accuracy                 0
# median_user_accuracy              0
# skew_user_accuracy                0
# mean_accuracy                     0
# question_asked                    0
# std_accuracy                      0
# median_accuracy                   0
# prior_question_elapsed_time       0
# prior_question_had_explanation    0
# skew_accuracy                     0
# answered_correctly                0
# dtype: int64

# %%
print(train_df.dtypes)
print(train_df.shape)
train_df.head()
# Out:
# mean_user_accuracy                float64
# questions_answered                float64
# std_user_accuracy                 float64
# median_user_accuracy              float64
# skew_user_accuracy                float64
# mean_accuracy                     float64
# question_asked                    float64
# std_accuracy                      float64
# median_accuracy                   float64
# prior_question_elapsed_time       float16
# prior_question_had_explanation       bool
# skew_accuracy                     float64
# answered_correctly                   int8
# dtype: object
# (9926951, 13)
#    mean_user_accuracy  questions_answered  std_user_accuracy  \
# 0            0.779843              5219.0           0.414392
# 1            0.779843              5219.0           0.414392
# 2            0.779843              5219.0           0.414392
# 3            0.779843              5219.0           0.414392
# 4            0.779843              5219.0           0.414392
#
#    median_user_accuracy  skew_user_accuracy  mean_accuracy  question_asked  \
# 0                   1.0           -1.351136       0.532146          1291.0
# 1                   1.0           -1.351136       0.584772          2548.0
# 2                   1.0           -1.351136       0.603571          1960.0
# 3                   1.0           -1.351136       0.694888          2504.0
# 4                   1.0           -1.351136       0.765869          1922.0
#
#    std_accuracy  median_accuracy  prior_question_elapsed_time  \
# 0      0.499159              1.0                      13000.0
# 1      0.492858              1.0                      44000.0
# 2      0.489280              1.0                      22000.0
# 3      0.460547              1.0                          0.5
# 4      0.423565              1.0                       9000.0
#
#    prior_question_had_explanation  skew_accuracy  answered_correctly
# 0                            True      -0.128999                   0
# 1                            True      -0.344273                   1
# 2                            True      -0.423795                   1
# 3                            True      -0.847011                   1
# 4                            True      -1.256695                   1

# %%
train_df, test_df = train_test_split(train_df, random_state=666, test_size=0.2)

print(train_df.shape)
print(test_df.shape)
train_df.head()
# Out:
# (7941560, 13)
# (1985391, 13)
#          mean_user_accuracy  questions_answered  std_user_accuracy  \
# 7195423                 0.5                 0.5                0.5
# 507380                  0.5                 0.5                0.5
# 3855082                 0.5                 0.5                0.5
# 742455                  0.5                 0.5                0.5
# 7013908                 0.5                 0.5                0.5
#
#          median_user_accuracy  skew_user_accuracy  mean_accuracy  \
# 7195423                   0.5                 0.5       0.751375
# 507380                    0.5                 0.5       0.362581
# 3855082                   0.5                 0.5       0.492388
# 742455                    0.5                 0.5       0.691253
# 7013908                   0.5                 0.5       0.661801
#
#          question_asked  std_accuracy  median_accuracy  \
# 7195423         28179.0      0.432224              1.0
# 507380           5687.0      0.480788              0.0
# 3855082         58326.0      0.499946              0.0
# 742455           9626.0      0.462001              1.0
# 7013908         14728.0      0.473113              1.0
#
#          prior_question_elapsed_time  prior_question_had_explanation  \
# 7195423                      19008.0                            True
# 507380                       25744.0                            True
# 3855082                      46016.0                            True
# 742455                       44000.0                            True
# 7013908                      26000.0                            True
#
#          skew_accuracy  answered_correctly
# 7195423      -1.163255                   0
# 507380        0.571841                   0
# 3855082       0.030454                   0
# 742455       -0.828105                   0
# 7013908      -0.684076                   1

# %%
def create_model(trial):
    num_leaves = trial.suggest_int("num_leaves", 2, 31)
    n_estimators = trial.suggest_int("n_estimators", 50, 300)
    max_depth = trial.suggest_int('max_depth', 3, 8)
    min_child_samples = trial.suggest_int('min_child_samples', 100, 1200)
    learning_rate = trial.suggest_uniform('learning_rate', 0.0001, 0.99)
    min_data_in_leaf = trial.suggest_int('min_data_in_leaf', 5, 90)
    bagging_fraction = trial.suggest_uniform('bagging_fraction', 0.0001, 1.0)
    feature_fraction = trial.suggest_uniform('feature_fraction', 0.0001, 1.0)
    
    model = lgb.LGBMClassifier(
        num_leaves=num_leaves,
        n_estimators=n_estimators, 
        max_depth=max_depth, 
        min_child_samples=min_child_samples, 
        min_data_in_leaf=min_data_in_leaf,
        learning_rate=learning_rate,
        feature_fraction=feature_fraction,
        random_state=666
    )
    return model

# %% [markdown]
# # Modeling

# %%
def objective(trial):
    model = create_model(trial)
    model.fit(train_df[features], train_df[target])
    score = roc_auc_score(
        test_df[target].values, 
        model.predict_proba(test_df[features])[:,1]
    )
    return score

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=70)
params = study.best_params

print(params)
# Out:
# [I 2020-12-08 23:03:33,254] A new study created in memory with name: no-name-b1b1facc-6815-44d1-a7d8-b771ead65e12
# [I 2020-12-08 23:04:28,672] Trial 0 finished with value: 0.7198165891469471 and parameters: {'num_leaves': 2, 'n_estimators': 136, 'max_depth': 4, 'min_child_samples': 336, 'learning_rate': 0.7891960380158618, 'min_data_in_leaf': 7, 'bagging_fraction': 0.6061515990034877, 'feature_fraction': 0.700437785011895}. Best is trial 0 with value: 0.7198165891469471.
# [I 2020-12-08 23:05:33,992] Trial 1 finished with value: 0.7212493862979616 and parameters: {'num_leaves': 7, 'n_estimators': 162, 'max_depth': 3, 'min_child_samples': 963, 'learning_rate': 0.7843658599232078, 'min_data_in_leaf': 49, 'bagging_fraction': 0.5269505656716831, 'feature_fraction': 0.2230621733725758}. Best is trial 1 with value: 0.7212493862979616.
# [I 2020-12-08 23:07:23,992] Trial 2 finished with value: 0.720813860892448 and parameters: {'num_leaves': 23, 'n_estimators': 298, 'max_depth': 7, 'min_child_samples': 156, 'learning_rate': 0.41662243951302796, 'min_data_in_leaf': 74, 'bagging_fraction': 0.5520584633488312, 'feature_fraction': 0.14109397411760996}. Best is trial 1 with value: 0.7212493862979616.
# [I 2020-12-08 23:08:24,929] Trial 3 finished with value: 0.7189853143096713 and parameters: {'num_leaves': 11, 'n_estimators': 65, 'max_depth': 5, 'min_child_samples': 963, 'learning_rate': 0.022576242663453313, 'min_data_in_leaf': 13, 'bagging_fraction': 0.6889645969007886, 'feature_fraction': 0.8684001450598888}. Best is trial 1 with value: 0.7212493862979616.
# [I 2020-12-08 23:09:20,708] Trial 4 finished with value: 0.7215248509147472 and parameters: {'num_leaves': 25, 'n_estimators': 84, 'max_depth': 6, 'min_child_samples': 905, 'learning_rate': 0.7943055034477109, 'min_data_in_leaf': 41, 'bagging_fraction': 0.2947856807926126, 'feature_fraction': 0.6219399520048317}. Best is trial 4 with value: 0.7215248509147472.
# [I 2020-12-08 23:10:33,859] Trial 5 finished with value: 0.7207434094606757 and parameters: {'num_leaves': 23, 'n_estimators': 190, 'max_depth': 4, 'min_child_samples': 1045, 'learning_rate': 0.8905214243692616, 'min_data_in_leaf': 45, 'bagging_fraction': 0.9639874483439932, 'feature_fraction': 0.20777476439018328}. Best is trial 4 with value: 0.7215248509147472.
# [I 2020-12-08 23:11:20,474] Trial 6 finished with value: 0.7204699731456206 and parameters: {'num_leaves': 3, 'n_estimators': 86, 'max_depth': 8, 'min_child_samples': 154, 'learning_rate': 0.2697581963987689, 'min_data_in_leaf': 60, 'bagging_fraction': 0.7132667958202578, 'feature_fraction': 0.561398286147178}. Best is trial 4 with value: 0.7215248509147472.
# [I 2020-12-08 23:12:24,290] Trial 7 finished with value: 0.7216266825750886 and parameters: {'num_leaves': 22, 'n_estimators': 113, 'max_depth': 8, 'min_child_samples': 257, 'learning_rate': 0.5704305968328419, 'min_data_in_leaf': 35, 'bagging_fraction': 0.02990201231940278, 'feature_fraction': 0.8962516319006664}. Best is trial 7 with value: 0.7216266825750886.
# [I 2020-12-08 23:13:30,897] Trial 8 finished with value: 0.7209713293837507 and parameters: {'num_leaves': 3, 'n_estimators': 148, 'max_depth': 6, 'min_child_samples': 838, 'learning_rate': 0.3566299488780569, 'min_data_in_leaf': 55, 'bagging_fraction': 0.5234384559827954, 'feature_fraction': 0.894987946751288}. Best is trial 7 with value: 0.7216266825750886.
# [I 2020-12-08 23:14:55,833] Trial 9 finished with value: 0.7207907859672448 and parameters: {'num_leaves': 17, 'n_estimators': 221, 'max_depth': 6, 'min_child_samples': 993, 'learning_rate': 0.4556122249887219, 'min_data_in_leaf': 70, 'bagging_fraction': 0.058832436857073026, 'feature_fraction': 0.19220611797919876}. Best is trial 7 with value: 0.7216266825750886.
# [I 2020-12-08 23:16:44,241] Trial 10 finished with value: 0.7214244973850197 and parameters: {'num_leaves': 30, 'n_estimators': 257, 'max_depth': 8, 'min_child_samples': 511, 'learning_rate': 0.6095173386340847, 'min_data_in_leaf': 27, 'bagging_fraction': 0.02668301275570828, 'feature_fraction': 0.9484483463723132}. Best is trial 7 with value: 0.7216266825750886.
# [I 2020-12-08 23:17:43,408] Trial 11 finished with value: 0.7216084922911392 and parameters: {'num_leaves': 30, 'n_estimators': 101, 'max_depth': 7, 'min_child_samples': 646, 'learning_rate': 0.6295054361706046, 'min_data_in_leaf': 31, 'bagging_fraction': 0.2633587074807934, 'feature_fraction': 0.6805000793749173}. Best is trial 7 with value: 0.7216266825750886.
# [I 2020-12-08 23:18:54,151] Trial 12 finished with value: 0.7216791317959321 and parameters: {'num_leaves': 31, 'n_estimators': 113, 'max_depth': 8, 'min_child_samples': 659, 'learning_rate': 0.6214812361448545, 'min_data_in_leaf': 27, 'bagging_fraction': 0.24270799635070797, 'feature_fraction': 0.4072288718735131}. Best is trial 12 with value: 0.7216791317959321.
# [I 2020-12-08 23:20:02,178] Trial 13 finished with value: 0.7217018031397373 and parameters: {'num_leaves': 17, 'n_estimators': 112, 'max_depth': 8, 'min_child_samples': 435, 'learning_rate': 0.6125583245154049, 'min_data_in_leaf': 24, 'bagging_fraction': 0.20315987957691511, 'feature_fraction': 0.3931198777162557}. Best is trial 13 with value: 0.7217018031397373.
# [I 2020-12-08 23:21:12,564] Trial 14 finished with value: 0.7214641558270583 and parameters: {'num_leaves': 13, 'n_estimators': 130, 'max_depth': 7, 'min_child_samples': 510, 'learning_rate': 0.13212023273720935, 'min_data_in_leaf': 18, 'bagging_fraction': 0.2894379777451508, 'feature_fraction': 0.3793454634078825}. Best is trial 13 with value: 0.7217018031397373.
# [I 2020-12-08 23:21:56,189] Trial 15 finished with value: 0.7216186655404527 and parameters: {'num_leaves': 17, 'n_estimators': 51, 'max_depth': 8, 'min_child_samples': 761, 'learning_rate': 0.7027792644620493, 'min_data_in_leaf': 89, 'bagging_fraction': 0.16629742974830278, 'feature_fraction': 0.4325591006360689}. Best is trial 13 with value: 0.7217018031397373.
# [I 2020-12-08 23:23:17,214] Trial 16 finished with value: 0.7213748648073349 and parameters: {'num_leaves': 31, 'n_estimators': 178, 'max_depth': 7, 'min_child_samples': 456, 'learning_rate': 0.9866653889172325, 'min_data_in_leaf': 20, 'bagging_fraction': 0.34732896772315536, 'feature_fraction': 0.3423858340343983}. Best is trial 13 with value: 0.7217018031397373.
# [I 2020-12-08 23:24:43,506] Trial 17 finished with value: 0.7216708903216024 and parameters: {'num_leaves': 26, 'n_estimators': 204, 'max_depth': 8, 'min_child_samples': 668, 'learning_rate': 0.5116589173280586, 'min_data_in_leaf': 6, 'bagging_fraction': 0.15068824201422126, 'feature_fraction': 0.5066519134105874}. Best is trial 13 with value: 0.7217018031397373.
# [I 2020-12-08 23:25:45,647] Trial 18 finished with value: 0.7207071283902523 and parameters: {'num_leaves': 20, 'n_estimators': 118, 'max_depth': 7, 'min_child_samples': 408, 'learning_rate': 0.3128235521015544, 'min_data_in_leaf': 25, 'bagging_fraction': 0.443952084873712, 'feature_fraction': 0.009751577161448699}. Best is trial 13 with value: 0.7217018031397373.
# [I 2020-12-08 23:26:30,281] Trial 19 finished with value: 0.7212094412368475 and parameters: {'num_leaves': 11, 'n_estimators': 66, 'max_depth': 5, 'min_child_samples': 591, 'learning_rate': 0.978880130953538, 'min_data_in_leaf': 37, 'bagging_fraction': 0.21915927152707304, 'feature_fraction': 0.31527538695961754}. Best is trial 13 with value: 0.7217018031397373.
# [I 2020-12-08 23:27:31,733] Trial 20 finished with value: 0.7206832492583525 and parameters: {'num_leaves': 7, 'n_estimators': 155, 'max_depth': 8, 'min_child_samples': 771, 'learning_rate': 0.729765362661276, 'min_data_in_leaf': 13, 'bagging_fraction': 0.4013988107869617, 'feature_fraction': 0.0003730252200717654}. Best is trial 13 with value: 0.7217018031397373.
# [I 2020-12-08 23:29:07,845] Trial 21 finished with value: 0.7216555436728098 and parameters: {'num_leaves': 27, 'n_estimators': 209, 'max_depth': 8, 'min_child_samples': 715, 'learning_rate': 0.5399992199520698, 'min_data_in_leaf': 8, 'bagging_fraction': 0.1459147908929242, 'feature_fraction': 0.4879404256966107}. Best is trial 13 with value: 0.7217018031397373.
# [I 2020-12-08 23:30:48,751] Trial 22 finished with value: 0.7217331926765906 and parameters: {'num_leaves': 27, 'n_estimators': 240, 'max_depth': 8, 'min_child_samples': 597, 'learning_rate': 0.4985431430987924, 'min_data_in_leaf': 23, 'bagging_fraction': 0.13357268273969783, 'feature_fraction': 0.5201273212663945}. Best is trial 22 with value: 0.7217331926765906.
# [I 2020-12-08 23:32:34,359] Trial 23 finished with value: 0.7215628486866957 and parameters: {'num_leaves': 29, 'n_estimators': 265, 'max_depth': 7, 'min_child_samples': 595, 'learning_rate': 0.6628822861684739, 'min_data_in_leaf': 24, 'bagging_fraction': 0.12444177854164884, 'feature_fraction': 0.29122769957176653}. Best is trial 22 with value: 0.7217331926765906.
# [I 2020-12-08 23:34:13,422] Trial 24 finished with value: 0.7217499616850633 and parameters: {'num_leaves': 20, 'n_estimators': 238, 'max_depth': 8, 'min_child_samples': 1174, 'learning_rate': 0.41854863950873367, 'min_data_in_leaf': 30, 'bagging_fraction': 0.3710046690736068, 'feature_fraction': 0.437371559974432}. Best is trial 24 with value: 0.7217499616850633.
# [I 2020-12-08 23:35:58,754] Trial 25 finished with value: 0.7217910145512405 and parameters: {'num_leaves': 19, 'n_estimators': 239, 'max_depth': 7, 'min_child_samples': 1129, 'learning_rate': 0.259573429915929, 'min_data_in_leaf': 34, 'bagging_fraction': 0.3842779373753935, 'feature_fraction': 0.7440340628923328}. Best is trial 25 with value: 0.7217910145512405.
# [I 2020-12-08 23:37:45,645] Trial 26 finished with value: 0.7217769196584556 and parameters: {'num_leaves': 19, 'n_estimators': 242, 'max_depth': 7, 'min_child_samples': 1199, 'learning_rate': 0.21785793524104263, 'min_data_in_leaf': 34, 'bagging_fraction': 0.4057593480476883, 'feature_fraction': 0.7914315714599713}. Best is trial 25 with value: 0.7217910145512405.
# [I 2020-12-08 23:40:00,254] Trial 27 finished with value: 0.7217970454409275 and parameters: {'num_leaves': 20, 'n_estimators': 299, 'max_depth': 6, 'min_child_samples': 1188, 'learning_rate': 0.20502766766993205, 'min_data_in_leaf': 35, 'bagging_fraction': 0.4286217356645164, 'feature_fraction': 0.7940865318485886}. Best is trial 27 with value: 0.7217970454409275.
# [I 2020-12-08 23:42:04,722] Trial 28 finished with value: 0.7217682207290088 and parameters: {'num_leaves': 14, 'n_estimators': 300, 'max_depth': 6, 'min_child_samples': 1197, 'learning_rate': 0.179569813681647, 'min_data_in_leaf': 50, 'bagging_fraction': 0.6123630381154559, 'feature_fraction': 0.7674754648046468}. Best is trial 27 with value: 0.7217970454409275.
# [I 2020-12-08 23:44:54,724] Trial 29 finished with value: 0.7211533661755489 and parameters: {'num_leaves': 20, 'n_estimators': 281, 'max_depth': 5, 'min_child_samples': 1104, 'learning_rate': 0.014838118450067744, 'min_data_in_leaf': 40, 'bagging_fraction': 0.46125174423294685, 'feature_fraction': 0.7822243738138477}. Best is trial 27 with value: 0.7217970454409275.
# [I 2020-12-08 23:46:54,333] Trial 30 finished with value: 0.7217508122531352 and parameters: {'num_leaves': 15, 'n_estimators': 282, 'max_depth': 6, 'min_child_samples': 1127, 'learning_rate': 0.16569071871045124, 'min_data_in_leaf': 35, 'bagging_fraction': 0.8462093855614581, 'feature_fraction': 0.7842240559325757}. Best is trial 27 with value: 0.7217970454409275.
# [I 2020-12-08 23:48:59,238] Trial 31 finished with value: 0.7217788559266666 and parameters: {'num_leaves': 14, 'n_estimators': 285, 'max_depth': 6, 'min_child_samples': 1189, 'learning_rate': 0.16984408787303132, 'min_data_in_leaf': 50, 'bagging_fraction': 0.6252852473694455, 'feature_fraction': 0.7697899980872698}. Best is trial 27 with value: 0.7217970454409275.
# [I 2020-12-08 23:51:07,159] Trial 32 finished with value: 0.7216931760664836 and parameters: {'num_leaves': 19, 'n_estimators': 270, 'max_depth': 6, 'min_child_samples': 1127, 'learning_rate': 0.0924772446203542, 'min_data_in_leaf': 45, 'bagging_fraction': 0.6183478439773327, 'feature_fraction': 0.721261486724305}. Best is trial 27 with value: 0.7217970454409275.
# [I 2020-12-08 23:52:52,137] Trial 33 finished with value: 0.7217335654783117 and parameters: {'num_leaves': 12, 'n_estimators': 245, 'max_depth': 7, 'min_child_samples': 1198, 'learning_rate': 0.24876356792605378, 'min_data_in_leaf': 56, 'bagging_fraction': 0.4507595029811185, 'feature_fraction': 0.9965178188159086}. Best is trial 27 with value: 0.7217970454409275.
# [I 2020-12-08 23:54:47,544] Trial 34 finished with value: 0.7216655900168604 and parameters: {'num_leaves': 8, 'n_estimators': 293, 'max_depth': 5, 'min_child_samples': 1092, 'learning_rate': 0.21956577991411583, 'min_data_in_leaf': 63, 'bagging_fraction': 0.7071814382636556, 'feature_fraction': 0.8385826961744411}. Best is trial 27 with value: 0.7217970454409275.
# [I 2020-12-08 23:56:36,426] Trial 35 finished with value: 0.7215143047191143 and parameters: {'num_leaves': 15, 'n_estimators': 227, 'max_depth': 7, 'min_child_samples': 1044, 'learning_rate': 0.058987027769591194, 'min_data_in_leaf': 49, 'bagging_fraction': 0.5649175826701615, 'feature_fraction': 0.6565636563672356}. Best is trial 27 with value: 0.7217970454409275.
# [I 2020-12-08 23:58:23,992] Trial 36 finished with value: 0.7217316695748797 and parameters: {'num_leaves': 22, 'n_estimators': 255, 'max_depth': 4, 'min_child_samples': 918, 'learning_rate': 0.3460338347967018, 'min_data_in_leaf': 40, 'bagging_fraction': 0.5066056340119885, 'feature_fraction': 0.6234416579132693}. Best is trial 27 with value: 0.7217970454409275.
# [I 2020-12-09 00:00:38,422] Trial 37 finished with value: 0.7217145467644099 and parameters: {'num_leaves': 18, 'n_estimators': 285, 'max_depth': 6, 'min_child_samples': 1027, 'learning_rate': 0.1121098778482475, 'min_data_in_leaf': 32, 'bagging_fraction': 0.7805882820981838, 'feature_fraction': 0.8362918525364793}. Best is trial 27 with value: 0.7217970454409275.
# [I 2020-12-09 00:02:42,289] Trial 38 finished with value: 0.721807105943202 and parameters: {'num_leaves': 24, 'n_estimators': 273, 'max_depth': 5, 'min_child_samples': 1192, 'learning_rate': 0.28993411641370764, 'min_data_in_leaf': 44, 'bagging_fraction': 0.3313164981456472, 'feature_fraction': 0.7288991446089245}. Best is trial 38 with value: 0.721807105943202.
# [I 2020-12-09 00:04:42,904] Trial 39 finished with value: 0.7216030403284361 and parameters: {'num_leaves': 24, 'n_estimators': 299, 'max_depth': 3, 'min_child_samples': 919, 'learning_rate': 0.2857678079832063, 'min_data_in_leaf': 52, 'bagging_fraction': 0.3522227868710104, 'feature_fraction': 0.7289499018396406}. Best is trial 38 with value: 0.721807105943202.
# [I 2020-12-09 00:06:47,806] Trial 40 finished with value: 0.7217497889540568 and parameters: {'num_leaves': 22, 'n_estimators': 271, 'max_depth': 4, 'min_child_samples': 1146, 'learning_rate': 0.37043926992573395, 'min_data_in_leaf': 44, 'bagging_fraction': 0.572428070215094, 'feature_fraction': 0.9317922363254074}. Best is trial 38 with value: 0.721807105943202.
# [I 2020-12-09 00:08:37,145] Trial 41 finished with value: 0.7217768896782871 and parameters: {'num_leaves': 21, 'n_estimators': 253, 'max_depth': 5, 'min_child_samples': 1185, 'learning_rate': 0.2321482408532546, 'min_data_in_leaf': 42, 'bagging_fraction': 0.410921618947261, 'feature_fraction': 0.6005874912304375}. Best is trial 38 with value: 0.721807105943202.
# [I 2020-12-09 00:10:28,089] Trial 42 finished with value: 0.721768296587809 and parameters: {'num_leaves': 19, 'n_estimators': 225, 'max_depth': 6, 'min_child_samples': 1082, 'learning_rate': 0.18968356556707025, 'min_data_in_leaf': 36, 'bagging_fraction': 0.3331584764295242, 'feature_fraction': 0.836990990952112}. Best is trial 38 with value: 0.721807105943202.
# [I 2020-12-09 00:12:33,574] Trial 43 finished with value: 0.7217806911023236 and parameters: {'num_leaves': 24, 'n_estimators': 276, 'max_depth': 5, 'min_child_samples': 988, 'learning_rate': 0.30634792900324187, 'min_data_in_leaf': 54, 'bagging_fraction': 0.6547776576603666, 'feature_fraction': 0.7478727540299638}. Best is trial 38 with value: 0.721807105943202.
# [I 2020-12-09 00:14:43,521] Trial 44 finished with value: 0.7218041743423995 and parameters: {'num_leaves': 25, 'n_estimators': 288, 'max_depth': 5, 'min_child_samples': 986, 'learning_rate': 0.31310814176614776, 'min_data_in_leaf': 58, 'bagging_fraction': 0.6490946834233858, 'feature_fraction': 0.719831971012334}. Best is trial 38 with value: 0.721807105943202.
# [I 2020-12-09 00:16:38,928] Trial 45 finished with value: 0.7217754377615424 and parameters: {'num_leaves': 24, 'n_estimators': 270, 'max_depth': 5, 'min_child_samples': 988, 'learning_rate': 0.3950674601212365, 'min_data_in_leaf': 65, 'bagging_fraction': 0.7683466445180136, 'feature_fraction': 0.660695490421573}. Best is trial 38 with value: 0.721807105943202.
# [I 2020-12-09 00:18:50,655] Trial 46 finished with value: 0.7217518143570758 and parameters: {'num_leaves': 25, 'n_estimators': 298, 'max_depth': 4, 'min_child_samples': 837, 'learning_rate': 0.3113529451880794, 'min_data_in_leaf': 73, 'bagging_fraction': 0.6814429170565213, 'feature_fraction': 0.7112468025874226}. Best is trial 38 with value: 0.721807105943202.
# [I 2020-12-09 00:20:54,938] Trial 47 finished with value: 0.721735052351196 and parameters: {'num_leaves': 28, 'n_estimators': 260, 'max_depth': 5, 'min_child_samples': 849, 'learning_rate': 0.4418301057496517, 'min_data_in_leaf': 58, 'bagging_fraction': 0.8769157311382393, 'feature_fraction': 0.588075625915629}. Best is trial 38 with value: 0.721807105943202.
# [I 2020-12-09 00:23:03,021] Trial 48 finished with value: 0.7218010589013018 and parameters: {'num_leaves': 23, 'n_estimators': 277, 'max_depth': 5, 'min_child_samples': 1021, 'learning_rate': 0.32462659089543733, 'min_data_in_leaf': 54, 'bagging_fraction': 0.6595046561762794, 'feature_fraction': 0.9918411390369735}. Best is trial 38 with value: 0.721807105943202.
# [I 2020-12-09 00:25:14,668] Trial 49 finished with value: 0.7217457673950701 and parameters: {'num_leaves': 23, 'n_estimators': 291, 'max_depth': 4, 'min_child_samples': 1065, 'learning_rate': 0.3516114024746937, 'min_data_in_leaf': 64, 'bagging_fraction': 0.4747568106376713, 'feature_fraction': 0.9987691951073742}. Best is trial 38 with value: 0.721807105943202.
# [I 2020-12-09 00:27:18,570] Trial 50 finished with value: 0.7216400288897634 and parameters: {'num_leaves': 26, 'n_estimators': 300, 'max_depth': 3, 'min_child_samples': 949, 'learning_rate': 0.26249495166672526, 'min_data_in_leaf': 46, 'bagging_fraction': 0.29856719994957526, 'feature_fraction': 0.9429381472455753}. Best is trial 38 with value: 0.721807105943202.
# [I 2020-12-09 00:29:26,053] Trial 51 finished with value: 0.7218304251354642 and parameters: {'num_leaves': 24, 'n_estimators': 275, 'max_depth': 5, 'min_child_samples': 1021, 'learning_rate': 0.2917353070190297, 'min_data_in_leaf': 54, 'bagging_fraction': 0.672031123804561, 'feature_fraction': 0.8873705167954823}. Best is trial 51 with value: 0.7218304251354642.
# [I 2020-12-09 00:31:28,205] Trial 52 finished with value: 0.721728951408008 and parameters: {'num_leaves': 21, 'n_estimators': 262, 'max_depth': 5, 'min_child_samples': 1035, 'learning_rate': 0.4617854754575896, 'min_data_in_leaf': 60, 'bagging_fraction': 0.7561096835039932, 'feature_fraction': 0.8809547691721299}. Best is trial 51 with value: 0.7218304251354642.
# [I 2020-12-09 00:33:26,062] Trial 53 finished with value: 0.72181994047668 and parameters: {'num_leaves': 23, 'n_estimators': 250, 'max_depth': 5, 'min_child_samples': 1151, 'learning_rate': 0.2715920626412282, 'min_data_in_leaf': 83, 'bagging_fraction': 0.540834982548989, 'feature_fraction': 0.9821220984190007}. Best is trial 51 with value: 0.7218304251354642.
# [I 2020-12-09 00:35:38,849] Trial 54 finished with value: 0.7217731373759283 and parameters: {'num_leaves': 25, 'n_estimators': 290, 'max_depth': 5, 'min_child_samples': 1008, 'learning_rate': 0.32888833483169744, 'min_data_in_leaf': 83, 'bagging_fraction': 0.5504250394956419, 'feature_fraction': 0.9727142173674925}. Best is trial 51 with value: 0.7218304251354642.
# [I 2020-12-09 00:37:46,180] Trial 55 finished with value: 0.7217833277924539 and parameters: {'num_leaves': 22, 'n_estimators': 277, 'max_depth': 5, 'min_child_samples': 884, 'learning_rate': 0.39594585844205177, 'min_data_in_leaf': 69, 'bagging_fraction': 0.6721003358373214, 'feature_fraction': 0.9094744561376457}. Best is trial 51 with value: 0.7218304251354642.
# [I 2020-12-09 00:39:54,164] Trial 56 finished with value: 0.7217575454197591 and parameters: {'num_leaves': 23, 'n_estimators': 257, 'max_depth': 4, 'min_child_samples': 1072, 'learning_rate': 0.283288462189207, 'min_data_in_leaf': 81, 'bagging_fraction': 0.7387739653177336, 'feature_fraction': 0.865929392773805}. Best is trial 51 with value: 0.7218304251354642.
# [I 2020-12-09 00:41:37,469] Trial 57 finished with value: 0.7217742832232003 and parameters: {'num_leaves': 26, 'n_estimators': 185, 'max_depth': 5, 'min_child_samples': 1155, 'learning_rate': 0.20363515217776612, 'min_data_in_leaf': 55, 'bagging_fraction': 0.5119744910758625, 'feature_fraction': 0.9571917937746154}. Best is trial 51 with value: 0.7218304251354642.
# [I 2020-12-09 00:43:45,114] Trial 58 finished with value: 0.721787448698129 and parameters: {'num_leaves': 28, 'n_estimators': 249, 'max_depth': 5, 'min_child_samples': 248, 'learning_rate': 0.13736369771767193, 'min_data_in_leaf': 61, 'bagging_fraction': 0.5896532509979759, 'feature_fraction': 0.817314748758794}. Best is trial 51 with value: 0.7218304251354642.
# [I 2020-12-09 00:45:22,032] Trial 59 finished with value: 0.721766025387356 and parameters: {'num_leaves': 23, 'n_estimators': 212, 'max_depth': 6, 'min_child_samples': 953, 'learning_rate': 0.38682446264970777, 'min_data_in_leaf': 90, 'bagging_fraction': 0.6443255284604906, 'feature_fraction': 0.873696463675111}. Best is trial 51 with value: 0.7218304251354642.
# [I 2020-12-09 00:47:23,298] Trial 60 finished with value: 0.7217936606891888 and parameters: {'num_leaves': 21, 'n_estimators': 266, 'max_depth': 5, 'min_child_samples': 1112, 'learning_rate': 0.281396712802557, 'min_data_in_leaf': 78, 'bagging_fraction': 0.5436184383984455, 'feature_fraction': 0.9151434949931603}. Best is trial 51 with value: 0.7218304251354642.
# [I 2020-12-09 00:49:24,152] Trial 61 finished with value: 0.7218059233055905 and parameters: {'num_leaves': 21, 'n_estimators': 269, 'max_depth': 5, 'min_child_samples': 1123, 'learning_rate': 0.2967170623149279, 'min_data_in_leaf': 82, 'bagging_fraction': 0.5349738447748403, 'feature_fraction': 0.9125593447620014}. Best is trial 51 with value: 0.7218304251354642.
# [I 2020-12-09 00:51:38,902] Trial 62 finished with value: 0.7217725069771276 and parameters: {'num_leaves': 24, 'n_estimators': 276, 'max_depth': 5, 'min_child_samples': 1159, 'learning_rate': 0.3253519654473982, 'min_data_in_leaf': 83, 'bagging_fraction': 0.7084572421958835, 'feature_fraction': 0.9925879090422812}. Best is trial 51 with value: 0.7218304251354642.
# [I 2020-12-09 00:53:36,525] Trial 63 finished with value: 0.7218095905275113 and parameters: {'num_leaves': 26, 'n_estimators': 231, 'max_depth': 5, 'min_child_samples': 1060, 'learning_rate': 0.22793174467170968, 'min_data_in_leaf': 68, 'bagging_fraction': 0.8075593492278297, 'feature_fraction': 0.8061736386565914}. Best is trial 51 with value: 0.7218304251354642.
# [I 2020-12-09 00:55:05,420] Trial 64 finished with value: 0.7216537975498155 and parameters: {'num_leaves': 27, 'n_estimators': 166, 'max_depth': 4, 'min_child_samples': 1055, 'learning_rate': 0.2478890350158132, 'min_data_in_leaf': 68, 'bagging_fraction': 0.8259368295288219, 'feature_fraction': 0.9017380785121386}. Best is trial 51 with value: 0.7218304251354642.
# [I 2020-12-09 00:56:57,808] Trial 65 finished with value: 0.7217716471350928 and parameters: {'num_leaves': 26, 'n_estimators': 228, 'max_depth': 5, 'min_child_samples': 973, 'learning_rate': 0.3581044734279246, 'min_data_in_leaf': 86, 'bagging_fraction': 0.9179128647149601, 'feature_fraction': 0.9681894867298041}. Best is trial 51 with value: 0.7218304251354642.
# [I 2020-12-09 00:58:49,291] Trial 66 finished with value: 0.7217485907437495 and parameters: {'num_leaves': 25, 'n_estimators': 234, 'max_depth': 4, 'min_child_samples': 1013, 'learning_rate': 0.4310690964466737, 'min_data_in_leaf': 75, 'bagging_fraction': 0.599211451200128, 'feature_fraction': 0.8504389741793917}. Best is trial 51 with value: 0.7218304251354642.
# [I 2020-12-09 01:00:46,054] Trial 67 finished with value: 0.7217520610007175 and parameters: {'num_leaves': 30, 'n_estimators': 194, 'max_depth': 5, 'min_child_samples': 872, 'learning_rate': 0.13750505171400285, 'min_data_in_leaf': 72, 'bagging_fraction': 0.8059109468860666, 'feature_fraction': 0.8143789692356274}. Best is trial 51 with value: 0.7218304251354642.
# [I 2020-12-09 01:02:41,687] Trial 68 finished with value: 0.7217466162971705 and parameters: {'num_leaves': 28, 'n_estimators': 250, 'max_depth': 5, 'min_child_samples': 1093, 'learning_rate': 0.47865288775582143, 'min_data_in_leaf': 76, 'bagging_fraction': 0.48660247048259025, 'feature_fraction': 0.6878943330480118}. Best is trial 51 with value: 0.7218304251354642.
# [I 2020-12-09 01:04:28,303] Trial 69 finished with value: 0.7218070929170058 and parameters: {'num_leaves': 24, 'n_estimators': 216, 'max_depth': 5, 'min_child_samples': 777, 'learning_rate': 0.29373101710689886, 'min_data_in_leaf': 66, 'bagging_fraction': 0.5249732389485379, 'feature_fraction': 0.8844288878950768}. Best is trial 51 with value: 0.7218304251354642.
# {'num_leaves': 24, 'n_estimators': 275, 'max_depth': 5, 'min_child_samples': 1021, 'learning_rate': 0.2917353070190297, 'min_data_in_leaf': 54, 'bagging_fraction': 0.672031123804561, 'feature_fraction': 0.8873705167954823}

# %%
model = lgb.LGBMClassifier(**params)

model.fit(train_df[features], train_df[target])
print('LGB score: ', roc_auc_score(test_df[target].values, model.predict_proba(test_df[features])[:,1]))
# Out:
# LGB score:  0.7218414484295962

# %% [markdown]
# # Submit

# %%
for (test_df, sample_prediction_df) in iter_test:
    test_df = test_df.merge(user_answers_df, how='left', on='user_id')
    test_df = test_df.merge(content_answers_df, how='left', on='content_id')
    test_df['prior_question_had_explanation'] = test_df['prior_question_had_explanation'].fillna(value=False).astype(bool)
    test_df.fillna(value = 0.5, inplace = True)

    test_df['answered_correctly'] = model.predict_proba(test_df[features])[:,1]
    env.predict(test_df.loc[test_df['content_type_id'] == 0, ['row_id', 'answered_correctly']])
