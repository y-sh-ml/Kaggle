# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

import riiideducation
env = riiideducation.make_env()
iter_test = env.iter_test()
# Out:
# /kaggle/input/riiid-test-answer-prediction/example_sample_submission.csv
# /kaggle/input/riiid-test-answer-prediction/example_test.csv
# /kaggle/input/riiid-test-answer-prediction/questions.csv
# /kaggle/input/riiid-test-answer-prediction/train.csv
# /kaggle/input/riiid-test-answer-prediction/lectures.csv
# /kaggle/input/riiid-test-answer-prediction/riiideducation/competition.cpython-37m-x86_64-linux-gnu.so
# /kaggle/input/riiid-test-answer-prediction/riiideducation/__init__.py

# %%
import optuna
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# .datatable .frame thead tr.colnames {  background-image: url('data:image/png;base64,...');  background-repeat: repeat-x;  background-size: 14px;  height: 28px;}
# </style>

# %%
used_data_types_dict = {
    'user_id': 'int32',
    'content_id': 'int16',
    'content_type_id':'int8',
    'answered_correctly': 'int8',
    'prior_question_elapsed_time': 'float16',
    'prior_question_had_explanation': 'boolean'
}

target = 'answered_correctly'

train_df = pd.read_csv('/kaggle/input/riiid-test-answer-prediction/train.csv',
                       usecols = used_data_types_dict.keys(),
                       dtype=used_data_types_dict, nrows=10**6)

train_df = train_df[train_df['answered_correctly'] != -1].reset_index(drop=True)

print(train_df.dtypes)
print(train_df.shape)
train_df.head(10)
# Out:
# user_id                             int32
# content_id                          int16
# content_type_id                      int8
# answered_correctly                   int8
# prior_question_elapsed_time       float16
# prior_question_had_explanation    boolean
# dtype: object
# (980093, 6)
#    user_id  content_id  content_type_id  answered_correctly  \
# 0      115        5692                0                   1
# 1      115        5716                0                   1
# 2      115         128                0                   1
# 3      115        7860                0                   1
# 4      115        7922                0                   1
# 5      115         156                0                   1
# 6      115          51                0                   1
# 7      115          50                0                   1
# 8      115        7896                0                   1
# 9      115        7863                0                   1
#
#    prior_question_elapsed_time  prior_question_had_explanation
# 0                          NaN                            <NA>
# 1                      36992.0                           False
# 2                      55008.0                           False
# 3                      19008.0                           False
# 4                      11000.0                           False
# 5                       5000.0                           False
# 6                      16992.0                           False
# 7                      16992.0                           False
# 8                      16000.0                           False
# 9                      16000.0                           False

# %% [markdown]
# row_id：行に対するid<br>
# timestamp：ユーザーが新規登録してから、該当イベント完了までにかかる時間<br>
# user_id：ユーザーのid<br>
# content_id：コンテンツのid<br>
# content_type_id：イベントが問題が投げていれば0、ユーザーがそのイベントを見ていれば1<br>
# task_container_id：問題または講義のバッチのid<br>
# user_answer：問題に対するユーザの解答した数字（講義の場合は、-1をnullとする）<br>
# answered_correctly：ユーザが正しく応答したもの（講義の場合は、-1をnullとする）<br>
# prior_question_elapsed_time：前の問題の回答にかかった時間<br>
# prior_question_had_explanation：前の問題の解説を見たかどうか

# %%
train_df['prior_question_had_explanation'].fillna(False, inplace=True)

print(train_df.isnull().sum())
train_df.head()
# Out:
# user_id                              0
# content_id                           0
# content_type_id                      0
# answered_correctly                   0
# prior_question_elapsed_time       3816
# prior_question_had_explanation       0
# dtype: int64
#    user_id  content_id  content_type_id  answered_correctly  \
# 0      115        5692                0                   1
# 1      115        5716                0                   1
# 2      115         128                0                   1
# 3      115        7860                0                   1
# 4      115        7922                0                   1
#
#    prior_question_elapsed_time  prior_question_had_explanation
# 0                          NaN                           False
# 1                      36992.0                           False
# 2                      55008.0                           False
# 3                      19008.0                           False
# 4                      11000.0                           False

# %%
train_df['lag'] = train_df.groupby('user_id')[target].shift()

print(train_df.shape)
train_df.head()
# Out:
# (980093, 7)
#    user_id  content_id  content_type_id  answered_correctly  \
# 0      115        5692                0                   1
# 1      115        5716                0                   1
# 2      115         128                0                   1
# 3      115        7860                0                   1
# 4      115        7922                0                   1
#
#    prior_question_elapsed_time  prior_question_had_explanation  lag
# 0                          NaN                           False  NaN
# 1                      36992.0                           False  1.0
# 2                      55008.0                           False  1.0
# 3                      19008.0                           False  1.0
# 4                      11000.0                           False  1.0

# %%
cum = train_df.groupby('user_id')['lag'].agg(['cumsum', 'cumcount'])

print(cum.shape)
cum.head()
# Out:
# (980093, 2)
#    cumsum  cumcount
# 0     NaN         0
# 1     1.0         1
# 2     2.0         2
# 3     3.0         3
# 4     4.0         4

# %%
train_df['user_correctness'] = cum['cumsum'] / cum['cumcount']
train_df.drop(columns=['lag'], inplace=True)

print(train_df.isnull().sum())
print(train_df.shape)
train_df.head()
# Out:
# user_id                              0
# content_id                           0
# content_type_id                      0
# answered_correctly                   0
# prior_question_elapsed_time       3816
# prior_question_had_explanation       0
# user_correctness                  3824
# dtype: int64
# (980093, 7)
#    user_id  content_id  content_type_id  answered_correctly  \
# 0      115        5692                0                   1
# 1      115        5716                0                   1
# 2      115         128                0                   1
# 3      115        7860                0                   1
# 4      115        7922                0                   1
#
#    prior_question_elapsed_time  prior_question_had_explanation  \
# 0                          NaN                           False
# 1                      36992.0                           False
# 2                      55008.0                           False
# 3                      19008.0                           False
# 4                      11000.0                           False
#
#    user_correctness
# 0               NaN
# 1               1.0
# 2               1.0
# 3               1.0
# 4               1.0

# %%
questions_df = pd.read_csv('../input/riiid-test-answer-prediction/questions.csv', usecols=[0, 3],
                           dtype={'question_id': 'int16', 'part': 'int8'})

questions_df.columns = ['question_id', 'question_part']

print(questions_df.shape)
questions_df.head(10)
# Out:
# (13523, 2)
#    question_id  question_part
# 0            0              1
# 1            1              1
# 2            2              1
# 3            3              1
# 4            4              1
# 5            5              1
# 6            6              1
# 7            7              1
# 8            8              1
# 9            9              1

# %% [markdown]
# question_id：コンテンツが問題ならば0、train・testデータの外部キー、小問番号<br>
# bundle_id：問題が一緒に出される番号、大問番号<br>
# correct_answer：問題へ解答した番号、train.csvの「user_answer」と照らし合わせて、正解したかどうかが分かるもの<br>
# part：TOEICにおける問題の各セクション<br>
# tags：質問をまとめるタグ

# %%
train_df = pd.merge(train_df, questions_df, left_on='content_id', right_on='question_id', how='left')
train_df.drop(columns=['question_id'], inplace=True)

print(train_df.isnull().sum())
print(train_df.shape)
train_df.head()
# Out:
# user_id                              0
# content_id                           0
# content_type_id                      0
# answered_correctly                   0
# prior_question_elapsed_time       3816
# prior_question_had_explanation       0
# user_correctness                  3824
# question_part                        0
# dtype: int64
# (980093, 8)
#    user_id  content_id  content_type_id  answered_correctly  \
# 0      115        5692                0                   1
# 1      115        5716                0                   1
# 2      115         128                0                   1
# 3      115        7860                0                   1
# 4      115        7922                0                   1
#
#    prior_question_elapsed_time  prior_question_had_explanation  \
# 0                          NaN                           False
# 1                      36992.0                           False
# 2                      55008.0                           False
# 3                      19008.0                           False
# 4                      11000.0                           False
#
#    user_correctness  question_part
# 0               NaN              5
# 1               1.0              5
# 2               1.0              1
# 3               1.0              1
# 4               1.0              1

# %%
lectures_df = pd.read_csv("/kaggle/input/riiid-test-answer-prediction/lectures.csv")

print(lectures_df.dtypes)
print(lectures_df.shape)
lectures_df.head(10)
# Out:
# lecture_id     int64
# tag            int64
# part           int64
# type_of       object
# dtype: object
# (418, 4)
#    lecture_id  tag  part           type_of
# 0          89  159     5           concept
# 1         100   70     1           concept
# 2         185   45     6           concept
# 3         192   79     5  solving question
# 4         317  156     5  solving question
# 5         335  114     2           concept
# 6         484  179     5           concept
# 7         641  134     6  solving question
# 8         761   93     1           concept
# 9         814   80     5  solving question

# %% [markdown]
# lecture_id：コンテンツタイプが講義なら1、train・testデータにおけるcontent_idの外部キー<br>
# tag：講義をまとめるタグ<br>
# part：講義のカテゴリーコード（識別するもの）<br>
# type_of：講義の目的の説明

# %%
lectures_df['type_of'] = lectures_df['type_of'].replace('solving question', 'solving_question')
lectures_df = pd.get_dummies(lectures_df, columns=['part', 'type_of'])

part_lectures_columns = [column for column in lectures_df.columns if column.startswith('part')]
types_of_lectures_columns = [column for column in lectures_df.columns if column.startswith('type_of_')]

print(part_lectures_columns)
print(types_of_lectures_columns)
lectures_df.head()
# Out:
# ['part_1', 'part_2', 'part_3', 'part_4', 'part_5', 'part_6', 'part_7']
# ['type_of_concept', 'type_of_intention', 'type_of_solving_question', 'type_of_starter']
#    lecture_id  tag  part_1  part_2  part_3  part_4  part_5  part_6  part_7  \
# 0          89  159       0       0       0       0       1       0       0
# 1         100   70       1       0       0       0       0       0       0
# 2         185   45       0       0       0       0       0       1       0
# 3         192   79       0       0       0       0       1       0       0
# 4         317  156       0       0       0       0       1       0       0
#
#    type_of_concept  type_of_intention  type_of_solving_question  \
# 0                1                  0                         0
# 1                1                  0                         0
# 2                1                  0                         0
# 3                0                  0                         1
# 4                0                  0                         1
#
#    type_of_starter
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0

# %% [markdown]
# 下記のように2分割するまでに、train_df全体としての特徴量を増やしておきたい。

# %%
features_df = train_df.iloc[:int(9/10 * len(train_df))]
train_df = train_df.iloc[int(9/10 * len(train_df)):]

print(features_df.shape)
print(train_df.shape)
# Out:
# (882083, 8)
# (98010, 8)

# %%
grouped_by_user_df = features_df.groupby('user_id')

user_answers_df = grouped_by_user_df.agg({'answered_correctly': ['mean', 'count','std','median','skew']}).copy()

user_answers_df.columns = ['mean_user_accuracy', 
                           'questions_answered', 
                           'std_user_accuracy', 
                           'median_user_accuracy', 
                           'skew_user_accuracy']

print(user_answers_df.dtypes)
print(user_answers_df.shape)
user_answers_df.head()
# Out:
# mean_user_accuracy      float64
# questions_answered        int64
# std_user_accuracy       float64
# median_user_accuracy    float64
# skew_user_accuracy      float64
# dtype: object
# (3458, 5)
#          mean_user_accuracy  questions_answered  std_user_accuracy  \
# user_id
# 115                0.695652                  46           0.465215
# 124                0.233333                  30           0.430183
# 2746               0.578947                  19           0.507257
# 5382               0.672000                 125           0.471374
# 8623               0.642202                 109           0.481566
#
#          median_user_accuracy  skew_user_accuracy
# user_id
# 115                       1.0           -0.879359
# 124                       0.0            1.328338
# 2746                      1.0           -0.347892
# 5382                      1.0           -0.741648
# 8623                      1.0           -0.601619

# %%
grouped_by_content_df = features_df.groupby('content_id')

content_answers_df = grouped_by_content_df.agg({'answered_correctly': ['mean', 'count','std','median','skew']}).copy()

content_answers_df.columns = ['mean_accuracy', 
                              'question_asked', 
                              'std_accuracy', 
                              'median_accuracy', 
                              'skew_accuracy']

print(content_answers_df.dtypes)
print(content_answers_df.shape)
content_answers_df.head()
# Out:
# mean_accuracy      float64
# question_asked       int64
# std_accuracy       float64
# median_accuracy    float64
# skew_accuracy      float64
# dtype: object
# (12986, 5)
#             mean_accuracy  question_asked  std_accuracy  median_accuracy  \
# content_id
# 0                0.857143              70      0.352454              1.0
# 1                0.918367              49      0.276642              1.0
# 2                0.555276             398      0.497561              1.0
# 3                0.784091             176      0.412625              1.0
# 4                0.600760             263      0.490676              1.0
#
#             skew_accuracy
# content_id
# 0               -2.086215
# 1               -3.153323
# 2               -0.223312
# 3               -1.392819
# 4               -0.413848

# %%
del features_df
del grouped_by_user_df
del grouped_by_content_df

# %%
train_df = train_df.merge(user_answers_df, how='left', on='user_id')
train_df = train_df.merge(content_answers_df, how='left', on='content_id')

print(train_df.dtypes)
print(train_df.shape)
train_df.head()
# Out:
# user_id                             int32
# content_id                          int16
# content_type_id                      int8
# answered_correctly                   int8
# prior_question_elapsed_time       float16
# prior_question_had_explanation    boolean
# user_correctness                  float64
# question_part                        int8
# mean_user_accuracy                float64
# questions_answered                float64
# std_user_accuracy                 float64
# median_user_accuracy              float64
# skew_user_accuracy                float64
# mean_accuracy                     float64
# question_asked                    float64
# std_accuracy                      float64
# median_accuracy                   float64
# skew_accuracy                     float64
# dtype: object
# (98010, 18)
#     user_id  content_id  content_type_id  answered_correctly  \
# 0  18789336        7796                0                   0
# 1  18789336        7798                0                   0
# 2  18789336        2908                0                   0
# 3  18789336        2909                0                   0
# 4  18789336        2907                0                   0
#
#    prior_question_elapsed_time  prior_question_had_explanation  \
# 0                       1400.0                            True
# 1                       1400.0                            True
# 2                       1600.0                            True
# 3                       1600.0                            True
# 4                       1600.0                            True
#
#    user_correctness  question_part  mean_user_accuracy  questions_answered  \
# 0          0.310865              7            0.310865              2255.0
# 1          0.310727              7            0.310865              2255.0
# 2          0.310589              4            0.310865              2255.0
# 3          0.310452              4            0.310865              2255.0
# 4          0.310314              4            0.310865              2255.0
#
#    std_user_accuracy  median_user_accuracy  skew_user_accuracy  mean_accuracy  \
# 0            0.46295                   0.0            0.817812       0.962963
# 1            0.46295                   0.0            0.817812       0.870370
# 2            0.46295                   0.0            0.817812       0.676768
# 3            0.46295                   0.0            0.817812       0.616162
# 4            0.46295                   0.0            0.817812       0.454545
#
#    question_asked  std_accuracy  median_accuracy  skew_accuracy
# 0            54.0      0.190626              1.0      -5.044113
# 1            54.0      0.339050              1.0      -2.268786
# 2            99.0      0.470091              1.0      -0.767564
# 3            99.0      0.488794              1.0      -0.485099
# 4            99.0      0.500464              0.0       0.185395

# %%
features = [
    'mean_user_accuracy', 
    'questions_answered',
    'std_user_accuracy', 
    'median_user_accuracy',
    'skew_user_accuracy',
    'mean_accuracy', 
    'question_asked',
    'std_accuracy', 
    'median_accuracy',
    'prior_question_elapsed_time', 
    'prior_question_had_explanation',
    'user_correctness',
    'skew_accuracy'
]

target = 'answered_correctly'

print(train_df.isnull().sum())
# Out:
# user_id                               0
# content_id                            0
# content_type_id                       0
# answered_correctly                    0
# prior_question_elapsed_time         366
# prior_question_had_explanation        0
# user_correctness                    366
# question_part                         0
# mean_user_accuracy                97881
# questions_answered                97881
# std_user_accuracy                 97881
# median_user_accuracy              97881
# skew_user_accuracy                97881
# mean_accuracy                       100
# question_asked                      100
# std_accuracy                        231
# median_accuracy                     100
# skew_accuracy                       325
# dtype: int64

# %%
train_df = train_df.fillna(value=0.5)
train_df.isnull().sum()
# Out:
# user_id                           0
# content_id                        0
# content_type_id                   0
# answered_correctly                0
# prior_question_elapsed_time       0
# prior_question_had_explanation    0
# user_correctness                  0
# question_part                     0
# mean_user_accuracy                0
# questions_answered                0
# std_user_accuracy                 0
# median_user_accuracy              0
# skew_user_accuracy                0
# mean_accuracy                     0
# question_asked                    0
# std_accuracy                      0
# median_accuracy                   0
# skew_accuracy                     0
# dtype: int64

# %%
train_df['prior_question_had_explanation'] = train_df['prior_question_had_explanation'].astype('int')

# %% [markdown]
# # Modeling

# %%
train_df, test_df = train_test_split(train_df, random_state=666, test_size=0.2)

print(train_df.dtypes)
print(train_df.shape)
print(test_df.shape)
train_df.head()
# Out:
# user_id                             int32
# content_id                          int16
# content_type_id                      int8
# answered_correctly                   int8
# prior_question_elapsed_time       float16
# prior_question_had_explanation      int64
# user_correctness                  float64
# question_part                        int8
# mean_user_accuracy                float64
# questions_answered                float64
# std_user_accuracy                 float64
# median_user_accuracy              float64
# skew_user_accuracy                float64
# mean_accuracy                     float64
# question_asked                    float64
# std_accuracy                      float64
# median_accuracy                   float64
# skew_accuracy                     float64
# dtype: object
# (78408, 18)
# (19602, 18)
#         user_id  content_id  content_type_id  answered_correctly  \
# 1273   18802864       10940                0                   1
# 5034   18824449         350                0                   1
# 37526  19492810        8742                0                   1
# 29573  19444654        5810                0                   0
# 31622  19489973        8460                0                   0
#
#        prior_question_elapsed_time  prior_question_had_explanation  \
# 1273                       26336.0                               1
# 5034                       16992.0                               1
# 37526                      15000.0                               1
# 29573                       7000.0                               1
# 31622                      20992.0                               1
#
#        user_correctness  question_part  mean_user_accuracy  \
# 1273           0.470588              6                 0.5
# 5034           0.666667              2                 0.5
# 37526          0.689655              5                 0.5
# 29573          0.573070              5                 0.5
# 31622          0.667297              5                 0.5
#
#        questions_answered  std_user_accuracy  median_user_accuracy  \
# 1273                  0.5                0.5                   0.5
# 5034                  0.5                0.5                   0.5
# 37526                 0.5                0.5                   0.5
# 29573                 0.5                0.5                   0.5
# 31622                 0.5                0.5                   0.5
#
#        skew_user_accuracy  mean_accuracy  question_asked  std_accuracy  \
# 1273                  0.5       0.833333            42.0      0.377195
# 5034                  0.5       0.733813           139.0      0.443562
# 37526                 0.5       0.763636            55.0      0.428764
# 29573                 0.5       0.428571            21.0      0.507093
# 31622                 0.5       0.710227           176.0      0.454951
#
#        median_accuracy  skew_accuracy
# 1273               1.0      -1.855802
# 5034               1.0      -1.069643
# 37526              1.0      -1.276157
# 29573              0.0       0.311373
# 31622              1.0      -0.934798

# %%
def create_model(trial):
    num_leaves = trial.suggest_int("num_leaves", 2, 31)
    n_estimators = trial.suggest_int("n_estimators", 50, 300)
    max_depth = trial.suggest_int('max_depth', 3, 8)
    min_child_samples = trial.suggest_int('min_child_samples', 100, 1200)
    learning_rate = trial.suggest_uniform('learning_rate', 0.0001, 0.99)
    min_data_in_leaf = trial.suggest_int('min_data_in_leaf', 5, 90)
    bagging_fraction = trial.suggest_uniform('bagging_fraction', 0.0001, 1.0)
    feature_fraction = trial.suggest_uniform('feature_fraction', 0.0001, 1.0)
    
    model = lgb.LGBMClassifier(
        num_leaves=num_leaves,
        n_estimators=n_estimators, 
        max_depth=max_depth, 
        min_child_samples=min_child_samples, 
        min_data_in_leaf=min_data_in_leaf,
        learning_rate=learning_rate,
        feature_fraction=feature_fraction,
        random_state=666
    )
    return model

# %%
def objective(trial):
    model = create_model(trial)
    model.fit(train_df[features], train_df[target])
    score = roc_auc_score(
        test_df[target].values, 
        model.predict_proba(test_df[features])[:,1]
    )
    return score

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=70)
params = study.best_params

print(params)
# Out:
# [I 2020-12-27 13:13:07,391] A new study created in memory with name: no-name-a1c2aca3-2cdd-42d4-b0c8-13e4b98961b8
# [I 2020-12-27 13:13:07,947] Trial 0 finished with value: 0.7242047427739593 and parameters: {'num_leaves': 6, 'n_estimators': 127, 'max_depth': 5, 'min_child_samples': 115, 'learning_rate': 0.9744603674078063, 'min_data_in_leaf': 65, 'bagging_fraction': 0.26626875513977843, 'feature_fraction': 0.7469443330361799}. Best is trial 0 with value: 0.7242047427739593.
# [I 2020-12-27 13:13:08,699] Trial 1 finished with value: 0.7258578936288177 and parameters: {'num_leaves': 29, 'n_estimators': 227, 'max_depth': 3, 'min_child_samples': 996, 'learning_rate': 0.8280979672060833, 'min_data_in_leaf': 31, 'bagging_fraction': 0.594405610080071, 'feature_fraction': 0.3527327611127342}. Best is trial 1 with value: 0.7258578936288177.
# [I 2020-12-27 13:13:09,277] Trial 2 finished with value: 0.715994903887763 and parameters: {'num_leaves': 27, 'n_estimators': 113, 'max_depth': 7, 'min_child_samples': 212, 'learning_rate': 0.5457958989564263, 'min_data_in_leaf': 6, 'bagging_fraction': 0.2879384707105039, 'feature_fraction': 0.8176126028234261}. Best is trial 1 with value: 0.7258578936288177.
# [I 2020-12-27 13:13:09,975] Trial 3 finished with value: 0.733267232321846 and parameters: {'num_leaves': 4, 'n_estimators': 275, 'max_depth': 8, 'min_child_samples': 777, 'learning_rate': 0.5638285568836423, 'min_data_in_leaf': 13, 'bagging_fraction': 0.4523998622093847, 'feature_fraction': 0.12373773959701309}. Best is trial 3 with value: 0.733267232321846.
# [I 2020-12-27 13:13:11,007] Trial 4 finished with value: 0.6987254020217388 and parameters: {'num_leaves': 24, 'n_estimators': 258, 'max_depth': 8, 'min_child_samples': 802, 'learning_rate': 0.8027059023790621, 'min_data_in_leaf': 61, 'bagging_fraction': 0.40886556944613656, 'feature_fraction': 0.5176679932720172}. Best is trial 3 with value: 0.733267232321846.
# [I 2020-12-27 13:13:11,274] Trial 5 finished with value: 0.7328443811943074 and parameters: {'num_leaves': 4, 'n_estimators': 58, 'max_depth': 7, 'min_child_samples': 775, 'learning_rate': 0.7236219646617656, 'min_data_in_leaf': 21, 'bagging_fraction': 0.32160707969862656, 'feature_fraction': 0.14644891922841155}. Best is trial 3 with value: 0.733267232321846.
# [I 2020-12-27 13:13:12,143] Trial 6 finished with value: 0.7346799521889755 and parameters: {'num_leaves': 14, 'n_estimators': 193, 'max_depth': 3, 'min_child_samples': 324, 'learning_rate': 0.3480897729043796, 'min_data_in_leaf': 57, 'bagging_fraction': 0.4345121287762282, 'feature_fraction': 0.5210015386959215}. Best is trial 6 with value: 0.7346799521889755.
# [I 2020-12-27 13:13:12,488] Trial 7 finished with value: 0.7319940447492355 and parameters: {'num_leaves': 21, 'n_estimators': 60, 'max_depth': 8, 'min_child_samples': 1020, 'learning_rate': 0.2901677333486237, 'min_data_in_leaf': 61, 'bagging_fraction': 0.38603503400574696, 'feature_fraction': 0.15058012405539736}. Best is trial 6 with value: 0.7346799521889755.
# [I 2020-12-27 13:13:13,349] Trial 8 finished with value: 0.7293658603195265 and parameters: {'num_leaves': 4, 'n_estimators': 225, 'max_depth': 3, 'min_child_samples': 476, 'learning_rate': 0.9769313976723483, 'min_data_in_leaf': 81, 'bagging_fraction': 0.9995361898020856, 'feature_fraction': 0.827568551983446}. Best is trial 6 with value: 0.7346799521889755.
# [I 2020-12-27 13:13:13,633] Trial 9 finished with value: 0.7316544881496854 and parameters: {'num_leaves': 2, 'n_estimators': 63, 'max_depth': 8, 'min_child_samples': 549, 'learning_rate': 0.8659718232743094, 'min_data_in_leaf': 20, 'bagging_fraction': 0.3786698553080806, 'feature_fraction': 0.5641011201241581}. Best is trial 6 with value: 0.7346799521889755.
# [I 2020-12-27 13:13:14,448] Trial 10 finished with value: 0.7339947598536839 and parameters: {'num_leaves': 12, 'n_estimators': 190, 'max_depth': 4, 'min_child_samples': 327, 'learning_rate': 0.03211865931230917, 'min_data_in_leaf': 41, 'bagging_fraction': 0.022370659503226142, 'feature_fraction': 0.3404197088469837}. Best is trial 6 with value: 0.7346799521889755.
# [I 2020-12-27 13:13:15,248] Trial 11 finished with value: 0.7338449056925066 and parameters: {'num_leaves': 13, 'n_estimators': 168, 'max_depth': 4, 'min_child_samples': 316, 'learning_rate': 0.030875135092481343, 'min_data_in_leaf': 42, 'bagging_fraction': 0.04981721958337395, 'feature_fraction': 0.3821028349933328}. Best is trial 6 with value: 0.7346799521889755.
# [I 2020-12-27 13:13:15,992] Trial 12 finished with value: 0.7347796880171188 and parameters: {'num_leaves': 13, 'n_estimators': 177, 'max_depth': 4, 'min_child_samples': 385, 'learning_rate': 0.0428261204403228, 'min_data_in_leaf': 43, 'bagging_fraction': 0.6809499741110481, 'feature_fraction': 0.33396095873879517}. Best is trial 12 with value: 0.7347796880171188.
# [I 2020-12-27 13:13:16,742] Trial 13 finished with value: 0.732658604864725 and parameters: {'num_leaves': 16, 'n_estimators': 162, 'max_depth': 4, 'min_child_samples': 418, 'learning_rate': 0.32690702865123744, 'min_data_in_leaf': 79, 'bagging_fraction': 0.7009381036340712, 'feature_fraction': 0.6646282976105611}. Best is trial 12 with value: 0.7347796880171188.
# [I 2020-12-27 13:13:17,621] Trial 14 finished with value: 0.7345170129174159 and parameters: {'num_leaves': 10, 'n_estimators': 204, 'max_depth': 5, 'min_child_samples': 137, 'learning_rate': 0.20242744676300709, 'min_data_in_leaf': 51, 'bagging_fraction': 0.8188797336969778, 'feature_fraction': 0.981656879792846}. Best is trial 12 with value: 0.7347796880171188.
# [I 2020-12-27 13:13:18,126] Trial 15 finished with value: 0.735361632902035 and parameters: {'num_leaves': 19, 'n_estimators': 130, 'max_depth': 3, 'min_child_samples': 578, 'learning_rate': 0.1301497877222767, 'min_data_in_leaf': 48, 'bagging_fraction': 0.6095693065995925, 'feature_fraction': 0.29423938547985057}. Best is trial 15 with value: 0.735361632902035.
# [I 2020-12-27 13:13:18,657] Trial 16 finished with value: 0.7348031410482215 and parameters: {'num_leaves': 20, 'n_estimators': 124, 'max_depth': 4, 'min_child_samples': 627, 'learning_rate': 0.1437418615148014, 'min_data_in_leaf': 32, 'bagging_fraction': 0.8097503274857378, 'feature_fraction': 0.26434357925000684}. Best is trial 15 with value: 0.735361632902035.
# [I 2020-12-27 13:13:19,178] Trial 17 finished with value: 0.7332777787020572 and parameters: {'num_leaves': 20, 'n_estimators': 116, 'max_depth': 6, 'min_child_samples': 614, 'learning_rate': 0.18018999101877725, 'min_data_in_leaf': 30, 'bagging_fraction': 0.936664522627953, 'feature_fraction': 0.031127943457413654}. Best is trial 15 with value: 0.735361632902035.
# [I 2020-12-27 13:13:19,559] Trial 18 finished with value: 0.734070553326315 and parameters: {'num_leaves': 19, 'n_estimators': 89, 'max_depth': 3, 'min_child_samples': 681, 'learning_rate': 0.15121527800343038, 'min_data_in_leaf': 31, 'bagging_fraction': 0.7903685964136294, 'feature_fraction': 0.23177630815618838}. Best is trial 15 with value: 0.735361632902035.
# [I 2020-12-27 13:13:20,101] Trial 19 finished with value: 0.7317246112159257 and parameters: {'num_leaves': 23, 'n_estimators': 139, 'max_depth': 5, 'min_child_samples': 918, 'learning_rate': 0.3805089126533373, 'min_data_in_leaf': 75, 'bagging_fraction': 0.5690566723973989, 'feature_fraction': 0.03613551960517075}. Best is trial 15 with value: 0.735361632902035.
# [I 2020-12-27 13:13:20,499] Trial 20 finished with value: 0.7342221863256394 and parameters: {'num_leaves': 17, 'n_estimators': 91, 'max_depth': 4, 'min_child_samples': 1120, 'learning_rate': 0.4455518403925775, 'min_data_in_leaf': 90, 'bagging_fraction': 0.8809807920540365, 'feature_fraction': 0.24398605284948482}. Best is trial 15 with value: 0.735361632902035.
# [I 2020-12-27 13:13:22,000] Trial 21 finished with value: 0.7255964101779708 and parameters: {'num_leaves': 9, 'n_estimators': 146, 'max_depth': 4, 'min_child_samples': 500, 'learning_rate': 0.006855545448551242, 'min_data_in_leaf': 44, 'bagging_fraction': 0.6483891081947545, 'feature_fraction': 0.4154107468459829}. Best is trial 15 with value: 0.735361632902035.
# [I 2020-12-27 13:13:22,419] Trial 22 finished with value: 0.7347340772254086 and parameters: {'num_leaves': 17, 'n_estimators': 95, 'max_depth': 3, 'min_child_samples': 639, 'learning_rate': 0.10786311387242953, 'min_data_in_leaf': 51, 'bagging_fraction': 0.7219431684538068, 'feature_fraction': 0.26986706969554564}. Best is trial 15 with value: 0.735361632902035.
# [I 2020-12-27 13:13:23,299] Trial 23 finished with value: 0.7360119450420759 and parameters: {'num_leaves': 25, 'n_estimators': 161, 'max_depth': 4, 'min_child_samples': 401, 'learning_rate': 0.08169726005112735, 'min_data_in_leaf': 36, 'bagging_fraction': 0.5626889222300132, 'feature_fraction': 0.42555052189776854}. Best is trial 23 with value: 0.7360119450420759.
# [I 2020-12-27 13:13:23,982] Trial 24 finished with value: 0.7335145541486103 and parameters: {'num_leaves': 25, 'n_estimators': 149, 'max_depth': 5, 'min_child_samples': 580, 'learning_rate': 0.23492804192824515, 'min_data_in_leaf': 35, 'bagging_fraction': 0.5428070868121418, 'feature_fraction': 0.44234517249645033}. Best is trial 23 with value: 0.7360119450420759.
# [I 2020-12-27 13:13:24,628] Trial 25 finished with value: 0.7361641076631139 and parameters: {'num_leaves': 30, 'n_estimators': 111, 'max_depth': 6, 'min_child_samples': 686, 'learning_rate': 0.10030166143567876, 'min_data_in_leaf': 22, 'bagging_fraction': 0.781685833865072, 'feature_fraction': 0.6339345362780877}. Best is trial 25 with value: 0.7361641076631139.
# [I 2020-12-27 13:13:25,264] Trial 26 finished with value: 0.736223753430236 and parameters: {'num_leaves': 30, 'n_estimators': 101, 'max_depth': 6, 'min_child_samples': 713, 'learning_rate': 0.09176559413966816, 'min_data_in_leaf': 19, 'bagging_fraction': 0.5045147540862904, 'feature_fraction': 0.667610572502153}. Best is trial 26 with value: 0.736223753430236.
# [I 2020-12-27 13:13:25,893] Trial 27 finished with value: 0.7362294123231113 and parameters: {'num_leaves': 31, 'n_estimators': 101, 'max_depth': 6, 'min_child_samples': 852, 'learning_rate': 0.07751325449782365, 'min_data_in_leaf': 24, 'bagging_fraction': 0.19374272972763928, 'feature_fraction': 0.628997402288671}. Best is trial 27 with value: 0.7362294123231113.
# [I 2020-12-27 13:13:26,356] Trial 28 finished with value: 0.7327229423894194 and parameters: {'num_leaves': 30, 'n_estimators': 78, 'max_depth': 6, 'min_child_samples': 871, 'learning_rate': 0.27490571381732615, 'min_data_in_leaf': 6, 'bagging_fraction': 0.1418126313433153, 'feature_fraction': 0.632229382568053}. Best is trial 27 with value: 0.7362294123231113.
# [I 2020-12-27 13:13:26,923] Trial 29 finished with value: 0.7324626678577013 and parameters: {'num_leaves': 31, 'n_estimators': 101, 'max_depth': 7, 'min_child_samples': 711, 'learning_rate': 0.23372784150269865, 'min_data_in_leaf': 23, 'bagging_fraction': 0.1604535662946859, 'feature_fraction': 0.7198231197311039}. Best is trial 27 with value: 0.7362294123231113.
# [I 2020-12-27 13:13:27,650] Trial 30 finished with value: 0.7365617211646451 and parameters: {'num_leaves': 28, 'n_estimators': 108, 'max_depth': 6, 'min_child_samples': 892, 'learning_rate': 0.06949548283973625, 'min_data_in_leaf': 13, 'bagging_fraction': 0.4838179809691812, 'feature_fraction': 0.9108523878258267}. Best is trial 30 with value: 0.7365617211646451.
# [I 2020-12-27 13:13:28,326] Trial 31 finished with value: 0.7313642727208722 and parameters: {'num_leaves': 28, 'n_estimators': 76, 'max_depth': 6, 'min_child_samples': 880, 'learning_rate': 0.0023776584370947124, 'min_data_in_leaf': 13, 'bagging_fraction': 0.48799355270967665, 'feature_fraction': 0.9128292965911767}. Best is trial 30 with value: 0.7365617211646451.
# [I 2020-12-27 13:13:28,769] Trial 32 finished with value: 0.7360751599990076 and parameters: {'num_leaves': 31, 'n_estimators': 50, 'max_depth': 6, 'min_child_samples': 980, 'learning_rate': 0.0836515127659216, 'min_data_in_leaf': 14, 'bagging_fraction': 0.17326114644058566, 'feature_fraction': 0.5943708721272911}. Best is trial 30 with value: 0.7365617211646451.
# [I 2020-12-27 13:13:29,459] Trial 33 finished with value: 0.7359874788216078 and parameters: {'num_leaves': 27, 'n_estimators': 109, 'max_depth': 7, 'min_child_samples': 1089, 'learning_rate': 0.08196733981996511, 'min_data_in_leaf': 26, 'bagging_fraction': 0.27108905778129216, 'feature_fraction': 0.7627754447981536}. Best is trial 30 with value: 0.7365617211646451.
# [I 2020-12-27 13:13:29,990] Trial 34 finished with value: 0.73524501250339 and parameters: {'num_leaves': 29, 'n_estimators': 78, 'max_depth': 6, 'min_child_samples': 731, 'learning_rate': 0.18048742118256478, 'min_data_in_leaf': 6, 'bagging_fraction': 0.20175496768258294, 'feature_fraction': 0.8594233614621865}. Best is trial 30 with value: 0.7365617211646451.
# [I 2020-12-27 13:13:30,921] Trial 35 finished with value: 0.7320451129472993 and parameters: {'num_leaves': 31, 'n_estimators': 125, 'max_depth': 7, 'min_child_samples': 840, 'learning_rate': 0.0039011667452196197, 'min_data_in_leaf': 17, 'bagging_fraction': 0.5088280615763037, 'feature_fraction': 0.7049463924831507}. Best is trial 30 with value: 0.7365617211646451.
# [I 2020-12-27 13:13:31,519] Trial 36 finished with value: 0.7160159045400611 and parameters: {'num_leaves': 27, 'n_estimators': 109, 'max_depth': 5, 'min_child_samples': 935, 'learning_rate': 0.6291357063160339, 'min_data_in_leaf': 8, 'bagging_fraction': 0.33534115645395, 'feature_fraction': 0.7711721697846666}. Best is trial 30 with value: 0.7365617211646451.
# [I 2020-12-27 13:13:32,248] Trial 37 finished with value: 0.720477247882938 and parameters: {'num_leaves': 29, 'n_estimators': 131, 'max_depth': 6, 'min_child_samples': 802, 'learning_rate': 0.4106911697174956, 'min_data_in_leaf': 25, 'bagging_fraction': 0.7545570038042962, 'feature_fraction': 0.9880165046216348}. Best is trial 30 with value: 0.7365617211646451.
# [I 2020-12-27 13:13:33,365] Trial 38 finished with value: 0.7264425096493334 and parameters: {'num_leaves': 23, 'n_estimators': 298, 'max_depth': 7, 'min_child_samples': 747, 'learning_rate': 0.2606029870403571, 'min_data_in_leaf': 19, 'bagging_fraction': 0.06309668288589812, 'feature_fraction': 0.4827159956934092}. Best is trial 30 with value: 0.7365617211646451.
# [I 2020-12-27 13:13:33,966] Trial 39 finished with value: 0.7259466110226137 and parameters: {'num_leaves': 26, 'n_estimators': 66, 'max_depth': 6, 'min_child_samples': 1044, 'learning_rate': 0.5320906410328188, 'min_data_in_leaf': 9, 'bagging_fraction': 0.2209235228134639, 'feature_fraction': 0.9182906550233225}. Best is trial 30 with value: 0.7365617211646451.
# [I 2020-12-27 13:13:34,623] Trial 40 finished with value: 0.7362395269464908 and parameters: {'num_leaves': 29, 'n_estimators': 103, 'max_depth': 7, 'min_child_samples': 1166, 'learning_rate': 0.05884293432727034, 'min_data_in_leaf': 12, 'bagging_fraction': 0.9898732396192225, 'feature_fraction': 0.5767509884193375}. Best is trial 30 with value: 0.7365617211646451.
# [I 2020-12-27 13:13:35,258] Trial 41 finished with value: 0.7360021758241619 and parameters: {'num_leaves': 29, 'n_estimators': 102, 'max_depth': 7, 'min_child_samples': 1182, 'learning_rate': 0.06895271174279219, 'min_data_in_leaf': 16, 'bagging_fraction': 0.985733327514254, 'feature_fraction': 0.5560267722594201}. Best is trial 30 with value: 0.7365617211646451.
# [I 2020-12-27 13:13:35,804] Trial 42 finished with value: 0.7361621964195384 and parameters: {'num_leaves': 31, 'n_estimators': 85, 'max_depth': 6, 'min_child_samples': 810, 'learning_rate': 0.130899446034834, 'min_data_in_leaf': 11, 'bagging_fraction': 0.8844112873545003, 'feature_fraction': 0.6659941424317043}. Best is trial 30 with value: 0.7365617211646451.
# [I 2020-12-27 13:13:36,404] Trial 43 finished with value: 0.732895150040968 and parameters: {'num_leaves': 28, 'n_estimators': 114, 'max_depth': 7, 'min_child_samples': 1196, 'learning_rate': 0.20081862458521307, 'min_data_in_leaf': 28, 'bagging_fraction': 0.345924596716604, 'feature_fraction': 0.6124362890104741}. Best is trial 30 with value: 0.7365617211646451.
# [I 2020-12-27 13:13:37,032] Trial 44 finished with value: 0.7355987710243268 and parameters: {'num_leaves': 30, 'n_estimators': 99, 'max_depth': 5, 'min_child_samples': 698, 'learning_rate': 0.041318778571366364, 'min_data_in_leaf': 20, 'bagging_fraction': 0.472420501751977, 'feature_fraction': 0.5181730763017508}. Best is trial 30 with value: 0.7365617211646451.
# [I 2020-12-27 13:13:37,459] Trial 45 finished with value: 0.7329757158657798 and parameters: {'num_leaves': 26, 'n_estimators': 70, 'max_depth': 6, 'min_child_samples': 967, 'learning_rate': 0.31483766770956245, 'min_data_in_leaf': 23, 'bagging_fraction': 0.6471612319691044, 'feature_fraction': 0.677710993207031}. Best is trial 30 with value: 0.7365617211646451.
# [I 2020-12-27 13:13:37,912] Trial 46 finished with value: 0.730515697843674 and parameters: {'num_leaves': 28, 'n_estimators': 50, 'max_depth': 7, 'min_child_samples': 768, 'learning_rate': 0.004624892914534148, 'min_data_in_leaf': 12, 'bagging_fraction': 0.4218976599202171, 'feature_fraction': 0.5757048194408548}. Best is trial 30 with value: 0.7365617211646451.
# [I 2020-12-27 13:13:38,671] Trial 47 finished with value: 0.7349930104325691 and parameters: {'num_leaves': 23, 'n_estimators': 141, 'max_depth': 8, 'min_child_samples': 851, 'learning_rate': 0.11635682890761646, 'min_data_in_leaf': 5, 'bagging_fraction': 0.8782033921028898, 'feature_fraction': 0.7879496718851134}. Best is trial 30 with value: 0.7365617211646451.
# [I 2020-12-27 13:13:39,404] Trial 48 finished with value: 0.7362436027309828 and parameters: {'num_leaves': 30, 'n_estimators': 119, 'max_depth': 6, 'min_child_samples': 1049, 'learning_rate': 0.05956858330734371, 'min_data_in_leaf': 16, 'bagging_fraction': 0.09861040478508781, 'feature_fraction': 0.6330771106630674}. Best is trial 30 with value: 0.7365617211646451.
# [I 2020-12-27 13:13:40,554] Trial 49 finished with value: 0.7362058441568534 and parameters: {'num_leaves': 25, 'n_estimators': 155, 'max_depth': 5, 'min_child_samples': 1142, 'learning_rate': 0.049584505700134285, 'min_data_in_leaf': 14, 'bagging_fraction': 0.09285037781382281, 'feature_fraction': 0.47545309183555473}. Best is trial 30 with value: 0.7365617211646451.
# [I 2020-12-27 13:13:41,516] Trial 50 finished with value: 0.7345264367298645 and parameters: {'num_leaves': 31, 'n_estimators': 121, 'max_depth': 7, 'min_child_samples': 1020, 'learning_rate': 0.15991315679431856, 'min_data_in_leaf': 16, 'bagging_fraction': 0.2406573409732358, 'feature_fraction': 0.828507923682877}. Best is trial 30 with value: 0.7365617211646451.
# [I 2020-12-27 13:13:42,652] Trial 51 finished with value: 0.7363044804442651 and parameters: {'num_leaves': 26, 'n_estimators': 157, 'max_depth': 5, 'min_child_samples': 1139, 'learning_rate': 0.04982462697396211, 'min_data_in_leaf': 11, 'bagging_fraction': 0.1136444622367846, 'feature_fraction': 0.499696885191687}. Best is trial 30 with value: 0.7365617211646451.
# [I 2020-12-27 13:13:44,881] Trial 52 finished with value: 0.7363654963197335 and parameters: {'num_leaves': 29, 'n_estimators': 179, 'max_depth': 5, 'min_child_samples': 1063, 'learning_rate': 0.03854889873498377, 'min_data_in_leaf': 10, 'bagging_fraction': 0.00957390410319317, 'feature_fraction': 0.5432238031045178}. Best is trial 30 with value: 0.7365617211646451.
# [I 2020-12-27 13:13:46,224] Trial 53 finished with value: 0.736231743810003 and parameters: {'num_leaves': 27, 'n_estimators': 183, 'max_depth': 5, 'min_child_samples': 1065, 'learning_rate': 0.0374794870505838, 'min_data_in_leaf': 10, 'bagging_fraction': 0.009674960528582395, 'feature_fraction': 0.5364409939725587}. Best is trial 30 with value: 0.7365617211646451.
# [I 2020-12-27 13:13:47,691] Trial 54 finished with value: 0.7297347533566072 and parameters: {'num_leaves': 27, 'n_estimators': 213, 'max_depth': 5, 'min_child_samples': 1071, 'learning_rate': 0.0009709006484942481, 'min_data_in_leaf': 9, 'bagging_fraction': 0.0005801945268884279, 'feature_fraction': 0.5470547865482859}. Best is trial 30 with value: 0.7365617211646451.
# [I 2020-12-27 13:13:48,811] Trial 55 finished with value: 0.735956248410775 and parameters: {'num_leaves': 22, 'n_estimators': 180, 'max_depth': 5, 'min_child_samples': 1147, 'learning_rate': 0.03417448197571709, 'min_data_in_leaf': 11, 'bagging_fraction': 0.09038366559212382, 'feature_fraction': 0.46238745459240305}. Best is trial 30 with value: 0.7365617211646451.
# [I 2020-12-27 13:13:49,904] Trial 56 finished with value: 0.734062896838498 and parameters: {'num_leaves': 24, 'n_estimators': 248, 'max_depth': 5, 'min_child_samples': 1082, 'learning_rate': 0.148294605809632, 'min_data_in_leaf': 5, 'bagging_fraction': 0.02514291569027116, 'feature_fraction': 0.5153458942095173}. Best is trial 30 with value: 0.7365617211646451.
# [I 2020-12-27 13:13:50,880] Trial 57 finished with value: 0.7358999012658476 and parameters: {'num_leaves': 26, 'n_estimators': 195, 'max_depth': 5, 'min_child_samples': 1192, 'learning_rate': 0.046214200929329805, 'min_data_in_leaf': 10, 'bagging_fraction': 0.1267395125154014, 'feature_fraction': 0.3542284071919951}. Best is trial 30 with value: 0.7365617211646451.
# [I 2020-12-27 13:13:51,847] Trial 58 finished with value: 0.7255624395504454 and parameters: {'num_leaves': 28, 'n_estimators': 171, 'max_depth': 5, 'min_child_samples': 1023, 'learning_rate': 0.0007913073029740397, 'min_data_in_leaf': 16, 'bagging_fraction': 0.00034919083686962143, 'feature_fraction': 0.40734037666590467}. Best is trial 30 with value: 0.7365617211646451.
# [I 2020-12-27 13:13:52,640] Trial 59 finished with value: 0.7301172323419947 and parameters: {'num_leaves': 29, 'n_estimators': 183, 'max_depth': 8, 'min_child_samples': 1115, 'learning_rate': 0.2182061393680363, 'min_data_in_leaf': 5, 'bagging_fraction': 0.052956848895100495, 'feature_fraction': 0.5410274548334061}. Best is trial 30 with value: 0.7365617211646451.
# [I 2020-12-27 13:13:53,604] Trial 60 finished with value: 0.7329114359086629 and parameters: {'num_leaves': 26, 'n_estimators': 220, 'max_depth': 5, 'min_child_samples': 914, 'learning_rate': 0.16741065744273975, 'min_data_in_leaf': 8, 'bagging_fraction': 0.07423457576166763, 'feature_fraction': 0.5024946352226756}. Best is trial 30 with value: 0.7365617211646451.
# [I 2020-12-27 13:13:54,581] Trial 61 finished with value: 0.7366415270974329 and parameters: {'num_leaves': 27, 'n_estimators': 136, 'max_depth': 6, 'min_child_samples': 1056, 'learning_rate': 0.06416560327486993, 'min_data_in_leaf': 18, 'bagging_fraction': 0.11436344106341374, 'feature_fraction': 0.594602551817492}. Best is trial 61 with value: 0.7366415270974329.
# [I 2020-12-27 13:13:55,973] Trial 62 finished with value: 0.735938488813094 and parameters: {'num_leaves': 24, 'n_estimators': 135, 'max_depth': 5, 'min_child_samples': 1162, 'learning_rate': 0.11356591612980353, 'min_data_in_leaf': 14, 'bagging_fraction': 0.11957617698307421, 'feature_fraction': 0.5882979100467662}. Best is trial 61 with value: 0.7366415270974329.
# [I 2020-12-27 13:13:56,884] Trial 63 finished with value: 0.7364744832575926 and parameters: {'num_leaves': 27, 'n_estimators': 163, 'max_depth': 6, 'min_child_samples': 1052, 'learning_rate': 0.053979708235731824, 'min_data_in_leaf': 18, 'bagging_fraction': 0.023218125248743452, 'feature_fraction': 0.7108995299724025}. Best is trial 61 with value: 0.7366415270974329.
# [I 2020-12-27 13:13:57,691] Trial 64 finished with value: 0.6910412472268979 and parameters: {'num_leaves': 29, 'n_estimators': 164, 'max_depth': 6, 'min_child_samples': 994, 'learning_rate': 0.9227605962682138, 'min_data_in_leaf': 27, 'bagging_fraction': 0.03801405539601387, 'feature_fraction': 0.7318032913265383}. Best is trial 61 with value: 0.7366415270974329.
# [I 2020-12-27 13:13:58,558] Trial 65 finished with value: 0.736131104170892 and parameters: {'num_leaves': 28, 'n_estimators': 154, 'max_depth': 6, 'min_child_samples': 1119, 'learning_rate': 0.0681932211127915, 'min_data_in_leaf': 19, 'bagging_fraction': 0.29847956712624857, 'feature_fraction': 0.6916500261476239}. Best is trial 61 with value: 0.7366415270974329.
# [I 2020-12-27 13:13:59,290] Trial 66 finished with value: 0.7356234675151053 and parameters: {'num_leaves': 25, 'n_estimators': 140, 'max_depth': 6, 'min_child_samples': 957, 'learning_rate': 0.12207595593231942, 'min_data_in_leaf': 18, 'bagging_fraction': 0.10236746972775412, 'feature_fraction': 0.6105215631631198}. Best is trial 61 with value: 0.7366415270974329.
# [I 2020-12-27 13:14:00,144] Trial 67 finished with value: 0.735942311300245 and parameters: {'num_leaves': 30, 'n_estimators': 149, 'max_depth': 6, 'min_child_samples': 1039, 'learning_rate': 0.06092109153392787, 'min_data_in_leaf': 69, 'bagging_fraction': 0.14097007266735148, 'feature_fraction': 0.6518056079221235}. Best is trial 61 with value: 0.7366415270974329.
# [I 2020-12-27 13:14:01,133] Trial 68 finished with value: 0.7358575718260592 and parameters: {'num_leaves': 24, 'n_estimators': 174, 'max_depth': 6, 'min_child_samples': 1102, 'learning_rate': 0.027181385998183483, 'min_data_in_leaf': 34, 'bagging_fraction': 0.24951171418006723, 'feature_fraction': 0.5725843110331008}. Best is trial 61 with value: 0.7366415270974329.
# [I 2020-12-27 13:14:02,037] Trial 69 finished with value: 0.7350349196290414 and parameters: {'num_leaves': 26, 'n_estimators': 203, 'max_depth': 6, 'min_child_samples': 999, 'learning_rate': 0.09964647642431751, 'min_data_in_leaf': 14, 'bagging_fraction': 0.1548361222470319, 'feature_fraction': 0.45662938311271917}. Best is trial 61 with value: 0.7366415270974329.
# {'num_leaves': 27, 'n_estimators': 136, 'max_depth': 6, 'min_child_samples': 1056, 'learning_rate': 0.06416560327486993, 'min_data_in_leaf': 18, 'bagging_fraction': 0.11436344106341374, 'feature_fraction': 0.594602551817492}

# %%
model = lgb.LGBMClassifier(**params)

model.fit(train_df[features], train_df[target])
print('LGB score: ', roc_auc_score(test_df[target].values, model.predict_proba(test_df[features])[:,1]))
# Out:
# LGB score:  0.7363509777766699

# %% [markdown]
# # Submit

# %%
test_df = pd.read_csv("/kaggle/input/riiid-test-answer-prediction/example_test.csv")

print(test_df.dtypes)
print(test_df.shape)
test_df.head()
# Out:
# row_id                              int64
# group_num                           int64
# timestamp                           int64
# user_id                             int64
# content_id                          int64
# content_type_id                     int64
# task_container_id                   int64
# prior_question_elapsed_time       float64
# prior_question_had_explanation     object
# prior_group_answers_correct        object
# prior_group_responses              object
# dtype: object
# (104, 11)
#    row_id  group_num    timestamp     user_id  content_id  content_type_id  \
# 0       0          0            0   275030867        5729                0
# 1       1          0  13309898705   554169193       12010                0
# 2       2          0   4213672059  1720860329         457                0
# 3       3          0  62798072960   288641214       13262                0
# 4       4          0  10585422061  1728340777        6119                0
#
#    task_container_id  prior_question_elapsed_time  \
# 0                  0                          NaN
# 1               4427                      19000.0
# 2                240                      17000.0
# 3                266                      23000.0
# 4                162                      72400.0
#
#   prior_question_had_explanation prior_group_answers_correct  \
# 0                            NaN                          []
# 1                           True                         NaN
# 2                           True                         NaN
# 3                           True                         NaN
# 4                           True                         NaN
#
#   prior_group_responses
# 0                    []
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
for (test_df, sample_prediction_df) in iter_test:
    test_df['prior_question_had_explanation'].fillna(False, inplace=True)
    test_df['user_correctness'] = cum['cumsum'] / cum['cumcount']
    test_df = test_df.merge(user_answers_df, how='left', on='user_id')
    test_df = test_df.merge(content_answers_df, how='left', on='content_id')
    test_df['prior_question_had_explanation'] = test_df['prior_question_had_explanation'].astype('int')
    test_df.fillna(value = 0.5, inplace = True)

    test_df['answered_correctly'] = model.predict_proba(test_df[features])[:,1]
    env.predict(test_df.loc[test_df['content_type_id'] == 0, ['row_id', 'answered_correctly']])
