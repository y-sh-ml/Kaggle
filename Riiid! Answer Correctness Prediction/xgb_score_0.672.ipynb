# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

import riiideducation
env = riiideducation.make_env()
iter_test = env.iter_test()
# Out:
# /kaggle/input/riiid-test-answer-prediction/example_sample_submission.csv
# /kaggle/input/riiid-test-answer-prediction/example_test.csv
# /kaggle/input/riiid-test-answer-prediction/questions.csv
# /kaggle/input/riiid-test-answer-prediction/train.csv
# /kaggle/input/riiid-test-answer-prediction/lectures.csv
# /kaggle/input/riiid-test-answer-prediction/riiideducation/competition.cpython-37m-x86_64-linux-gnu.so
# /kaggle/input/riiid-test-answer-prediction/riiideducation/__init__.py

# %%
import optuna
import lightgbm as lgb
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# .datatable .frame thead tr.colnames {  background-image: url('data:image/png;base64,...');  background-repeat: repeat-x;  background-size: 14px;  height: 28px;}
# </style>

# %%
used_data_types_dict = {
    'user_id': 'int32',
    'content_id': 'int16',
    'content_type_id':'int8',
    'answered_correctly': 'int8',
    'prior_question_elapsed_time': 'float16',
    'prior_question_had_explanation': 'boolean'
}

target = 'answered_correctly'

train_df = pd.read_csv('/kaggle/input/riiid-test-answer-prediction/train.csv',
                       usecols = used_data_types_dict.keys(),
                       dtype=used_data_types_dict, nrows=10**6)

train_df = train_df[train_df['answered_correctly'] != -1].reset_index(drop=True)

print(train_df.dtypes)
print(train_df.shape)
train_df.head(10)
# Out:
# user_id                             int32
# content_id                          int16
# content_type_id                      int8
# answered_correctly                   int8
# prior_question_elapsed_time       float16
# prior_question_had_explanation    boolean
# dtype: object
# (980093, 6)
#    user_id  content_id  content_type_id  answered_correctly  \
# 0      115        5692                0                   1
# 1      115        5716                0                   1
# 2      115         128                0                   1
# 3      115        7860                0                   1
# 4      115        7922                0                   1
# 5      115         156                0                   1
# 6      115          51                0                   1
# 7      115          50                0                   1
# 8      115        7896                0                   1
# 9      115        7863                0                   1
#
#    prior_question_elapsed_time  prior_question_had_explanation
# 0                          NaN                            <NA>
# 1                      36992.0                           False
# 2                      55008.0                           False
# 3                      19008.0                           False
# 4                      11000.0                           False
# 5                       5000.0                           False
# 6                      16992.0                           False
# 7                      16992.0                           False
# 8                      16000.0                           False
# 9                      16000.0                           False

# %% [markdown]
# row_id：行に対するid<br>
# timestamp：ユーザーが新規登録してから、該当イベント完了までにかかる時間<br>
# user_id：ユーザーのid<br>
# content_id：コンテンツのid<br>
# content_type_id：イベントが問題が投げていれば0、ユーザーがそのイベントを見ていれば1<br>
# task_container_id：問題または講義のバッチのid<br>
# user_answer：問題に対するユーザの解答した数字（講義の場合は、-1をnullとする）<br>
# answered_correctly：ユーザが正しく応答したもの（講義の場合は、-1をnullとする）<br>
# prior_question_elapsed_time：前の問題の回答にかかった時間<br>
# prior_question_had_explanation：前の問題の解説を見たかどうか

# %%
train_df['prior_question_had_explanation'].fillna(False, inplace=True)

print(train_df.isnull().sum())
train_df.head()
# Out:
# user_id                              0
# content_id                           0
# content_type_id                      0
# answered_correctly                   0
# prior_question_elapsed_time       3816
# prior_question_had_explanation       0
# dtype: int64
#    user_id  content_id  content_type_id  answered_correctly  \
# 0      115        5692                0                   1
# 1      115        5716                0                   1
# 2      115         128                0                   1
# 3      115        7860                0                   1
# 4      115        7922                0                   1
#
#    prior_question_elapsed_time  prior_question_had_explanation
# 0                          NaN                           False
# 1                      36992.0                           False
# 2                      55008.0                           False
# 3                      19008.0                           False
# 4                      11000.0                           False

# %%
train_df['lag'] = train_df.groupby('user_id')[target].shift()

print(train_df.shape)
train_df.head()
# Out:
# (980093, 7)
#    user_id  content_id  content_type_id  answered_correctly  \
# 0      115        5692                0                   1
# 1      115        5716                0                   1
# 2      115         128                0                   1
# 3      115        7860                0                   1
# 4      115        7922                0                   1
#
#    prior_question_elapsed_time  prior_question_had_explanation  lag
# 0                          NaN                           False  NaN
# 1                      36992.0                           False  1.0
# 2                      55008.0                           False  1.0
# 3                      19008.0                           False  1.0
# 4                      11000.0                           False  1.0

# %%
cum = train_df.groupby('user_id')['lag'].agg(['cumsum', 'cumcount'])

print(cum.shape)
cum.head()
# Out:
# (980093, 2)
#    cumsum  cumcount
# 0     NaN         0
# 1     1.0         1
# 2     2.0         2
# 3     3.0         3
# 4     4.0         4

# %%
train_df['user_correctness'] = cum['cumsum'] / cum['cumcount']
train_df.drop(columns=['lag'], inplace=True)

print(train_df.isnull().sum())
print(train_df.shape)
train_df.head()
# Out:
# user_id                              0
# content_id                           0
# content_type_id                      0
# answered_correctly                   0
# prior_question_elapsed_time       3816
# prior_question_had_explanation       0
# user_correctness                  3824
# dtype: int64
# (980093, 7)
#    user_id  content_id  content_type_id  answered_correctly  \
# 0      115        5692                0                   1
# 1      115        5716                0                   1
# 2      115         128                0                   1
# 3      115        7860                0                   1
# 4      115        7922                0                   1
#
#    prior_question_elapsed_time  prior_question_had_explanation  \
# 0                          NaN                           False
# 1                      36992.0                           False
# 2                      55008.0                           False
# 3                      19008.0                           False
# 4                      11000.0                           False
#
#    user_correctness
# 0               NaN
# 1               1.0
# 2               1.0
# 3               1.0
# 4               1.0

# %%
questions_df = pd.read_csv('../input/riiid-test-answer-prediction/questions.csv', usecols=[0, 3],
                           dtype={'question_id': 'int16', 'part': 'int8'})

questions_df.columns = ['question_id', 'question_part']

print(questions_df.shape)
questions_df.head(10)
# Out:
# (13523, 2)
#    question_id  question_part
# 0            0              1
# 1            1              1
# 2            2              1
# 3            3              1
# 4            4              1
# 5            5              1
# 6            6              1
# 7            7              1
# 8            8              1
# 9            9              1

# %% [markdown]
# question_id：コンテンツが問題ならば0、train・testデータの外部キー、小問番号<br>
# bundle_id：問題が一緒に出される番号、大問番号<br>
# correct_answer：問題へ解答した番号、train.csvの「user_answer」と照らし合わせて、正解したかどうかが分かるもの<br>
# part：TOEICにおける問題の各セクション<br>
# tags：質問をまとめるタグ

# %%
train_df = pd.merge(train_df, questions_df, left_on='content_id', right_on='question_id', how='left')
train_df.drop(columns=['question_id'], inplace=True)

print(train_df.isnull().sum())
print(train_df.shape)
train_df.head()
# Out:
# user_id                              0
# content_id                           0
# content_type_id                      0
# answered_correctly                   0
# prior_question_elapsed_time       3816
# prior_question_had_explanation       0
# user_correctness                  3824
# question_part                        0
# dtype: int64
# (980093, 8)
#    user_id  content_id  content_type_id  answered_correctly  \
# 0      115        5692                0                   1
# 1      115        5716                0                   1
# 2      115         128                0                   1
# 3      115        7860                0                   1
# 4      115        7922                0                   1
#
#    prior_question_elapsed_time  prior_question_had_explanation  \
# 0                          NaN                           False
# 1                      36992.0                           False
# 2                      55008.0                           False
# 3                      19008.0                           False
# 4                      11000.0                           False
#
#    user_correctness  question_part
# 0               NaN              5
# 1               1.0              5
# 2               1.0              1
# 3               1.0              1
# 4               1.0              1

# %%
lectures_df = pd.read_csv("/kaggle/input/riiid-test-answer-prediction/lectures.csv")

print(lectures_df.dtypes)
print(lectures_df.shape)
lectures_df.head(10)
# Out:
# lecture_id     int64
# tag            int64
# part           int64
# type_of       object
# dtype: object
# (418, 4)
#    lecture_id  tag  part           type_of
# 0          89  159     5           concept
# 1         100   70     1           concept
# 2         185   45     6           concept
# 3         192   79     5  solving question
# 4         317  156     5  solving question
# 5         335  114     2           concept
# 6         484  179     5           concept
# 7         641  134     6  solving question
# 8         761   93     1           concept
# 9         814   80     5  solving question

# %% [markdown]
# lecture_id：コンテンツタイプが講義なら1、train・testデータにおけるcontent_idの外部キー<br>
# tag：講義をまとめるタグ<br>
# part：講義のカテゴリーコード（識別するもの）<br>
# type_of：講義の目的の説明

# %%
lectures_df['type_of'] = lectures_df['type_of'].replace('solving question', 'solving_question')
lectures_df = pd.get_dummies(lectures_df, columns=['part', 'type_of'])

part_lectures_columns = [column for column in lectures_df.columns if column.startswith('part')]
types_of_lectures_columns = [column for column in lectures_df.columns if column.startswith('type_of_')]

print(part_lectures_columns)
print(types_of_lectures_columns)
lectures_df.head()
# Out:
# ['part_1', 'part_2', 'part_3', 'part_4', 'part_5', 'part_6', 'part_7']
# ['type_of_concept', 'type_of_intention', 'type_of_solving_question', 'type_of_starter']
#    lecture_id  tag  part_1  part_2  part_3  part_4  part_5  part_6  part_7  \
# 0          89  159       0       0       0       0       1       0       0
# 1         100   70       1       0       0       0       0       0       0
# 2         185   45       0       0       0       0       0       1       0
# 3         192   79       0       0       0       0       1       0       0
# 4         317  156       0       0       0       0       1       0       0
#
#    type_of_concept  type_of_intention  type_of_solving_question  \
# 0                1                  0                         0
# 1                1                  0                         0
# 2                1                  0                         0
# 3                0                  0                         1
# 4                0                  0                         1
#
#    type_of_starter
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0

# %% [markdown]
# 下記のように2分割するまでに、train_df全体としての特徴量を増やしておきたい。

# %%
features_df = train_df.iloc[:int(9/10 * len(train_df))]
train_df = train_df.iloc[int(9/10 * len(train_df)):]

print(features_df.shape)
print(train_df.shape)
# Out:
# (882083, 8)
# (98010, 8)

# %%
grouped_by_user_df = features_df.groupby('user_id')

user_answers_df = grouped_by_user_df.agg({'answered_correctly': ['mean', 'count','std','median','skew']}).copy()

user_answers_df.columns = ['mean_user_accuracy', 
                           'questions_answered', 
                           'std_user_accuracy', 
                           'median_user_accuracy', 
                           'skew_user_accuracy']

print(user_answers_df.dtypes)
print(user_answers_df.shape)
user_answers_df.head()
# Out:
# mean_user_accuracy      float64
# questions_answered        int64
# std_user_accuracy       float64
# median_user_accuracy    float64
# skew_user_accuracy      float64
# dtype: object
# (3458, 5)
#          mean_user_accuracy  questions_answered  std_user_accuracy  \
# user_id
# 115                0.695652                  46           0.465215
# 124                0.233333                  30           0.430183
# 2746               0.578947                  19           0.507257
# 5382               0.672000                 125           0.471374
# 8623               0.642202                 109           0.481566
#
#          median_user_accuracy  skew_user_accuracy
# user_id
# 115                       1.0           -0.879359
# 124                       0.0            1.328338
# 2746                      1.0           -0.347892
# 5382                      1.0           -0.741648
# 8623                      1.0           -0.601619

# %%
grouped_by_content_df = features_df.groupby('content_id')

content_answers_df = grouped_by_content_df.agg({'answered_correctly': ['mean', 'count','std','median','skew']}).copy()

content_answers_df.columns = ['mean_accuracy', 
                              'question_asked', 
                              'std_accuracy', 
                              'median_accuracy', 
                              'skew_accuracy']

print(content_answers_df.dtypes)
print(content_answers_df.shape)
content_answers_df.head()
# Out:
# mean_accuracy      float64
# question_asked       int64
# std_accuracy       float64
# median_accuracy    float64
# skew_accuracy      float64
# dtype: object
# (12986, 5)
#             mean_accuracy  question_asked  std_accuracy  median_accuracy  \
# content_id
# 0                0.857143              70      0.352454              1.0
# 1                0.918367              49      0.276642              1.0
# 2                0.555276             398      0.497561              1.0
# 3                0.784091             176      0.412625              1.0
# 4                0.600760             263      0.490676              1.0
#
#             skew_accuracy
# content_id
# 0               -2.086215
# 1               -3.153323
# 2               -0.223312
# 3               -1.392819
# 4               -0.413848

# %%
del features_df
del grouped_by_user_df
del grouped_by_content_df

# %%
train_df = train_df.merge(user_answers_df, how='left', on='user_id')
train_df = train_df.merge(content_answers_df, how='left', on='content_id')

print(train_df.dtypes)
print(train_df.shape)
train_df.head()
# Out:
# user_id                             int32
# content_id                          int16
# content_type_id                      int8
# answered_correctly                   int8
# prior_question_elapsed_time       float16
# prior_question_had_explanation    boolean
# user_correctness                  float64
# question_part                        int8
# mean_user_accuracy                float64
# questions_answered                float64
# std_user_accuracy                 float64
# median_user_accuracy              float64
# skew_user_accuracy                float64
# mean_accuracy                     float64
# question_asked                    float64
# std_accuracy                      float64
# median_accuracy                   float64
# skew_accuracy                     float64
# dtype: object
# (98010, 18)
#     user_id  content_id  content_type_id  answered_correctly  \
# 0  18789336        7796                0                   0
# 1  18789336        7798                0                   0
# 2  18789336        2908                0                   0
# 3  18789336        2909                0                   0
# 4  18789336        2907                0                   0
#
#    prior_question_elapsed_time  prior_question_had_explanation  \
# 0                       1400.0                            True
# 1                       1400.0                            True
# 2                       1600.0                            True
# 3                       1600.0                            True
# 4                       1600.0                            True
#
#    user_correctness  question_part  mean_user_accuracy  questions_answered  \
# 0          0.310865              7            0.310865              2255.0
# 1          0.310727              7            0.310865              2255.0
# 2          0.310589              4            0.310865              2255.0
# 3          0.310452              4            0.310865              2255.0
# 4          0.310314              4            0.310865              2255.0
#
#    std_user_accuracy  median_user_accuracy  skew_user_accuracy  mean_accuracy  \
# 0            0.46295                   0.0            0.817812       0.962963
# 1            0.46295                   0.0            0.817812       0.870370
# 2            0.46295                   0.0            0.817812       0.676768
# 3            0.46295                   0.0            0.817812       0.616162
# 4            0.46295                   0.0            0.817812       0.454545
#
#    question_asked  std_accuracy  median_accuracy  skew_accuracy
# 0            54.0      0.190626              1.0      -5.044113
# 1            54.0      0.339050              1.0      -2.268786
# 2            99.0      0.470091              1.0      -0.767564
# 3            99.0      0.488794              1.0      -0.485099
# 4            99.0      0.500464              0.0       0.185395

# %%
features = [
    'mean_user_accuracy', 
    'questions_answered',
    'std_user_accuracy', 
    'median_user_accuracy',
    'skew_user_accuracy',
    'mean_accuracy', 
    'question_asked',
    'std_accuracy', 
    'median_accuracy',
    'prior_question_elapsed_time', 
    'prior_question_had_explanation',
    'user_correctness',
    'skew_accuracy'
]

target = 'answered_correctly'

print(train_df.isnull().sum())
# Out:
# user_id                               0
# content_id                            0
# content_type_id                       0
# answered_correctly                    0
# prior_question_elapsed_time         366
# prior_question_had_explanation        0
# user_correctness                    366
# question_part                         0
# mean_user_accuracy                97881
# questions_answered                97881
# std_user_accuracy                 97881
# median_user_accuracy              97881
# skew_user_accuracy                97881
# mean_accuracy                       100
# question_asked                      100
# std_accuracy                        231
# median_accuracy                     100
# skew_accuracy                       325
# dtype: int64

# %%
train_df = train_df.fillna(value=0.5)
train_df.isnull().sum()
# Out:
# user_id                           0
# content_id                        0
# content_type_id                   0
# answered_correctly                0
# prior_question_elapsed_time       0
# prior_question_had_explanation    0
# user_correctness                  0
# question_part                     0
# mean_user_accuracy                0
# questions_answered                0
# std_user_accuracy                 0
# median_user_accuracy              0
# skew_user_accuracy                0
# mean_accuracy                     0
# question_asked                    0
# std_accuracy                      0
# median_accuracy                   0
# skew_accuracy                     0
# dtype: int64

# %%
train_df['prior_question_had_explanation'] = train_df['prior_question_had_explanation'].astype('int')

# %% [markdown]
# # Modeling

# %%
train_df, test_df = train_test_split(train_df, random_state=666, test_size=0.2)

print(train_df.dtypes)
print(train_df.shape)
print(test_df.shape)
train_df.head()
# Out:
# user_id                             int32
# content_id                          int16
# content_type_id                      int8
# answered_correctly                   int8
# prior_question_elapsed_time       float16
# prior_question_had_explanation      int64
# user_correctness                  float64
# question_part                        int8
# mean_user_accuracy                float64
# questions_answered                float64
# std_user_accuracy                 float64
# median_user_accuracy              float64
# skew_user_accuracy                float64
# mean_accuracy                     float64
# question_asked                    float64
# std_accuracy                      float64
# median_accuracy                   float64
# skew_accuracy                     float64
# dtype: object
# (78408, 18)
# (19602, 18)
#         user_id  content_id  content_type_id  answered_correctly  \
# 1273   18802864       10940                0                   1
# 5034   18824449         350                0                   1
# 37526  19492810        8742                0                   1
# 29573  19444654        5810                0                   0
# 31622  19489973        8460                0                   0
#
#        prior_question_elapsed_time  prior_question_had_explanation  \
# 1273                       26336.0                               1
# 5034                       16992.0                               1
# 37526                      15000.0                               1
# 29573                       7000.0                               1
# 31622                      20992.0                               1
#
#        user_correctness  question_part  mean_user_accuracy  \
# 1273           0.470588              6                 0.5
# 5034           0.666667              2                 0.5
# 37526          0.689655              5                 0.5
# 29573          0.573070              5                 0.5
# 31622          0.667297              5                 0.5
#
#        questions_answered  std_user_accuracy  median_user_accuracy  \
# 1273                  0.5                0.5                   0.5
# 5034                  0.5                0.5                   0.5
# 37526                 0.5                0.5                   0.5
# 29573                 0.5                0.5                   0.5
# 31622                 0.5                0.5                   0.5
#
#        skew_user_accuracy  mean_accuracy  question_asked  std_accuracy  \
# 1273                  0.5       0.833333            42.0      0.377195
# 5034                  0.5       0.733813           139.0      0.443562
# 37526                 0.5       0.763636            55.0      0.428764
# 29573                 0.5       0.428571            21.0      0.507093
# 31622                 0.5       0.710227           176.0      0.454951
#
#        median_accuracy  skew_accuracy
# 1273               1.0      -1.855802
# 5034               1.0      -1.069643
# 37526              1.0      -1.276157
# 29573              0.0       0.311373
# 31622              1.0      -0.934798

# %%
def create_model(trial):
    booster = 'gbtree'
    n_estimators = trial.suggest_int("n_estimators", 50, 3000)
    max_depth = trial.suggest_int('max_depth', 3, 8)
    min_child_weight = trial.suggest_int('min_child_weight', 0, 2)
    learning_rate = trial.suggest_uniform('learning_rate', 0.0001, 0.99)
    colsample_bytree = 1,
    subsample = 1
    
    model = xgb.XGBClassifier(
        booster = 'gbtree',
        n_estimators = n_estimators, 
        max_depth=max_depth, 
        min_child_weight = min_child_weight, 
        learning_rate=learning_rate,
        colsample_bytree = 1,
        subsample = 1,
        random_state=666
    )
    return model

# %%
def objective(trial):
    model = create_model(trial)
    model.fit(train_df[features], train_df[target])
    score = roc_auc_score(
        test_df[target].values, 
        model.predict_proba(test_df[features])[:,1]
    )
    return score

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=70)
params = study.best_params

print(params)
# Out:
# [I 2020-12-28 00:16:26,336] A new study created in memory with name: no-name-bc8b5c10-dec5-4537-ab1f-7e1721fc47ad
# [I 2020-12-28 00:17:28,557] Trial 0 finished with value: 0.6710996080856886 and parameters: {'n_estimators': 1452, 'max_depth': 6, 'min_child_weight': 0, 'learning_rate': 0.5175211647825423}. Best is trial 0 with value: 0.6710996080856886.
# [I 2020-12-28 00:19:06,148] Trial 1 finished with value: 0.6620231065894209 and parameters: {'n_estimators': 1701, 'max_depth': 8, 'min_child_weight': 0, 'learning_rate': 0.8069406779931929}. Best is trial 0 with value: 0.6710996080856886.
# [I 2020-12-28 00:19:18,797] Trial 2 finished with value: 0.6693821081926203 and parameters: {'n_estimators': 229, 'max_depth': 7, 'min_child_weight': 1, 'learning_rate': 0.9171530145578296}. Best is trial 0 with value: 0.6710996080856886.
# [I 2020-12-28 00:20:19,768] Trial 3 finished with value: 0.664370361240579 and parameters: {'n_estimators': 1684, 'max_depth': 5, 'min_child_weight': 1, 'learning_rate': 0.7245925702827899}. Best is trial 0 with value: 0.6710996080856886.
# [I 2020-12-28 00:20:50,127] Trial 4 finished with value: 0.7209177895270645 and parameters: {'n_estimators': 1314, 'max_depth': 3, 'min_child_weight': 0, 'learning_rate': 0.3106581516390286}. Best is trial 4 with value: 0.7209177895270645.
# [I 2020-12-28 00:21:32,685] Trial 5 finished with value: 0.716686722251233 and parameters: {'n_estimators': 1447, 'max_depth': 4, 'min_child_weight': 1, 'learning_rate': 0.19129642517440082}. Best is trial 4 with value: 0.7209177895270645.
# [I 2020-12-28 00:21:57,453] Trial 6 finished with value: 0.7291714373397931 and parameters: {'n_estimators': 1074, 'max_depth': 3, 'min_child_weight': 0, 'learning_rate': 0.1812611253567104}. Best is trial 6 with value: 0.7291714373397931.
# [I 2020-12-28 00:23:11,495] Trial 7 finished with value: 0.6738062398533546 and parameters: {'n_estimators': 2118, 'max_depth': 5, 'min_child_weight': 2, 'learning_rate': 0.5398167200360984}. Best is trial 6 with value: 0.7291714373397931.
# [I 2020-12-28 00:24:03,044] Trial 8 finished with value: 0.6635853467257777 and parameters: {'n_estimators': 1206, 'max_depth': 6, 'min_child_weight': 2, 'learning_rate': 0.7267054609910928}. Best is trial 6 with value: 0.7291714373397931.
# [I 2020-12-28 00:25:23,969] Trial 9 finished with value: 0.6651886383017012 and parameters: {'n_estimators': 1648, 'max_depth': 7, 'min_child_weight': 1, 'learning_rate': 0.5748190739691027}. Best is trial 6 with value: 0.7291714373397931.
# [I 2020-12-28 00:25:35,726] Trial 10 finished with value: 0.7331832239558954 and parameters: {'n_estimators': 486, 'max_depth': 3, 'min_child_weight': 0, 'learning_rate': 0.006950847397970528}. Best is trial 10 with value: 0.7331832239558954.
# [I 2020-12-28 00:25:46,508] Trial 11 finished with value: 0.7329632812690243 and parameters: {'n_estimators': 457, 'max_depth': 3, 'min_child_weight': 0, 'learning_rate': 0.007050386283070527}. Best is trial 10 with value: 0.7331832239558954.
# [I 2020-12-28 00:25:48,040] Trial 12 finished with value: 0.7278306078635354 and parameters: {'n_estimators': 58, 'max_depth': 3, 'min_child_weight': 0, 'learning_rate': 0.008305712716094548}. Best is trial 10 with value: 0.7331832239558954.
# [I 2020-12-28 00:26:04,873] Trial 13 finished with value: 0.736605512820904 and parameters: {'n_estimators': 572, 'max_depth': 4, 'min_child_weight': 0, 'learning_rate': 0.033416321279485205}. Best is trial 13 with value: 0.736605512820904.
# [I 2020-12-28 00:26:25,132] Trial 14 finished with value: 0.729490511395243 and parameters: {'n_estimators': 673, 'max_depth': 4, 'min_child_weight': 0, 'learning_rate': 0.15732882063980566}. Best is trial 13 with value: 0.736605512820904.
# [I 2020-12-28 00:27:46,149] Trial 15 finished with value: 0.6885350830346103 and parameters: {'n_estimators': 2784, 'max_depth': 4, 'min_child_weight': 1, 'learning_rate': 0.34622606005183465}. Best is trial 13 with value: 0.736605512820904.
# [I 2020-12-28 00:28:09,445] Trial 16 finished with value: 0.7366344750691804 and parameters: {'n_estimators': 806, 'max_depth': 4, 'min_child_weight': 0, 'learning_rate': 0.022672908469859535}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:28:37,064] Trial 17 finished with value: 0.7301917593279192 and parameters: {'n_estimators': 907, 'max_depth': 4, 'min_child_weight': 0, 'learning_rate': 0.11846499602419107}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:29:02,505] Trial 18 finished with value: 0.7064556511759416 and parameters: {'n_estimators': 721, 'max_depth': 5, 'min_child_weight': 1, 'learning_rate': 0.3600057992315696}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:29:06,028] Trial 19 finished with value: 0.7363716963478381 and parameters: {'n_estimators': 118, 'max_depth': 4, 'min_child_weight': 2, 'learning_rate': 0.07865494053552446}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:30:26,265] Trial 20 finished with value: 0.6932468223128938 and parameters: {'n_estimators': 2206, 'max_depth': 5, 'min_child_weight': 0, 'learning_rate': 0.2535156511871431}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:30:28,409] Trial 21 finished with value: 0.7358910128318706 and parameters: {'n_estimators': 67, 'max_depth': 4, 'min_child_weight': 2, 'learning_rate': 0.0765369241863899}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:30:40,441] Trial 22 finished with value: 0.7361094299779362 and parameters: {'n_estimators': 420, 'max_depth': 4, 'min_child_weight': 2, 'learning_rate': 0.05705840208789542}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:31:04,904] Trial 23 finished with value: 0.7068407552428664 and parameters: {'n_estimators': 849, 'max_depth': 4, 'min_child_weight': 2, 'learning_rate': 0.4103911055209308}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:31:14,455] Trial 24 finished with value: 0.7296810888607947 and parameters: {'n_estimators': 258, 'max_depth': 5, 'min_child_weight': 1, 'learning_rate': 0.23438264901684555}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:31:55,088] Trial 25 finished with value: 0.7227069034866321 and parameters: {'n_estimators': 976, 'max_depth': 6, 'min_child_weight': 2, 'learning_rate': 0.09204503041862311}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:32:13,404] Trial 26 finished with value: 0.7366153799036997 and parameters: {'n_estimators': 605, 'max_depth': 4, 'min_child_weight': 0, 'learning_rate': 0.02567650598386477}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:32:29,530] Trial 27 finished with value: 0.7351277588613917 and parameters: {'n_estimators': 640, 'max_depth': 3, 'min_child_weight': 0, 'learning_rate': 0.009552409328612657}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:33:09,988] Trial 28 finished with value: 0.6874695704980902 and parameters: {'n_estimators': 1135, 'max_depth': 5, 'min_child_weight': 0, 'learning_rate': 0.4470723537867702}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:33:26,728] Trial 29 finished with value: 0.7235775325027982 and parameters: {'n_estimators': 537, 'max_depth': 4, 'min_child_weight': 0, 'learning_rate': 0.2647764828811306}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:33:53,646] Trial 30 finished with value: 0.7228390901582527 and parameters: {'n_estimators': 758, 'max_depth': 5, 'min_child_weight': 0, 'learning_rate': 0.17193969286006394}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:34:00,653] Trial 31 finished with value: 0.736583343546781 and parameters: {'n_estimators': 244, 'max_depth': 4, 'min_child_weight': 0, 'learning_rate': 0.06262243055117556}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:34:11,597] Trial 32 finished with value: 0.7294304626550778 and parameters: {'n_estimators': 345, 'max_depth': 4, 'min_child_weight': 0, 'learning_rate': 0.0007810260943369278}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:34:19,633] Trial 33 finished with value: 0.7359146097819174 and parameters: {'n_estimators': 303, 'max_depth': 3, 'min_child_weight': 0, 'learning_rate': 0.12770648152008862}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:34:25,833] Trial 34 finished with value: 0.7365662632465155 and parameters: {'n_estimators': 207, 'max_depth': 4, 'min_child_weight': 0, 'learning_rate': 0.05966825526725866}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:34:46,242] Trial 35 finished with value: 0.7355815525618753 and parameters: {'n_estimators': 566, 'max_depth': 5, 'min_child_weight': 0, 'learning_rate': 0.041250774069436336}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:35:04,717] Trial 36 finished with value: 0.6966922475873285 and parameters: {'n_estimators': 822, 'max_depth': 3, 'min_child_weight': 0, 'learning_rate': 0.9798793244769256}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:35:43,083] Trial 37 finished with value: 0.717835909261754 and parameters: {'n_estimators': 1288, 'max_depth': 4, 'min_child_weight': 0, 'learning_rate': 0.20436681071148716}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:36:31,143] Trial 38 finished with value: 0.7087123577843367 and parameters: {'n_estimators': 985, 'max_depth': 7, 'min_child_weight': 1, 'learning_rate': 0.1288060206824065}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:36:40,761] Trial 39 finished with value: 0.6975713160103666 and parameters: {'n_estimators': 231, 'max_depth': 6, 'min_child_weight': 0, 'learning_rate': 0.5984770885567088}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:37:48,804] Trial 40 finished with value: 0.6926196350687637 and parameters: {'n_estimators': 1896, 'max_depth': 5, 'min_child_weight': 1, 'learning_rate': 0.2887794304140752}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:37:53,985] Trial 41 finished with value: 0.7363504423981987 and parameters: {'n_estimators': 152, 'max_depth': 4, 'min_child_weight': 0, 'learning_rate': 0.046778949565001}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:38:06,465] Trial 42 finished with value: 0.7326134373433623 and parameters: {'n_estimators': 435, 'max_depth': 4, 'min_child_weight': 0, 'learning_rate': 0.13359090331057866}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:38:22,093] Trial 43 finished with value: 0.7365444278643424 and parameters: {'n_estimators': 631, 'max_depth': 3, 'min_child_weight': 0, 'learning_rate': 0.0446165561393963}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:38:33,001] Trial 44 finished with value: 0.7313548949624858 and parameters: {'n_estimators': 359, 'max_depth': 4, 'min_child_weight': 0, 'learning_rate': 0.22125241895224002}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:39:05,631] Trial 45 finished with value: 0.7327614205582685 and parameters: {'n_estimators': 1425, 'max_depth': 3, 'min_child_weight': 0, 'learning_rate': 0.09631200271462777}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:39:07,273] Trial 46 finished with value: 0.7291238001693523 and parameters: {'n_estimators': 53, 'max_depth': 4, 'min_child_weight': 0, 'learning_rate': 0.8208868859788845}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:39:12,436] Trial 47 finished with value: 0.730773266699246 and parameters: {'n_estimators': 191, 'max_depth': 3, 'min_child_weight': 0, 'learning_rate': 0.009146770742576225}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:39:51,797] Trial 48 finished with value: 0.7331137456465239 and parameters: {'n_estimators': 1071, 'max_depth': 5, 'min_child_weight': 0, 'learning_rate': 0.037692068415423705}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:40:22,954] Trial 49 finished with value: 0.7072421969883061 and parameters: {'n_estimators': 535, 'max_depth': 8, 'min_child_weight': 0, 'learning_rate': 0.16414305189459777}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:40:43,871] Trial 50 finished with value: 0.7330416307420997 and parameters: {'n_estimators': 707, 'max_depth': 4, 'min_child_weight': 1, 'learning_rate': 0.09876615771704247}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:40:57,656] Trial 51 finished with value: 0.7363823636199622 and parameters: {'n_estimators': 610, 'max_depth': 3, 'min_child_weight': 0, 'learning_rate': 0.050907092893976685}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:41:08,079] Trial 52 finished with value: 0.725255281983553 and parameters: {'n_estimators': 421, 'max_depth': 3, 'min_child_weight': 0, 'learning_rate': 0.0004855671806058559}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:41:31,311] Trial 53 finished with value: 0.7298430609970508 and parameters: {'n_estimators': 765, 'max_depth': 4, 'min_child_weight': 0, 'learning_rate': 0.14755961894776418}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:41:52,593] Trial 54 finished with value: 0.7354638268657407 and parameters: {'n_estimators': 909, 'max_depth': 3, 'min_child_weight': 0, 'learning_rate': 0.06977858462552058}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:42:01,005] Trial 55 finished with value: 0.7329252578840381 and parameters: {'n_estimators': 291, 'max_depth': 4, 'min_child_weight': 0, 'learning_rate': 0.19498631949330025}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:43:30,768] Trial 56 finished with value: 0.7301892493815371 and parameters: {'n_estimators': 2992, 'max_depth': 4, 'min_child_weight': 0, 'learning_rate': 0.0360699185109762}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:43:44,776] Trial 57 finished with value: 0.7357321320745299 and parameters: {'n_estimators': 619, 'max_depth': 3, 'min_child_weight': 0, 'learning_rate': 0.10070675587496078}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:44:03,825] Trial 58 finished with value: 0.7360438489935661 and parameters: {'n_estimators': 523, 'max_depth': 5, 'min_child_weight': 0, 'learning_rate': 0.027653497911672657}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:44:08,374] Trial 59 finished with value: 0.7365680708684512 and parameters: {'n_estimators': 148, 'max_depth': 4, 'min_child_weight': 0, 'learning_rate': 0.0703293966507257}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:44:16,181] Trial 60 finished with value: 0.7361736178269287 and parameters: {'n_estimators': 232, 'max_depth': 4, 'min_child_weight': 0, 'learning_rate': 0.08858642207709885}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:44:18,811] Trial 61 finished with value: 0.7357821007318623 and parameters: {'n_estimators': 80, 'max_depth': 4, 'min_child_weight': 0, 'learning_rate': 0.06613923090185275}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:44:31,049] Trial 62 finished with value: 0.7325716490388028 and parameters: {'n_estimators': 381, 'max_depth': 4, 'min_child_weight': 0, 'learning_rate': 0.004020657840609253}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:44:36,555] Trial 63 finished with value: 0.7348422812442126 and parameters: {'n_estimators': 159, 'max_depth': 5, 'min_child_weight': 0, 'learning_rate': 0.16032421917302053}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:44:56,601] Trial 64 finished with value: 0.7350497432802661 and parameters: {'n_estimators': 675, 'max_depth': 4, 'min_child_weight': 0, 'learning_rate': 0.06582250391947364}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:45:08,634] Trial 65 finished with value: 0.7324350987448023 and parameters: {'n_estimators': 513, 'max_depth': 3, 'min_child_weight': 0, 'learning_rate': 0.005535707471684401}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:45:34,813] Trial 66 finished with value: 0.7300364650306614 and parameters: {'n_estimators': 852, 'max_depth': 4, 'min_child_weight': 0, 'learning_rate': 0.11457875051113163}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:45:46,437] Trial 67 finished with value: 0.7032425456175558 and parameters: {'n_estimators': 329, 'max_depth': 5, 'min_child_weight': 0, 'learning_rate': 0.6415004825046288}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:46:00,643] Trial 68 finished with value: 0.7365162024810589 and parameters: {'n_estimators': 467, 'max_depth': 4, 'min_child_weight': 0, 'learning_rate': 0.026034231739599546}. Best is trial 16 with value: 0.7366344750691804.
# [I 2020-12-28 00:46:57,985] Trial 69 finished with value: 0.7210020857309031 and parameters: {'n_estimators': 2441, 'max_depth': 3, 'min_child_weight': 1, 'learning_rate': 0.18241630925357752}. Best is trial 16 with value: 0.7366344750691804.
# {'n_estimators': 806, 'max_depth': 4, 'min_child_weight': 0, 'learning_rate': 0.022672908469859535}

# %%
# %%time

model = xgb.XGBClassifier(**params)

model.fit(train_df[features], train_df[target])
print('XGB score: ', roc_auc_score(test_df[target].values, model.predict_proba(test_df[features])[:,1]))
# Out:
# XGB score:  0.7366344750691804
# CPU times: user 1min 35s, sys: 862 ms, total: 1min 36s
# Wall time: 25.2 s

# %% [markdown]
# # Submit

# %%
test_df = pd.read_csv("/kaggle/input/riiid-test-answer-prediction/example_test.csv")

print(test_df.dtypes)
print(test_df.shape)
test_df.head()
# Out:
# row_id                              int64
# group_num                           int64
# timestamp                           int64
# user_id                             int64
# content_id                          int64
# content_type_id                     int64
# task_container_id                   int64
# prior_question_elapsed_time       float64
# prior_question_had_explanation     object
# prior_group_answers_correct        object
# prior_group_responses              object
# dtype: object
# (104, 11)
#    row_id  group_num    timestamp     user_id  content_id  content_type_id  \
# 0       0          0            0   275030867        5729                0
# 1       1          0  13309898705   554169193       12010                0
# 2       2          0   4213672059  1720860329         457                0
# 3       3          0  62798072960   288641214       13262                0
# 4       4          0  10585422061  1728340777        6119                0
#
#    task_container_id  prior_question_elapsed_time  \
# 0                  0                          NaN
# 1               4427                      19000.0
# 2                240                      17000.0
# 3                266                      23000.0
# 4                162                      72400.0
#
#   prior_question_had_explanation prior_group_answers_correct  \
# 0                            NaN                          []
# 1                           True                         NaN
# 2                           True                         NaN
# 3                           True                         NaN
# 4                           True                         NaN
#
#   prior_group_responses
# 0                    []
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
for (test_df, sample_prediction_df) in iter_test:
    test_df['prior_question_had_explanation'].fillna(False, inplace=True)
    test_df['user_correctness'] = cum['cumsum'] / cum['cumcount']
    test_df = test_df.merge(user_answers_df, how='left', on='user_id')
    test_df = test_df.merge(content_answers_df, how='left', on='content_id')
    test_df['prior_question_had_explanation'] = test_df['prior_question_had_explanation'].astype('int')
    test_df.fillna(value = 0.5, inplace = True)

    test_df['answered_correctly'] = model.predict_proba(test_df[features])[:,1]
    env.predict(test_df.loc[test_df['content_type_id'] == 0, ['row_id', 'answered_correctly']])
