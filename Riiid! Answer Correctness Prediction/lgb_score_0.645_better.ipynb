# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/riiid-test-answer-prediction/example_sample_submission.csv
# /kaggle/input/riiid-test-answer-prediction/example_test.csv
# /kaggle/input/riiid-test-answer-prediction/questions.csv
# /kaggle/input/riiid-test-answer-prediction/train.csv
# /kaggle/input/riiid-test-answer-prediction/lectures.csv
# /kaggle/input/riiid-test-answer-prediction/riiideducation/competition.cpython-37m-x86_64-linux-gnu.so
# /kaggle/input/riiid-test-answer-prediction/riiideducation/__init__.py

# %%
import optuna
import lightgbm as lgb

from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score

import riiideducation
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %% [markdown]
# # Data

# %%
# %%time

used_data_types_dict = {
    'row_id': 'int32',
    'timestamp': 'int64',
    'user_id': 'int32',
    'content_id': 'int16',
    'answered_correctly': 'int8',
    'prior_question_elapsed_time': 'float16',
    'prior_question_had_explanation': 'boolean'
}

train_df = pd.read_csv('/kaggle/input/riiid-test-answer-prediction/train.csv',
                       usecols = used_data_types_dict.keys(),
                       dtype=used_data_types_dict,
                       index_col = 0,
                       nrows=10**7)

print(train_df.dtypes)
print(train_df.shape)
train_df.head()
# Out:
# /opt/conda/lib/python3.7/site-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# timestamp                           int64
# user_id                             int32
# content_id                          int16
# answered_correctly                   int8
# prior_question_elapsed_time       float16
# prior_question_had_explanation    boolean
# dtype: object
# (10000000, 6)
# CPU times: user 23.7 s, sys: 638 ms, total: 24.3 s
# Wall time: 29.1 s
#         timestamp  user_id  content_id  answered_correctly  \
# row_id
# 0               0      115        5692                   1
# 1           56943      115        5716                   1
# 2          118363      115         128                   1
# 3          131167      115        7860                   1
# 4          137965      115        7922                   1
#
#         prior_question_elapsed_time  prior_question_had_explanation
# row_id
# 0                               NaN                            <NA>
# 1                           36992.0                           False
# 2                           55008.0                           False
# 3                           19008.0                           False
# 4                           11000.0                           False

# %%
test_df = pd.read_csv("/kaggle/input/riiid-test-answer-prediction/example_test.csv")

print(test_df.shape)
test_df.head()
# Out:
# (104, 11)
#    row_id  group_num    timestamp     user_id  content_id  content_type_id  \
# 0       0          0            0   275030867        5729                0
# 1       1          0  13309898705   554169193       12010                0
# 2       2          0   4213672059  1720860329         457                0
# 3       3          0  62798072960   288641214       13262                0
# 4       4          0  10585422061  1728340777        6119                0
#
#    task_container_id  prior_question_elapsed_time  \
# 0                  0                          NaN
# 1               4427                      19000.0
# 2                240                      17000.0
# 3                266                      23000.0
# 4                162                      72400.0
#
#   prior_question_had_explanation prior_group_answers_correct  \
# 0                            NaN                          []
# 1                           True                         NaN
# 2                           True                         NaN
# 3                           True                         NaN
# 4                           True                         NaN
#
#   prior_group_responses
# 0                    []
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
questions = pd.read_csv('/kaggle/input/riiid-test-answer-prediction/questions.csv')

print(questions.shape)
questions.head()
# Out:
# (13523, 5)
#    question_id  bundle_id  correct_answer  part            tags
# 0            0          0               0     1   51 131 162 38
# 1            1          1               1     1       131 36 81
# 2            2          2               0     1  131 101 162 92
# 3            3          3               0     1  131 149 162 29
# 4            4          4               3     1    131 5 162 38

# %%
lectures = pd.read_csv('/kaggle/input/riiid-test-answer-prediction/lectures.csv')

print(lectures.shape)
lectures.head()
# Out:
# (418, 4)
#    lecture_id  tag  part           type_of
# 0          89  159     5           concept
# 1         100   70     1           concept
# 2         185   45     6           concept
# 3         192   79     5  solving question
# 4         317  156     5  solving question

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ### user_df

# %%
user_df = train_df[train_df.answered_correctly != -1].groupby('user_id').agg({'answered_correctly': ['count', 'mean']}).reset_index()

user_df.columns = ['user_id', 'user_questions', 'user_mean']

print(user_df.shape)
user_df.head()
# Out:
# (39491, 3)
#    user_id  user_questions  user_mean
# 0      115              46   0.695652
# 1      124              30   0.233333
# 2     2746              19   0.578947
# 3     5382             125   0.672000
# 4     8623             109   0.642202

# %%
user_lect = train_df.groupby(["user_id", "answered_correctly"]).size().unstack()

# columns:-1, 0, 1
user_lect.columns = ['Lecture', 'Wrong', 'Right']

print(user_lect.shape)
user_lect.head()
# Out:
# (39491, 3)
#          Lecture  Wrong  Right
# user_id
# 115          NaN   14.0   32.0
# 124          NaN   23.0    7.0
# 2746         1.0    8.0   11.0
# 5382         3.0   41.0   84.0
# 8623         3.0   39.0   70.0

# %%
user_lect['Lecture'] = user_lect['Lecture'].fillna(0)
user_lect = user_lect.astype('Int64')
user_lect['watches_lecture'] = np.where(user_lect.Lecture > 0, 1, 0)
user_lect = user_lect.reset_index()
user_lect = user_lect[['user_id', 'watches_lecture']]

print(user_lect.shape)
user_lect.head()
# Out:
# (39491, 2)
#    user_id  watches_lecture
# 0      115                0
# 1      124                0
# 2     2746                1
# 3     5382                1
# 4     8623                1

# %%
user_df = user_df.merge(user_lect, on = "user_id", how = "left")
del user_lect

print(user_df.shape)
user_df.head()
# Out:
# (39491, 4)
#    user_id  user_questions  user_mean  watches_lecture
# 0      115              46   0.695652                0
# 1      124              30   0.233333                0
# 2     2746              19   0.578947                1
# 3     5382             125   0.672000                1
# 4     8623             109   0.642202                1

# %% [markdown]
# ### content_df

# %%
content_df = train_df[train_df.answered_correctly != -1].groupby('content_id') \
.agg({'answered_correctly': ['count', 'mean']}).reset_index()

content_df.columns = ['content_id', 'content_questions', 'content_mean']

print(content_df.shape)
content_df.head()
# Out:
# (13500, 3)
#    content_id  content_questions  content_mean
# 0           0                691      0.908828
# 1           1                726      0.893939
# 2           2               4501      0.562319
# 3           3               2276      0.780316
# 4           4               3153      0.627973

# %% [markdown]
# ### train_df

# %%
train_df = train_df.merge(user_df, on = "user_id", how = "left")
train_df = train_df.merge(content_df, on = "content_id", how = "left")

print(train_df.isnull().sum())
print(train_df.shape)
train_df.head()
# Out:
# timestamp                              0
# user_id                                0
# content_id                             0
# answered_correctly                     0
# prior_question_elapsed_time       234784
# prior_question_had_explanation     39388
# user_questions                         0
# user_mean                              0
# watches_lecture                        0
# content_questions                 118946
# content_mean                      118946
# dtype: int64
# (10000000, 11)
#    timestamp  user_id  content_id  answered_correctly  \
# 0          0      115        5692                   1
# 1      56943      115        5716                   1
# 2     118363      115         128                   1
# 3     131167      115        7860                   1
# 4     137965      115        7922                   1
#
#    prior_question_elapsed_time  prior_question_had_explanation  \
# 0                          NaN                            <NA>
# 1                      36992.0                           False
# 2                      55008.0                           False
# 3                      19008.0                           False
# 4                      11000.0                           False
#
#    user_questions  user_mean  watches_lecture  content_questions  content_mean
# 0              46   0.695652                0             3548.0      0.741545
# 1              46   0.695652                0             2376.0      0.735690
# 2              46   0.695652                0             1914.0      0.973877
# 3              46   0.695652                0             2137.0      0.955545
# 4              46   0.695652                0             1878.0      0.952609

# %%
features_df = train_df.iloc[:int(9/10 * len(train_df))]
train_df = train_df.iloc[int(9/10 * len(train_df)):]

# %%
train_questions_only_df = features_df[features_df['answered_correctly']!=-1]

grouped_by_user_df = train_questions_only_df.groupby('user_id')

user_answers_df = grouped_by_user_df.agg({'answered_correctly': ['mean', 'count','std','median','skew']}).copy()

user_answers_df.columns = ['mean_user_accuracy', 
                           'questions_answered', 
                           'std_user_accuracy', 
                           'median_user_accuracy', 
                           'skew_user_accuracy']

print(user_answers_df.dtypes)
print(user_answers_df.shape)
user_answers_df.head()
# Out:
# mean_user_accuracy      float64
# questions_answered        int64
# std_user_accuracy       float64
# median_user_accuracy    float64
# skew_user_accuracy      float64
# dtype: object
# (35683, 5)
#          mean_user_accuracy  questions_answered  std_user_accuracy  \
# user_id
# 115                0.695652                  46           0.465215
# 124                0.233333                  30           0.430183
# 2746               0.578947                  19           0.507257
# 5382               0.672000                 125           0.471374
# 8623               0.642202                 109           0.481566
#
#          median_user_accuracy  skew_user_accuracy
# user_id
# 115                       1.0           -0.879359
# 124                       0.0            1.328338
# 2746                      1.0           -0.347892
# 5382                      1.0           -0.741648
# 8623                      1.0           -0.601619

# %%
grouped_by_content_df = train_questions_only_df.groupby('content_id')

content_answers_df = grouped_by_content_df.agg({'answered_correctly': ['mean', 'count','std','median','skew']}).copy()

content_answers_df.columns = ['mean_accuracy', 
                              'question_asked', 
                              'std_accuracy', 
                              'median_accuracy', 
                              'skew_accuracy']

print(content_answers_df.dtypes)
print(content_answers_df.shape)
content_answers_df.head()
# Out:
# mean_accuracy      float64
# question_asked       int64
# std_accuracy       float64
# median_accuracy    float64
# skew_accuracy      float64
# dtype: object
# (13497, 5)
#             mean_accuracy  question_asked  std_accuracy  median_accuracy  \
# content_id
# 0                0.901274             628      0.298532              1.0
# 1                0.889571             652      0.313665              1.0
# 2                0.558317            4064      0.496649              1.0
# 3                0.779570            2046      0.414638              1.0
# 4                0.627244            2841      0.483623              1.0
#
#             skew_accuracy
# content_id
# 0               -2.696906
# 1               -2.491635
# 2               -0.234957
# 3               -1.349820
# 4               -0.526582

# %%
del(features_df)

train_df = train_df[train_df.answered_correctly != -1]

train_df = train_df.merge(user_answers_df, how='left', on='user_id')
train_df = train_df.merge(content_answers_df, how='left', on='content_id')

print(train_df.dtypes)
print(train_df.shape)
# Out:
# timestamp                           int64
# user_id                             int32
# content_id                          int16
# answered_correctly                   int8
# prior_question_elapsed_time       float16
# prior_question_had_explanation    boolean
# user_questions                      int64
# user_mean                         float64
# watches_lecture                     int64
# content_questions                 float64
# content_mean                      float64
# mean_user_accuracy                float64
# questions_answered                float64
# std_user_accuracy                 float64
# median_user_accuracy              float64
# skew_user_accuracy                float64
# mean_accuracy                     float64
# question_asked                    float64
# std_accuracy                      float64
# median_accuracy                   float64
# skew_accuracy                     float64
# dtype: object
# (981094, 21)

# %%
print(train_df.isnull().sum())
train_df.head()
# Out:
# timestamp                              0
# user_id                                0
# content_id                             0
# answered_correctly                     0
# prior_question_elapsed_time         3803
# prior_question_had_explanation      3803
# user_questions                         0
# user_mean                              0
# watches_lecture                        0
# content_questions                      0
# content_mean                           0
# mean_user_accuracy                981019
# questions_answered                981019
# std_user_accuracy                 981019
# median_user_accuracy              981019
# skew_user_accuracy                981019
# mean_accuracy                          3
# question_asked                         3
# std_accuracy                          14
# median_accuracy                        3
# skew_accuracy                         19
# dtype: int64
#     timestamp    user_id  content_id  answered_correctly  \
# 0  9871729962  196122333        3992                   1
# 1  9871801320  196122333        9510                   0
# 2  9871852731  196122333        5214                   1
# 3  9872436636  196122333        5334                   0
# 4  9872617214  196122333        3722                   1
#
#    prior_question_elapsed_time  prior_question_had_explanation  \
# 0                      19008.0                            True
# 1                      15000.0                            True
# 2                      13000.0                            True
# 3                      16000.0                            True
# 4                      16000.0                            True
#
#    user_questions  user_mean  watches_lecture  content_questions  ...  \
# 0             348   0.623563                1              431.0  ...
# 1             348   0.623563                1              475.0  ...
# 2             348   0.623563                1             1151.0  ...
# 3             348   0.623563                1             2512.0  ...
# 4             348   0.623563                1             1000.0  ...
#
#    mean_user_accuracy  questions_answered  std_user_accuracy  \
# 0            0.611722               273.0           0.488254
# 1            0.611722               273.0           0.488254
# 2            0.611722               273.0           0.488254
# 3            0.611722               273.0           0.488254
# 4            0.611722               273.0           0.488254
#
#    median_user_accuracy  skew_user_accuracy  mean_accuracy  question_asked  \
# 0                   1.0           -0.461015       0.867188           384.0
# 1                   1.0           -0.461015       0.533800           429.0
# 2                   1.0           -0.461015       0.715385          1040.0
# 3                   1.0           -0.461015       0.674593          2271.0
# 4                   1.0           -0.461015       0.719101           890.0
#
#    std_accuracy  median_accuracy  skew_accuracy
# 0      0.339815              1.0      -2.172419
# 1      0.499439              1.0      -0.135984
# 2      0.451448              1.0      -0.956033
# 3      0.468630              1.0      -0.745776
# 4      0.449691              1.0      -0.976647
#
# [5 rows x 21 columns]

# %%
mean_prior = train_df.prior_question_elapsed_time.mean()
label_enc = preprocessing.LabelEncoder()

train_df['content_questions'] = train_df['content_questions'].fillna(0)
train_df['content_mean'] = train_df['content_mean'].fillna(0.5)
train_df['user_questions'] = train_df['user_questions'].fillna(0)
train_df['user_mean'] = train_df['user_mean'].fillna(0.5)
train_df['prior_question_elapsed_time'] = train_df['prior_question_elapsed_time'].fillna(mean_prior)
train_df['prior_question_had_explanation'] = train_df['prior_question_had_explanation'].fillna(False)
train_df['prior_question_had_explanation'] = label_enc.fit_transform(train_df['prior_question_had_explanation'])
train_df['prior_question_had_explanation'] = train_df['prior_question_had_explanation'].astype(int)
train_df[['content_questions', 'user_questions']] = train_df[['content_questions', 'user_questions']].astype(int)
train_df = train_df.fillna(0.5)

print(train_df.dtypes)
print(train_df.isnull().sum())
train_df.head()
# Out:
# timestamp                           int64
# user_id                             int32
# content_id                          int16
# answered_correctly                   int8
# prior_question_elapsed_time       float16
# prior_question_had_explanation      int64
# user_questions                      int64
# user_mean                         float64
# watches_lecture                     int64
# content_questions                   int64
# content_mean                      float64
# mean_user_accuracy                float64
# questions_answered                float64
# std_user_accuracy                 float64
# median_user_accuracy              float64
# skew_user_accuracy                float64
# mean_accuracy                     float64
# question_asked                    float64
# std_accuracy                      float64
# median_accuracy                   float64
# skew_accuracy                     float64
# dtype: object
# timestamp                         0
# user_id                           0
# content_id                        0
# answered_correctly                0
# prior_question_elapsed_time       0
# prior_question_had_explanation    0
# user_questions                    0
# user_mean                         0
# watches_lecture                   0
# content_questions                 0
# content_mean                      0
# mean_user_accuracy                0
# questions_answered                0
# std_user_accuracy                 0
# median_user_accuracy              0
# skew_user_accuracy                0
# mean_accuracy                     0
# question_asked                    0
# std_accuracy                      0
# median_accuracy                   0
# skew_accuracy                     0
# dtype: int64
#     timestamp    user_id  content_id  answered_correctly  \
# 0  9871729962  196122333        3992                   1
# 1  9871801320  196122333        9510                   0
# 2  9871852731  196122333        5214                   1
# 3  9872436636  196122333        5334                   0
# 4  9872617214  196122333        3722                   1
#
#    prior_question_elapsed_time  prior_question_had_explanation  \
# 0                      19008.0                               1
# 1                      15000.0                               1
# 2                      13000.0                               1
# 3                      16000.0                               1
# 4                      16000.0                               1
#
#    user_questions  user_mean  watches_lecture  content_questions  ...  \
# 0             348   0.623563                1                431  ...
# 1             348   0.623563                1                475  ...
# 2             348   0.623563                1               1151  ...
# 3             348   0.623563                1               2512  ...
# 4             348   0.623563                1               1000  ...
#
#    mean_user_accuracy  questions_answered  std_user_accuracy  \
# 0            0.611722               273.0           0.488254
# 1            0.611722               273.0           0.488254
# 2            0.611722               273.0           0.488254
# 3            0.611722               273.0           0.488254
# 4            0.611722               273.0           0.488254
#
#    median_user_accuracy  skew_user_accuracy  mean_accuracy  question_asked  \
# 0                   1.0           -0.461015       0.867188           384.0
# 1                   1.0           -0.461015       0.533800           429.0
# 2                   1.0           -0.461015       0.715385          1040.0
# 3                   1.0           -0.461015       0.674593          2271.0
# 4                   1.0           -0.461015       0.719101           890.0
#
#    std_accuracy  median_accuracy  skew_accuracy
# 0      0.339815              1.0      -2.172419
# 1      0.499439              1.0      -0.135984
# 2      0.451448              1.0      -0.956033
# 3      0.468630              1.0      -0.745776
# 4      0.449691              1.0      -0.976647
#
# [5 rows x 21 columns]

# %%
train_df, test_df = train_test_split(train_df, random_state=666, test_size=0.2)

print(train_df.shape)
print(test_df.shape)
# Out:
# (784875, 21)
# (196219, 21)

# %%
features = [col for col in train_df.columns if col != 'answered_correctly']
target = 'answered_correctly'

print(features)
print(target)
# Out:
# ['timestamp', 'user_id', 'content_id', 'prior_question_elapsed_time', 'prior_question_had_explanation', 'user_questions', 'user_mean', 'watches_lecture', 'content_questions', 'content_mean', 'mean_user_accuracy', 'questions_answered', 'std_user_accuracy', 'median_user_accuracy', 'skew_user_accuracy', 'mean_accuracy', 'question_asked', 'std_accuracy', 'median_accuracy', 'skew_accuracy']
# answered_correctly

# %%
def create_model(trial):
    num_leaves = trial.suggest_int("num_leaves", 2, 31)
    n_estimators = trial.suggest_int("n_estimators", 50, 300)
    max_depth = trial.suggest_int('max_depth', 3, 8)
    min_child_samples = trial.suggest_int('min_child_samples', 100, 1200)
    learning_rate = trial.suggest_uniform('learning_rate', 0.0001, 0.99)
    min_data_in_leaf = trial.suggest_int('min_data_in_leaf', 5, 90)
    bagging_fraction = trial.suggest_uniform('bagging_fraction', 0.0001, 1.0)
    feature_fraction = trial.suggest_uniform('feature_fraction', 0.0001, 1.0)
    
    model = lgb.LGBMClassifier(
        num_leaves=num_leaves,
        n_estimators=n_estimators, 
        max_depth=max_depth, 
        min_child_samples=min_child_samples, 
        min_data_in_leaf=min_data_in_leaf,
        learning_rate=learning_rate,
        feature_fraction=feature_fraction,
        random_state=666
    )
    return model
    
def objective(trial):
    model = create_model(trial)
    model.fit(train_df[features], train_df[target])
    score = roc_auc_score(
        test_df[target].values, 
        model.predict_proba(test_df[features])[:,1]
    )
    return score
    
    
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=70)
params = study.best_params

print(params)
# Out:
# [I 2021-01-04 12:27:32,049] A new study created in memory with name: no-name-a6f28c8c-0cd5-4357-a6b9-992d0bd7ea6c
# [I 2021-01-04 12:27:41,230] Trial 0 finished with value: 0.7669094005932638 and parameters: {'num_leaves': 24, 'n_estimators': 299, 'max_depth': 6, 'min_child_samples': 406, 'learning_rate': 0.5090017194568264, 'min_data_in_leaf': 42, 'bagging_fraction': 0.6774112484542419, 'feature_fraction': 0.16837817348192277}. Best is trial 0 with value: 0.7669094005932638.
# [I 2021-01-04 12:27:48,606] Trial 1 finished with value: 0.7630853001088651 and parameters: {'num_leaves': 8, 'n_estimators': 279, 'max_depth': 7, 'min_child_samples': 690, 'learning_rate': 0.7824251865205841, 'min_data_in_leaf': 46, 'bagging_fraction': 0.10526737818187129, 'feature_fraction': 0.10710174654685117}. Best is trial 0 with value: 0.7669094005932638.
# [I 2021-01-04 12:27:52,249] Trial 2 finished with value: 0.7581054566840624 and parameters: {'num_leaves': 30, 'n_estimators': 51, 'max_depth': 3, 'min_child_samples': 245, 'learning_rate': 0.060442767275486135, 'min_data_in_leaf': 39, 'bagging_fraction': 0.607075698653913, 'feature_fraction': 0.901561319451972}. Best is trial 0 with value: 0.7669094005932638.
# [I 2021-01-04 12:27:57,056] Trial 3 finished with value: 0.7566661730483878 and parameters: {'num_leaves': 27, 'n_estimators': 151, 'max_depth': 3, 'min_child_samples': 411, 'learning_rate': 0.040152273309487584, 'min_data_in_leaf': 85, 'bagging_fraction': 0.9934329334220128, 'feature_fraction': 0.25767321170619123}. Best is trial 0 with value: 0.7669094005932638.
# [I 2021-01-04 12:28:07,744] Trial 4 finished with value: 0.7694034015495459 and parameters: {'num_leaves': 19, 'n_estimators': 256, 'max_depth': 7, 'min_child_samples': 627, 'learning_rate': 0.435680008298566, 'min_data_in_leaf': 77, 'bagging_fraction': 0.811310110357211, 'feature_fraction': 0.8716885776839551}. Best is trial 4 with value: 0.7694034015495459.
# [I 2021-01-04 12:28:15,496] Trial 5 finished with value: 0.7687479115891338 and parameters: {'num_leaves': 20, 'n_estimators': 195, 'max_depth': 5, 'min_child_samples': 610, 'learning_rate': 0.26586909805201075, 'min_data_in_leaf': 85, 'bagging_fraction': 0.033039293768870596, 'feature_fraction': 0.3893250346396311}. Best is trial 4 with value: 0.7694034015495459.
# [I 2021-01-04 12:28:20,950] Trial 6 finished with value: 0.7691248165933935 and parameters: {'num_leaves': 17, 'n_estimators': 141, 'max_depth': 7, 'min_child_samples': 384, 'learning_rate': 0.5585376479359266, 'min_data_in_leaf': 82, 'bagging_fraction': 0.7473159878031361, 'feature_fraction': 0.5789643262563957}. Best is trial 4 with value: 0.7694034015495459.
# [I 2021-01-04 12:28:25,415] Trial 7 finished with value: 0.7666991309566129 and parameters: {'num_leaves': 22, 'n_estimators': 103, 'max_depth': 7, 'min_child_samples': 368, 'learning_rate': 0.45687369528254884, 'min_data_in_leaf': 58, 'bagging_fraction': 0.5765440949831578, 'feature_fraction': 0.22701617455021442}. Best is trial 4 with value: 0.7694034015495459.
# [I 2021-01-04 12:28:34,766] Trial 8 finished with value: 0.7610588699147626 and parameters: {'num_leaves': 23, 'n_estimators': 200, 'max_depth': 4, 'min_child_samples': 1068, 'learning_rate': 0.02981029654858144, 'min_data_in_leaf': 8, 'bagging_fraction': 0.7258472132161476, 'feature_fraction': 0.5848093165798295}. Best is trial 4 with value: 0.7694034015495459.
# [I 2021-01-04 12:28:38,216] Trial 9 finished with value: 0.7518386425154973 and parameters: {'num_leaves': 13, 'n_estimators': 86, 'max_depth': 6, 'min_child_samples': 1029, 'learning_rate': 0.11567048791347126, 'min_data_in_leaf': 43, 'bagging_fraction': 0.2965021631341248, 'feature_fraction': 0.03470199529382317}. Best is trial 4 with value: 0.7694034015495459.
# [I 2021-01-04 12:28:48,690] Trial 10 finished with value: 0.7681435418100657 and parameters: {'num_leaves': 5, 'n_estimators': 249, 'max_depth': 8, 'min_child_samples': 818, 'learning_rate': 0.8668981019411128, 'min_data_in_leaf': 67, 'bagging_fraction': 0.9788002137637205, 'feature_fraction': 0.9988722758903101}. Best is trial 4 with value: 0.7694034015495459.
# [I 2021-01-04 12:28:54,683] Trial 11 finished with value: 0.7686716602185358 and parameters: {'num_leaves': 15, 'n_estimators': 145, 'max_depth': 8, 'min_child_samples': 599, 'learning_rate': 0.5952111904134012, 'min_data_in_leaf': 73, 'bagging_fraction': 0.8549195292763898, 'feature_fraction': 0.7249478439623587}. Best is trial 4 with value: 0.7694034015495459.
# [I 2021-01-04 12:29:03,153] Trial 12 finished with value: 0.7693453197207489 and parameters: {'num_leaves': 11, 'n_estimators': 229, 'max_depth': 7, 'min_child_samples': 189, 'learning_rate': 0.3284678690748777, 'min_data_in_leaf': 85, 'bagging_fraction': 0.3883970785968468, 'feature_fraction': 0.7737433520750227}. Best is trial 4 with value: 0.7694034015495459.
# [I 2021-01-04 12:29:13,475] Trial 13 finished with value: 0.7690424981194256 and parameters: {'num_leaves': 10, 'n_estimators': 241, 'max_depth': 8, 'min_child_samples': 150, 'learning_rate': 0.30327656968199096, 'min_data_in_leaf': 23, 'bagging_fraction': 0.39593744957784127, 'feature_fraction': 0.8223141552733613}. Best is trial 4 with value: 0.7694034015495459.
# [I 2021-01-04 12:29:21,571] Trial 14 finished with value: 0.7594814916066552 and parameters: {'num_leaves': 2, 'n_estimators': 244, 'max_depth': 6, 'min_child_samples': 111, 'learning_rate': 0.32723807729816, 'min_data_in_leaf': 70, 'bagging_fraction': 0.4162473980633099, 'feature_fraction': 0.7202863375306978}. Best is trial 4 with value: 0.7694034015495459.
# [I 2021-01-04 12:29:29,569] Trial 15 finished with value: 0.7688951060975491 and parameters: {'num_leaves': 11, 'n_estimators': 215, 'max_depth': 7, 'min_child_samples': 851, 'learning_rate': 0.6668993985464375, 'min_data_in_leaf': 89, 'bagging_fraction': 0.2027154628352159, 'feature_fraction': 0.9251408497689001}. Best is trial 4 with value: 0.7694034015495459.
# [I 2021-01-04 12:29:40,782] Trial 16 finished with value: 0.7703793422993117 and parameters: {'num_leaves': 19, 'n_estimators': 279, 'max_depth': 5, 'min_child_samples': 1173, 'learning_rate': 0.40511385940402533, 'min_data_in_leaf': 57, 'bagging_fraction': 0.4587466492738103, 'feature_fraction': 0.7326597643828275}. Best is trial 16 with value: 0.7703793422993117.
# [I 2021-01-04 12:29:52,453] Trial 17 finished with value: 0.7699640536897012 and parameters: {'num_leaves': 18, 'n_estimators': 300, 'max_depth': 5, 'min_child_samples': 919, 'learning_rate': 0.44045602979175896, 'min_data_in_leaf': 55, 'bagging_fraction': 0.855812280257711, 'feature_fraction': 0.6374690049514112}. Best is trial 16 with value: 0.7703793422993117.
# [I 2021-01-04 12:30:03,924] Trial 18 finished with value: 0.7686961668650767 and parameters: {'num_leaves': 16, 'n_estimators': 297, 'max_depth': 4, 'min_child_samples': 1199, 'learning_rate': 0.20594833177809563, 'min_data_in_leaf': 57, 'bagging_fraction': 0.49506294797848627, 'feature_fraction': 0.46063796817350167}. Best is trial 16 with value: 0.7703793422993117.
# [I 2021-01-04 12:30:16,441] Trial 19 finished with value: 0.7666260195586081 and parameters: {'num_leaves': 27, 'n_estimators': 280, 'max_depth': 5, 'min_child_samples': 1173, 'learning_rate': 0.6890700061943846, 'min_data_in_leaf': 30, 'bagging_fraction': 0.895048189009303, 'feature_fraction': 0.6323278857899156}. Best is trial 16 with value: 0.7703793422993117.
# [I 2021-01-04 12:30:25,524] Trial 20 finished with value: 0.7691490431171697 and parameters: {'num_leaves': 19, 'n_estimators': 271, 'max_depth': 4, 'min_child_samples': 953, 'learning_rate': 0.38933306524993916, 'min_data_in_leaf': 56, 'bagging_fraction': 0.5329466519965437, 'feature_fraction': 0.3605089850246288}. Best is trial 16 with value: 0.7703793422993117.
# [I 2021-01-04 12:30:37,453] Trial 21 finished with value: 0.7701925406083739 and parameters: {'num_leaves': 20, 'n_estimators': 299, 'max_depth': 5, 'min_child_samples': 721, 'learning_rate': 0.4155721327805093, 'min_data_in_leaf': 60, 'bagging_fraction': 0.8437504325760764, 'feature_fraction': 0.6409171246663439}. Best is trial 16 with value: 0.7703793422993117.
# [I 2021-01-04 12:30:49,494] Trial 22 finished with value: 0.7697683758865598 and parameters: {'num_leaves': 21, 'n_estimators': 299, 'max_depth': 5, 'min_child_samples': 775, 'learning_rate': 0.17481534488536649, 'min_data_in_leaf': 64, 'bagging_fraction': 0.9351922559283903, 'feature_fraction': 0.6643797818725865}. Best is trial 16 with value: 0.7703793422993117.
# [I 2021-01-04 12:31:01,286] Trial 23 finished with value: 0.7700025170376017 and parameters: {'num_leaves': 25, 'n_estimators': 297, 'max_depth': 5, 'min_child_samples': 923, 'learning_rate': 0.40108139756855443, 'min_data_in_leaf': 52, 'bagging_fraction': 0.6611282075523925, 'feature_fraction': 0.49004157366362655}. Best is trial 16 with value: 0.7703793422993117.
# [I 2021-01-04 12:31:12,339] Trial 24 finished with value: 0.7696188686101815 and parameters: {'num_leaves': 25, 'n_estimators': 273, 'max_depth': 4, 'min_child_samples': 1120, 'learning_rate': 0.37010589649507936, 'min_data_in_leaf': 35, 'bagging_fraction': 0.6539968068960221, 'feature_fraction': 0.5078069257277533}. Best is trial 16 with value: 0.7703793422993117.
# [I 2021-01-04 12:31:22,955] Trial 25 finished with value: 0.7685679428342704 and parameters: {'num_leaves': 31, 'n_estimators': 264, 'max_depth': 5, 'min_child_samples': 731, 'learning_rate': 0.5204181807150028, 'min_data_in_leaf': 49, 'bagging_fraction': 0.47079019463338007, 'feature_fraction': 0.5050785980423773}. Best is trial 16 with value: 0.7703793422993117.
# [I 2021-01-04 12:31:33,600] Trial 26 finished with value: 0.7700959696308955 and parameters: {'num_leaves': 28, 'n_estimators': 287, 'max_depth': 6, 'min_child_samples': 510, 'learning_rate': 0.24884567134497013, 'min_data_in_leaf': 51, 'bagging_fraction': 0.7790285006426793, 'feature_fraction': 0.4067507948716106}. Best is trial 16 with value: 0.7703793422993117.
# [I 2021-01-04 12:31:41,807] Trial 27 finished with value: 0.7696726652861442 and parameters: {'num_leaves': 29, 'n_estimators': 227, 'max_depth': 6, 'min_child_samples': 531, 'learning_rate': 0.23323837211642828, 'min_data_in_leaf': 61, 'bagging_fraction': 0.7739422840552551, 'feature_fraction': 0.3621483041576099}. Best is trial 16 with value: 0.7703793422993117.
# [I 2021-01-04 12:31:53,542] Trial 28 finished with value: 0.768068475754257 and parameters: {'num_leaves': 14, 'n_estimators': 286, 'max_depth': 6, 'min_child_samples': 496, 'learning_rate': 0.1332411667436278, 'min_data_in_leaf': 27, 'bagging_fraction': 0.2726972592501011, 'feature_fraction': 0.739562113762856}. Best is trial 16 with value: 0.7703793422993117.
# [I 2021-01-04 12:32:00,105] Trial 29 finished with value: 0.7689273888420455 and parameters: {'num_leaves': 28, 'n_estimators': 182, 'max_depth': 6, 'min_child_samples': 261, 'learning_rate': 0.4913725795404685, 'min_data_in_leaf': 49, 'bagging_fraction': 0.6143026049890907, 'feature_fraction': 0.2871935487081211}. Best is trial 16 with value: 0.7703793422993117.
# [I 2021-01-04 12:32:11,479] Trial 30 finished with value: 0.7692416493161368 and parameters: {'num_leaves': 24, 'n_estimators': 263, 'max_depth': 4, 'min_child_samples': 517, 'learning_rate': 0.6150813806484964, 'min_data_in_leaf': 63, 'bagging_fraction': 0.7090513381416493, 'feature_fraction': 0.42540741113139047}. Best is trial 16 with value: 0.7703793422993117.
# [I 2021-01-04 12:32:22,925] Trial 31 finished with value: 0.7696624785995773 and parameters: {'num_leaves': 25, 'n_estimators': 300, 'max_depth': 5, 'min_child_samples': 914, 'learning_rate': 0.39144194496654405, 'min_data_in_leaf': 50, 'bagging_fraction': 0.6621180825005326, 'feature_fraction': 0.5558643406541155}. Best is trial 16 with value: 0.7703793422993117.
# [I 2021-01-04 12:32:33,947] Trial 32 finished with value: 0.7703388085118714 and parameters: {'num_leaves': 26, 'n_estimators': 288, 'max_depth': 5, 'min_child_samples': 708, 'learning_rate': 0.3534435810852652, 'min_data_in_leaf': 40, 'bagging_fraction': 0.8011493070503921, 'feature_fraction': 0.48239904108486054}. Best is trial 16 with value: 0.7703793422993117.
# [I 2021-01-04 12:32:46,086] Trial 33 finished with value: 0.770406819838498 and parameters: {'num_leaves': 22, 'n_estimators': 285, 'max_depth': 6, 'min_child_samples': 692, 'learning_rate': 0.2747879798365709, 'min_data_in_leaf': 39, 'bagging_fraction': 0.8031534035336778, 'feature_fraction': 0.6807356473365058}. Best is trial 33 with value: 0.770406819838498.
# [I 2021-01-04 12:32:57,650] Trial 34 finished with value: 0.7706177077578089 and parameters: {'num_leaves': 21, 'n_estimators': 283, 'max_depth': 5, 'min_child_samples': 701, 'learning_rate': 0.29153228711958473, 'min_data_in_leaf': 37, 'bagging_fraction': 0.9217338510876283, 'feature_fraction': 0.6793770082153542}. Best is trial 34 with value: 0.7706177077578089.
# [I 2021-01-04 12:33:10,773] Trial 35 finished with value: 0.767815054340719 and parameters: {'num_leaves': 22, 'n_estimators': 279, 'max_depth': 4, 'min_child_samples': 656, 'learning_rate': 0.13899315486934352, 'min_data_in_leaf': 18, 'bagging_fraction': 0.9281592140605441, 'feature_fraction': 0.8025856565079573}. Best is trial 34 with value: 0.7706177077578089.
# [I 2021-01-04 12:33:21,996] Trial 36 finished with value: 0.7679322875898715 and parameters: {'num_leaves': 23, 'n_estimators': 257, 'max_depth': 3, 'min_child_samples': 825, 'learning_rate': 0.28926419845813156, 'min_data_in_leaf': 37, 'bagging_fraction': 0.5517102691289105, 'feature_fraction': 0.8540384920022586}. Best is trial 34 with value: 0.7706177077578089.
# [I 2021-01-04 12:33:31,438] Trial 37 finished with value: 0.7700843255219836 and parameters: {'num_leaves': 17, 'n_estimators': 230, 'max_depth': 5, 'min_child_samples': 689, 'learning_rate': 0.3469148593270918, 'min_data_in_leaf': 41, 'bagging_fraction': 0.9900542010172542, 'feature_fraction': 0.6968777487421853}. Best is trial 34 with value: 0.7706177077578089.
# [I 2021-01-04 12:33:43,544] Trial 38 finished with value: 0.7681862256625853 and parameters: {'num_leaves': 26, 'n_estimators': 283, 'max_depth': 6, 'min_child_samples': 759, 'learning_rate': 0.08495652193673645, 'min_data_in_leaf': 33, 'bagging_fraction': 0.8025152998352578, 'feature_fraction': 0.5500378833148593}. Best is trial 34 with value: 0.7706177077578089.
# [I 2021-01-04 12:33:54,487] Trial 39 finished with value: 0.7692494304455373 and parameters: {'num_leaves': 21, 'n_estimators': 213, 'max_depth': 5, 'min_child_samples': 588, 'learning_rate': 0.18647330247302124, 'min_data_in_leaf': 42, 'bagging_fraction': 0.9355062768351388, 'feature_fraction': 0.9441886190333497}. Best is trial 34 with value: 0.7706177077578089.
# [I 2021-01-04 12:34:04,903] Trial 40 finished with value: 0.7695900902669961 and parameters: {'num_leaves': 19, 'n_estimators': 257, 'max_depth': 4, 'min_child_samples': 998, 'learning_rate': 0.49983217619570247, 'min_data_in_leaf': 16, 'bagging_fraction': 0.71926465511422, 'feature_fraction': 0.5991521167734708}. Best is trial 34 with value: 0.7706177077578089.
# [I 2021-01-04 12:34:17,924] Trial 41 finished with value: 0.770094049783669 and parameters: {'num_leaves': 20, 'n_estimators': 291, 'max_depth': 5, 'min_child_samples': 700, 'learning_rate': 0.43965885498116325, 'min_data_in_leaf': 46, 'bagging_fraction': 0.8527063247986024, 'feature_fraction': 0.7793047216017797}. Best is trial 34 with value: 0.7706177077578089.
# [I 2021-01-04 12:34:29,282] Trial 42 finished with value: 0.7705601033897227 and parameters: {'num_leaves': 23, 'n_estimators': 270, 'max_depth': 5, 'min_child_samples': 440, 'learning_rate': 0.26177924694153976, 'min_data_in_leaf': 44, 'bagging_fraction': 0.8340089699707602, 'feature_fraction': 0.669998780437644}. Best is trial 34 with value: 0.7706177077578089.
# [I 2021-01-04 12:34:40,574] Trial 43 finished with value: 0.7707847503799212 and parameters: {'num_leaves': 23, 'n_estimators': 271, 'max_depth': 6, 'min_child_samples': 303, 'learning_rate': 0.26914653564625524, 'min_data_in_leaf': 45, 'bagging_fraction': 0.9999980347158899, 'feature_fraction': 0.6753534078777056}. Best is trial 43 with value: 0.7707847503799212.
# [I 2021-01-04 12:34:50,947] Trial 44 finished with value: 0.7700618356657395 and parameters: {'num_leaves': 23, 'n_estimators': 240, 'max_depth': 6, 'min_child_samples': 309, 'learning_rate': 0.2631109796745809, 'min_data_in_leaf': 45, 'bagging_fraction': 0.9791498603475468, 'feature_fraction': 0.6661660022199907}. Best is trial 43 with value: 0.7707847503799212.
# [I 2021-01-04 12:34:58,728] Trial 45 finished with value: 0.7685771727272508 and parameters: {'num_leaves': 22, 'n_estimators': 160, 'max_depth': 6, 'min_child_samples': 347, 'learning_rate': 0.21316488395706643, 'min_data_in_leaf': 32, 'bagging_fraction': 0.9043312700159118, 'feature_fraction': 0.750578453299309}. Best is trial 43 with value: 0.7707847503799212.
# [I 2021-01-04 12:35:12,001] Trial 46 finished with value: 0.7700651017169788 and parameters: {'num_leaves': 17, 'n_estimators': 271, 'max_depth': 7, 'min_child_samples': 432, 'learning_rate': 0.2918058681278243, 'min_data_in_leaf': 38, 'bagging_fraction': 0.4511046522662751, 'feature_fraction': 0.8560341374372747}. Best is trial 43 with value: 0.7707847503799212.
# [I 2021-01-04 12:35:27,619] Trial 47 finished with value: 0.7600161535846179 and parameters: {'num_leaves': 21, 'n_estimators': 250, 'max_depth': 6, 'min_child_samples': 224, 'learning_rate': 0.011957036731015225, 'min_data_in_leaf': 27, 'bagging_fraction': 0.9934468330627468, 'feature_fraction': 0.6822640305693162}. Best is trial 43 with value: 0.7707847503799212.
# [I 2021-01-04 12:35:39,499] Trial 48 finished with value: 0.769943347129612 and parameters: {'num_leaves': 24, 'n_estimators': 265, 'max_depth': 6, 'min_child_samples': 410, 'learning_rate': 0.16633386347625295, 'min_data_in_leaf': 45, 'bagging_fraction': 0.6072493862091934, 'feature_fraction': 0.8174186416219819}. Best is trial 43 with value: 0.7707847503799212.
# [I 2021-01-04 12:35:43,272] Trial 49 finished with value: 0.7603820143920014 and parameters: {'num_leaves': 18, 'n_estimators': 51, 'max_depth': 7, 'min_child_samples': 295, 'learning_rate': 0.07564111597897588, 'min_data_in_leaf': 54, 'bagging_fraction': 0.31295974862451864, 'feature_fraction': 0.5917179116309298}. Best is trial 43 with value: 0.7707847503799212.
# [I 2021-01-04 12:35:54,046] Trial 50 finished with value: 0.7698065581756129 and parameters: {'num_leaves': 15, 'n_estimators': 239, 'max_depth': 5, 'min_child_samples': 447, 'learning_rate': 0.31625173792610645, 'min_data_in_leaf': 37, 'bagging_fraction': 0.008205821432665072, 'feature_fraction': 0.9902215647772885}. Best is trial 43 with value: 0.7707847503799212.
# [I 2021-01-04 12:36:06,626] Trial 51 finished with value: 0.7703183413549468 and parameters: {'num_leaves': 26, 'n_estimators': 273, 'max_depth': 5, 'min_child_samples': 572, 'learning_rate': 0.3558059182577056, 'min_data_in_leaf': 41, 'bagging_fraction': 0.8143046936106613, 'feature_fraction': 0.6976357694512325}. Best is trial 43 with value: 0.7707847503799212.
# [I 2021-01-04 12:36:12,237] Trial 52 finished with value: 0.7670877140027845 and parameters: {'num_leaves': 22, 'n_estimators': 104, 'max_depth': 5, 'min_child_samples': 642, 'learning_rate': 0.24760288380644604, 'min_data_in_leaf': 40, 'bagging_fraction': 0.754714316613629, 'feature_fraction': 0.5403102103431906}. Best is trial 43 with value: 0.7707847503799212.
# [I 2021-01-04 12:36:23,513] Trial 53 finished with value: 0.7701038744402302 and parameters: {'num_leaves': 24, 'n_estimators': 290, 'max_depth': 5, 'min_child_samples': 666, 'learning_rate': 0.29293673231121914, 'min_data_in_leaf': 29, 'bagging_fraction': 0.9505369472291284, 'feature_fraction': 0.6173431561511239}. Best is trial 43 with value: 0.7707847503799212.
# [I 2021-01-04 12:36:34,511] Trial 54 finished with value: 0.7695814371765087 and parameters: {'num_leaves': 19, 'n_estimators': 254, 'max_depth': 6, 'min_child_samples': 872, 'learning_rate': 0.46581732095644535, 'min_data_in_leaf': 48, 'bagging_fraction': 0.8917617115287697, 'feature_fraction': 0.7622061095974413}. Best is trial 43 with value: 0.7707847503799212.
# [I 2021-01-04 12:36:46,011] Trial 55 finished with value: 0.7601991842661747 and parameters: {'num_leaves': 27, 'n_estimators': 274, 'max_depth': 5, 'min_child_samples': 774, 'learning_rate': 0.984158880472902, 'min_data_in_leaf': 24, 'bagging_fraction': 0.8767765701855831, 'feature_fraction': 0.7158569867300049}. Best is trial 43 with value: 0.7707847503799212.
# [I 2021-01-04 12:36:57,608] Trial 56 finished with value: 0.7700686551456242 and parameters: {'num_leaves': 23, 'n_estimators': 287, 'max_depth': 4, 'min_child_samples': 562, 'learning_rate': 0.3599281842069266, 'min_data_in_leaf': 43, 'bagging_fraction': 0.8188710292660271, 'feature_fraction': 0.6429836122416883}. Best is trial 43 with value: 0.7707847503799212.
# [I 2021-01-04 12:37:08,558] Trial 57 finished with value: 0.7699702194912968 and parameters: {'num_leaves': 20, 'n_estimators': 260, 'max_depth': 6, 'min_child_samples': 129, 'learning_rate': 0.32530536226826856, 'min_data_in_leaf': 35, 'bagging_fraction': 0.33726085887154955, 'feature_fraction': 0.4647262248385641}. Best is trial 43 with value: 0.7707847503799212.
# [I 2021-01-04 12:37:20,807] Trial 58 finished with value: 0.7682501888993354 and parameters: {'num_leaves': 21, 'n_estimators': 278, 'max_depth': 7, 'min_child_samples': 463, 'learning_rate': 0.5385558769080349, 'min_data_in_leaf': 53, 'bagging_fraction': 0.9519185134189607, 'feature_fraction': 0.8871920703099972}. Best is trial 43 with value: 0.7707847503799212.
# [I 2021-01-04 12:37:30,248] Trial 59 finished with value: 0.7694205929433726 and parameters: {'num_leaves': 18, 'n_estimators': 246, 'max_depth': 5, 'min_child_samples': 365, 'learning_rate': 0.21559442810177296, 'min_data_in_leaf': 45, 'bagging_fraction': 0.7098798964469117, 'feature_fraction': 0.570121777588944}. Best is trial 43 with value: 0.7707847503799212.
# [I 2021-01-04 12:37:42,420] Trial 60 finished with value: 0.7700052390492447 and parameters: {'num_leaves': 25, 'n_estimators': 294, 'max_depth': 4, 'min_child_samples': 203, 'learning_rate': 0.26991277496584165, 'min_data_in_leaf': 34, 'bagging_fraction': 0.5310251078983309, 'feature_fraction': 0.7908722383021012}. Best is trial 43 with value: 0.7707847503799212.
# [I 2021-01-04 12:37:54,619] Trial 61 finished with value: 0.770088795843688 and parameters: {'num_leaves': 29, 'n_estimators': 268, 'max_depth': 5, 'min_child_samples': 612, 'learning_rate': 0.3587226875934536, 'min_data_in_leaf': 40, 'bagging_fraction': 0.8128270003379381, 'feature_fraction': 0.7126683144153981}. Best is trial 43 with value: 0.7707847503799212.
# [I 2021-01-04 12:38:07,230] Trial 62 finished with value: 0.7697691991128381 and parameters: {'num_leaves': 26, 'n_estimators': 279, 'max_depth': 5, 'min_child_samples': 559, 'learning_rate': 0.41877003684793496, 'min_data_in_leaf': 38, 'bagging_fraction': 0.8390978279043273, 'feature_fraction': 0.6693134064763226}. Best is trial 43 with value: 0.7707847503799212.
# [I 2021-01-04 12:38:20,110] Trial 63 finished with value: 0.770307021423194 and parameters: {'num_leaves': 26, 'n_estimators': 300, 'max_depth': 5, 'min_child_samples': 331, 'learning_rate': 0.33861783679103247, 'min_data_in_leaf': 43, 'bagging_fraction': 0.7655872898197007, 'feature_fraction': 0.6124940379621953}. Best is trial 43 with value: 0.7707847503799212.
# [I 2021-01-04 12:38:31,555] Trial 64 finished with value: 0.7697923238087059 and parameters: {'num_leaves': 31, 'n_estimators': 271, 'max_depth': 6, 'min_child_samples': 470, 'learning_rate': 0.38337818490234227, 'min_data_in_leaf': 59, 'bagging_fraction': 0.7995012513557359, 'feature_fraction': 0.7409049686099003}. Best is trial 43 with value: 0.7707847503799212.
# [I 2021-01-04 12:38:42,326] Trial 65 finished with value: 0.7704071557166917 and parameters: {'num_leaves': 23, 'n_estimators': 282, 'max_depth': 5, 'min_child_samples': 743, 'learning_rate': 0.2782633410206696, 'min_data_in_leaf': 47, 'bagging_fraction': 0.9032440164640534, 'feature_fraction': 0.5226539756839441}. Best is trial 43 with value: 0.7707847503799212.
# [I 2021-01-04 12:38:54,032] Trial 66 finished with value: 0.770208345429619 and parameters: {'num_leaves': 24, 'n_estimators': 286, 'max_depth': 5, 'min_child_samples': 744, 'learning_rate': 0.238853124099799, 'min_data_in_leaf': 56, 'bagging_fraction': 0.8985665733754413, 'feature_fraction': 0.5214789051577012}. Best is trial 43 with value: 0.7707847503799212.
# [I 2021-01-04 12:39:04,257] Trial 67 finished with value: 0.7666252039380022 and parameters: {'num_leaves': 22, 'n_estimators': 295, 'max_depth': 4, 'min_child_samples': 811, 'learning_rate': 0.15318642529105767, 'min_data_in_leaf': 47, 'bagging_fraction': 0.8640596637758664, 'feature_fraction': 0.30266985458854395}. Best is trial 43 with value: 0.7707847503799212.
# [I 2021-01-04 12:39:13,692] Trial 68 finished with value: 0.7696107949549199 and parameters: {'num_leaves': 20, 'n_estimators': 233, 'max_depth': 6, 'min_child_samples': 699, 'learning_rate': 0.2778320694073521, 'min_data_in_leaf': 50, 'bagging_fraction': 0.097416910005443, 'feature_fraction': 0.4481086201414585}. Best is trial 43 with value: 0.7707847503799212.
# [I 2021-01-04 12:39:21,233] Trial 69 finished with value: 0.7617159378766798 and parameters: {'num_leaves': 23, 'n_estimators': 219, 'max_depth': 5, 'min_child_samples': 807, 'learning_rate': 0.19515857994600766, 'min_data_in_leaf': 51, 'bagging_fraction': 0.9217621246383069, 'feature_fraction': 0.08873560192659741}. Best is trial 43 with value: 0.7707847503799212.
# {'num_leaves': 23, 'n_estimators': 271, 'max_depth': 6, 'min_child_samples': 303, 'learning_rate': 0.26914653564625524, 'min_data_in_leaf': 45, 'bagging_fraction': 0.9999980347158899, 'feature_fraction': 0.6753534078777056}

# %%
'''
params = {
'num_leaves': 13,
'n_estimators': 267,
'max_depth': 5,
'min_child_samples': 108,
'learning_rate': 0.1432743218178815,
'min_data_in_leaf': 34,
'bagging_fraction': 0.9288184187681869,
'feature_fraction': 0.7423767848466962}

'''

# score: 0.8008159759884459
# Out:
# "\nparams = {\n'num_leaves': 13,\n'n_estimators': 267,\n'max_depth': 5,\n'min_child_samples': 108,\n'learning_rate': 0.1432743218178815,\n'min_data_in_leaf': 34,\n'bagging_fraction': 0.9288184187681869,\n'feature_fraction': 0.7423767848466962}\n\n"

# %%
model = lgb.LGBMClassifier(**params)

model.fit(train_df[features], train_df[target])
print('LGB score: ', roc_auc_score(test_df[target].values, model.predict_proba(test_df[features])[:,1]))
# Out:
# LGB score:  0.7703803124320775

# %% [markdown]
# # Submit

# %%
test_df = pd.read_csv("/kaggle/input/riiid-test-answer-prediction/example_test.csv")

print(test_df.dtypes)
print(test_df.shape)
test_df.head()
# Out:
# row_id                              int64
# group_num                           int64
# timestamp                           int64
# user_id                             int64
# content_id                          int64
# content_type_id                     int64
# task_container_id                   int64
# prior_question_elapsed_time       float64
# prior_question_had_explanation     object
# prior_group_answers_correct        object
# prior_group_responses              object
# dtype: object
# (104, 11)
#    row_id  group_num    timestamp     user_id  content_id  content_type_id  \
# 0       0          0            0   275030867        5729                0
# 1       1          0  13309898705   554169193       12010                0
# 2       2          0   4213672059  1720860329         457                0
# 3       3          0  62798072960   288641214       13262                0
# 4       4          0  10585422061  1728340777        6119                0
#
#    task_container_id  prior_question_elapsed_time  \
# 0                  0                          NaN
# 1               4427                      19000.0
# 2                240                      17000.0
# 3                266                      23000.0
# 4                162                      72400.0
#
#   prior_question_had_explanation prior_group_answers_correct  \
# 0                            NaN                          []
# 1                           True                         NaN
# 2                           True                         NaN
# 3                           True                         NaN
# 4                           True                         NaN
#
#   prior_group_responses
# 0                    []
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
env = riiideducation.make_env()
iter_test = env.iter_test()

# %%
for (test_df, sample_prediction_df) in iter_test:
    
    test_df = test_df.merge(user_df, on = "user_id", how = "left")
    test_df = test_df.merge(content_df, on = "content_id", how = "left")
    
    test_df = test_df.merge(user_answers_df, how='left', on='user_id')
    test_df = test_df.merge(content_answers_df, how='left', on='content_id')
    
    mean_prior = test_df.prior_question_elapsed_time.mean()
    
    test_df['content_questions'] = test_df['content_questions'].fillna(0)
    test_df['content_mean'] = test_df['content_mean'].fillna(0.5)
    test_df['user_questions']= test_df['user_questions'].fillna(0)
    test_df['user_mean'] = test_df['user_mean'].fillna(0.5)
    test_df['prior_question_elapsed_time'] = test_df['prior_question_elapsed_time'].fillna(mean_prior)
    test_df['prior_question_had_explanation'] = test_df['prior_question_had_explanation'].fillna(False)
    test_df['prior_question_had_explanation'] = label_enc.fit_transform(test_df['prior_question_had_explanation'])
    test_df[['content_questions', 'user_questions']] = test_df[['content_questions', 'user_questions']].astype(int)
    test_df = test_df.fillna(0.5)
    
    # target
    test_df[target] =  model.predict(test_df[features])
    
    # submit_data
    env.predict(test_df.loc[test_df['content_type_id'] == 0, ['row_id', target]])

# %%
submission_df = pd.read_csv("/kaggle/input/riiid-test-answer-prediction/example_sample_submission.csv")

print(submission_df.dtypes)
print(submission_df.shape)
submission_df.head()
# Out:
# row_id                  int64
# answered_correctly    float64
# group_num               int64
# dtype: object
# (104, 3)
#    row_id  answered_correctly  group_num
# 0       0                 0.5          0
# 1       1                 0.5          0
# 2       2                 0.5          0
# 3       3                 0.5          0
# 4       4                 0.5          0
