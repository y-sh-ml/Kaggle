# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/riiid-test-answer-prediction/example_sample_submission.csv
# /kaggle/input/riiid-test-answer-prediction/example_test.csv
# /kaggle/input/riiid-test-answer-prediction/questions.csv
# /kaggle/input/riiid-test-answer-prediction/train.csv
# /kaggle/input/riiid-test-answer-prediction/lectures.csv
# /kaggle/input/riiid-test-answer-prediction/riiideducation/competition.cpython-37m-x86_64-linux-gnu.so
# /kaggle/input/riiid-test-answer-prediction/riiideducation/__init__.py

# %%
from sklearn.model_selection import train_test_split
import optuna
import lightgbm as lgb
import xgboost as xgb
from sklearn.metrics import roc_auc_score

# %%
import riiideducation
env = riiideducation.make_env()
iter_test = env.iter_test()

# %% [markdown]
# # Data

# %%
used_data_types_dict = {
    'timestamp': 'int64',
    'user_id': 'int32',
    'content_id': 'int16',
    'answered_correctly': 'int8',
    'prior_question_elapsed_time': 'float16',
    'prior_question_had_explanation': 'boolean'
}

train_df = pd.read_csv('/kaggle/input/riiid-test-answer-prediction/train.csv',
                       usecols = used_data_types_dict.keys(),
                       dtype=used_data_types_dict,
                       index_col = 0,
                       nrows=10**6)

print(train_df.dtypes)
print(train_df.shape)
train_df.head()
# Out:
# user_id                             int32
# content_id                          int16
# answered_correctly                   int8
# prior_question_elapsed_time       float16
# prior_question_had_explanation    boolean
# dtype: object
# (1000000, 5)
#            user_id  content_id  answered_correctly  \
# timestamp
# 0              115        5692                   1
# 56943          115        5716                   1
# 118363         115         128                   1
# 131167         115        7860                   1
# 137965         115        7922                   1
#
#            prior_question_elapsed_time  prior_question_had_explanation
# timestamp
# 0                                  NaN                            <NA>
# 56943                          36992.0                           False
# 118363                         55008.0                           False
# 131167                         19008.0                           False
# 137965                         11000.0                           False

# %%
test_df = pd.read_csv("/kaggle/input/riiid-test-answer-prediction/example_test.csv")

print(test_df.shape)
test_df.head()
# Out:
# (104, 11)
#    row_id  group_num    timestamp     user_id  content_id  content_type_id  \
# 0       0          0            0   275030867        5729                0
# 1       1          0  13309898705   554169193       12010                0
# 2       2          0   4213672059  1720860329         457                0
# 3       3          0  62798072960   288641214       13262                0
# 4       4          0  10585422061  1728340777        6119                0
#
#    task_container_id  prior_question_elapsed_time  \
# 0                  0                          NaN
# 1               4427                      19000.0
# 2                240                      17000.0
# 3                266                      23000.0
# 4                162                      72400.0
#
#   prior_question_had_explanation prior_group_answers_correct  \
# 0                            NaN                          []
# 1                           True                         NaN
# 2                           True                         NaN
# 3                           True                         NaN
# 4                           True                         NaN
#
#   prior_group_responses
# 0                    []
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
submission_df = pd.read_csv("/kaggle/input/riiid-test-answer-prediction/example_sample_submission.csv")

print(submission_df.shape)
submission_df.head()
# Out:
# (104, 3)
#    row_id  answered_correctly  group_num
# 0       0                 0.5          0
# 1       1                 0.5          0
# 2       2                 0.5          0
# 3       3                 0.5          0
# 4       4                 0.5          0

# %% [markdown]
# # Feature Engineering

# %%
features_df = train_df.iloc[:int(9/10 * len(train_df))]
train_df = train_df.iloc[int(9/10 * len(train_df)):]

# %%
print(features_df.dtypes)
print(features_df.shape)
features_df.head()
# Out:
# user_id                             int32
# content_id                          int16
# answered_correctly                   int8
# prior_question_elapsed_time       float16
# prior_question_had_explanation    boolean
# dtype: object
# (900000, 5)
#            user_id  content_id  answered_correctly  \
# timestamp
# 0              115        5692                   1
# 56943          115        5716                   1
# 118363         115         128                   1
# 131167         115        7860                   1
# 137965         115        7922                   1
#
#            prior_question_elapsed_time  prior_question_had_explanation
# timestamp
# 0                                  NaN                            <NA>
# 56943                          36992.0                           False
# 118363                         55008.0                           False
# 131167                         19008.0                           False
# 137965                         11000.0                           False

# %%
print(train_df.dtypes)
print(train_df.shape)
train_df.head()
# Out:
# user_id                             int32
# content_id                          int16
# answered_correctly                   int8
# prior_question_elapsed_time       float16
# prior_question_had_explanation    boolean
# dtype: object
# (100000, 5)
#               user_id  content_id  answered_correctly  \
# timestamp
# 23452298654  18789336        8144                   0
# 23452298654  18789336        8146                   0
# 23452320119  18789336       10166                   0
# 23452320119  18789336       10165                   0
# 23452320119  18789336       10167                   1
#
#              prior_question_elapsed_time  prior_question_had_explanation
# timestamp
# 23452298654                       4248.0                            True
# 23452298654                       4248.0                            True
# 23452320119                       2000.0                            True
# 23452320119                       2000.0                            True
# 23452320119                       2000.0                            True

# %%
train_questions_only_df = features_df[features_df['answered_correctly']!=-1]

grouped_by_user_df = train_questions_only_df.groupby('user_id')

user_answers_df = grouped_by_user_df.agg({'answered_correctly': ['mean', 'count','std','median','skew']}).copy()

user_answers_df.columns = ['mean_user_accuracy', 
                           'questions_answered', 
                           'std_user_accuracy', 
                           'median_user_accuracy', 
                           'skew_user_accuracy']

print(user_answers_df.dtypes)
print(user_answers_df.shape)
user_answers_df.head()
# Out:
# mean_user_accuracy      float64
# questions_answered        int64
# std_user_accuracy       float64
# median_user_accuracy    float64
# skew_user_accuracy      float64
# dtype: object
# (3458, 5)
#          mean_user_accuracy  questions_answered  std_user_accuracy  \
# user_id
# 115                0.695652                  46           0.465215
# 124                0.233333                  30           0.430183
# 2746               0.578947                  19           0.507257
# 5382               0.672000                 125           0.471374
# 8623               0.642202                 109           0.481566
#
#          median_user_accuracy  skew_user_accuracy
# user_id
# 115                       1.0           -0.879359
# 124                       0.0            1.328338
# 2746                      1.0           -0.347892
# 5382                      1.0           -0.741648
# 8623                      1.0           -0.601619

# %%
grouped_by_content_df = train_questions_only_df.groupby('content_id')

content_answers_df = grouped_by_content_df.agg({'answered_correctly': ['mean', 'count','std','median','skew']}).copy()

content_answers_df.columns = ['mean_accuracy', 
                              'question_asked', 
                              'std_accuracy', 
                              'median_accuracy', 
                              'skew_accuracy']

print(content_answers_df.dtypes)
print(content_answers_df.shape)
content_answers_df.head()
# Out:
# mean_accuracy      float64
# question_asked       int64
# std_accuracy       float64
# median_accuracy    float64
# skew_accuracy      float64
# dtype: object
# (12986, 5)
#             mean_accuracy  question_asked  std_accuracy  median_accuracy  \
# content_id
# 0                0.857143              70      0.352454              1.0
# 1                0.918367              49      0.276642              1.0
# 2                0.555276             398      0.497561              1.0
# 3                0.784091             176      0.412625              1.0
# 4                0.600760             263      0.490676              1.0
#
#             skew_accuracy
# content_id
# 0               -2.086215
# 1               -3.153323
# 2               -0.223312
# 3               -1.392819
# 4               -0.413848

# %%
del features_df
del grouped_by_user_df
del grouped_by_content_df

# %%
features = [
    'mean_user_accuracy', 
    'questions_answered',
    'std_user_accuracy', 
    'median_user_accuracy',
    'skew_user_accuracy',
    'mean_accuracy', 
    'question_asked',
    'std_accuracy', 
    'median_accuracy',
    'prior_question_elapsed_time', 
    'prior_question_had_explanation',
    'skew_accuracy'
]

target = 'answered_correctly'

# %%
train_df = train_df[train_df[target] != -1]

print(train_df.dtypes)
print(train_df.shape)
train_df.head()
# Out:
# user_id                             int32
# content_id                          int16
# answered_correctly                   int8
# prior_question_elapsed_time       float16
# prior_question_had_explanation    boolean
# dtype: object
# (97953, 5)
#               user_id  content_id  answered_correctly  \
# timestamp
# 23452298654  18789336        8144                   0
# 23452298654  18789336        8146                   0
# 23452320119  18789336       10166                   0
# 23452320119  18789336       10165                   0
# 23452320119  18789336       10167                   1
#
#              prior_question_elapsed_time  prior_question_had_explanation
# timestamp
# 23452298654                       4248.0                            True
# 23452298654                       4248.0                            True
# 23452320119                       2000.0                            True
# 23452320119                       2000.0                            True
# 23452320119                       2000.0                            True

# %%
train_df = train_df.merge(user_answers_df, how='left', on='user_id')
train_df = train_df.merge(content_answers_df, how='left', on='content_id')

print(train_df.dtypes)
print(train_df.shape)
train_df.head()
# Out:
# user_id                             int32
# content_id                          int16
# answered_correctly                   int8
# prior_question_elapsed_time       float16
# prior_question_had_explanation    boolean
# mean_user_accuracy                float64
# questions_answered                float64
# std_user_accuracy                 float64
# median_user_accuracy              float64
# skew_user_accuracy                float64
# mean_accuracy                     float64
# question_asked                    float64
# std_accuracy                      float64
# median_accuracy                   float64
# skew_accuracy                     float64
# dtype: object
# (97953, 15)
#     user_id  content_id  answered_correctly  prior_question_elapsed_time  \
# 0  18789336        8144                   0                       4248.0
# 1  18789336        8146                   0                       4248.0
# 2  18789336       10166                   0                       2000.0
# 3  18789336       10165                   0                       2000.0
# 4  18789336       10167                   1                       2000.0
#
#    prior_question_had_explanation  mean_user_accuracy  questions_answered  \
# 0                            True            0.309689              2312.0
# 1                            True            0.309689              2312.0
# 2                            True            0.309689              2312.0
# 3                            True            0.309689              2312.0
# 4                            True            0.309689              2312.0
#
#    std_user_accuracy  median_user_accuracy  skew_user_accuracy  mean_accuracy  \
# 0           0.462465                   0.0            0.823743       0.454545
# 1           0.462465                   0.0            0.823743       0.696970
# 2           0.462465                   0.0            0.823743       0.916667
# 3           0.462465                   0.0            0.823743       0.416667
# 4           0.462465                   0.0            0.823743       0.770833
#
#    question_asked  std_accuracy  median_accuracy  skew_accuracy
# 0            33.0      0.505650              0.0       0.191386
# 1            33.0      0.466694              1.0      -0.898565
# 2            48.0      0.279310              1.0      -3.113260
# 3            48.0      0.498224              0.0       0.349066
# 4            48.0      0.424744              1.0      -1.330724

# %% [markdown]
# # Preprocess

# %%
train_df['prior_question_had_explanation'] = train_df['prior_question_had_explanation'].fillna(value=False).astype(bool)
train_df = train_df.fillna(value=0.5)

print(train_df.isnull().sum())
# Out:
# user_id                           0
# content_id                        0
# answered_correctly                0
# prior_question_elapsed_time       0
# prior_question_had_explanation    0
# mean_user_accuracy                0
# questions_answered                0
# std_user_accuracy                 0
# median_user_accuracy              0
# skew_user_accuracy                0
# mean_accuracy                     0
# question_asked                    0
# std_accuracy                      0
# median_accuracy                   0
# skew_accuracy                     0
# dtype: int64

# %%
train_df = train_df[features + [target]]
train_df = train_df.replace([np.inf, -np.inf], np.nan)
train_df = train_df.fillna(0.5)

print(train_df.isnull().sum())
# Out:
# mean_user_accuracy                0
# questions_answered                0
# std_user_accuracy                 0
# median_user_accuracy              0
# skew_user_accuracy                0
# mean_accuracy                     0
# question_asked                    0
# std_accuracy                      0
# median_accuracy                   0
# prior_question_elapsed_time       0
# prior_question_had_explanation    0
# skew_accuracy                     0
# answered_correctly                0
# dtype: int64

# %%
print(train_df.dtypes)
print(train_df.shape)
train_df.head()
# Out:
# mean_user_accuracy                float64
# questions_answered                float64
# std_user_accuracy                 float64
# median_user_accuracy              float64
# skew_user_accuracy                float64
# mean_accuracy                     float64
# question_asked                    float64
# std_accuracy                      float64
# median_accuracy                   float64
# prior_question_elapsed_time       float16
# prior_question_had_explanation       bool
# skew_accuracy                     float64
# answered_correctly                   int8
# dtype: object
# (97953, 13)
#    mean_user_accuracy  questions_answered  std_user_accuracy  \
# 0            0.309689              2312.0           0.462465
# 1            0.309689              2312.0           0.462465
# 2            0.309689              2312.0           0.462465
# 3            0.309689              2312.0           0.462465
# 4            0.309689              2312.0           0.462465
#
#    median_user_accuracy  skew_user_accuracy  mean_accuracy  question_asked  \
# 0                   0.0            0.823743       0.454545            33.0
# 1                   0.0            0.823743       0.696970            33.0
# 2                   0.0            0.823743       0.916667            48.0
# 3                   0.0            0.823743       0.416667            48.0
# 4                   0.0            0.823743       0.770833            48.0
#
#    std_accuracy  median_accuracy  prior_question_elapsed_time  \
# 0      0.505650              0.0                       4248.0
# 1      0.466694              1.0                       4248.0
# 2      0.279310              1.0                       2000.0
# 3      0.498224              0.0                       2000.0
# 4      0.424744              1.0                       2000.0
#
#    prior_question_had_explanation  skew_accuracy  answered_correctly
# 0                            True       0.191386                   0
# 1                            True      -0.898565                   0
# 2                            True      -3.113260                   0
# 3                            True       0.349066                   0
# 4                            True      -1.330724                   1

# %%
train_df, test_df = train_test_split(train_df, random_state=666, test_size=0.2)

print(train_df.shape)
print(test_df.shape)
train_df.head()
# Out:
# (78362, 13)
# (19591, 13)
#        mean_user_accuracy  questions_answered  std_user_accuracy  \
# 20721                 0.5                 0.5                0.5
# 488                   0.5                 0.5                0.5
# 54213                 0.5                 0.5                0.5
# 62049                 0.5                 0.5                0.5
# 51788                 0.5                 0.5                0.5
#
#        median_user_accuracy  skew_user_accuracy  mean_accuracy  \
# 20721                   0.5                 0.5       0.610860
# 488                     0.5                 0.5       0.573427
# 54213                   0.5                 0.5       0.622951
# 62049                   0.5                 0.5       0.711670
# 51788                   0.5                 0.5       0.761905
#
#        question_asked  std_accuracy  median_accuracy  \
# 20721           221.0      0.488662              1.0
# 488             429.0      0.495157              1.0
# 54213           183.0      0.485977              1.0
# 62049           437.0      0.453504              1.0
# 51788            42.0      0.431081              1.0
#
#        prior_question_elapsed_time  prior_question_had_explanation  \
# 20721                      25328.0                            True
# 488                        15000.0                            True
# 54213                      20000.0                            True
# 62049                      26000.0                            True
# 51788                      27008.0                            True
#
#        skew_accuracy  answered_correctly
# 20721      -0.457871                   1
# 488        -0.297968                   0
# 54213      -0.511585                   0
# 62049      -0.937780                   0
# 51788      -1.275864                   1

# %%
def create_model(trial):
    n_estimators = trial.suggest_int("n_estimators", 50, 300)
    max_depth = trial.suggest_int('max_depth', 3, 8)
    learning_rate = trial.suggest_uniform('learning_rate', 0.0001, 0.99)
    
    model = xgb.XGBClassifier(
        n_estimators=n_estimators, 
        max_depth=max_depth, 
        learning_rate=learning_rate,
        random_state=666
    )
    return model

# %% [markdown]
# # Modeling

# %%
def objective(trial):
    model = create_model(trial)
    model.fit(train_df[features], train_df[target])
    score = roc_auc_score(
        test_df[target].values, 
        model.predict_proba(test_df[features])[:,1]
    )
    return score

# %%
# %%time

study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=70)
params = study.best_params

print(params)
# Out:
# [I 2020-12-10 07:13:48,013] A new study created in memory with name: no-name-635d2ac8-cb3e-4f01-b276-e7a43591fcb9
# [I 2020-12-10 07:13:54,945] Trial 0 finished with value: 0.6803988662845539 and parameters: {'n_estimators': 155, 'max_depth': 8, 'learning_rate': 0.5376115839881924}. Best is trial 0 with value: 0.6803988662845539.
# [I 2020-12-10 07:14:02,225] Trial 1 finished with value: 0.6697670765199295 and parameters: {'n_estimators': 187, 'max_depth': 7, 'learning_rate': 0.7696572327801647}. Best is trial 0 with value: 0.6803988662845539.
# [I 2020-12-10 07:14:13,005] Trial 2 finished with value: 0.6565687690916998 and parameters: {'n_estimators': 228, 'max_depth': 8, 'learning_rate': 0.7888752014161987}. Best is trial 0 with value: 0.6803988662845539.
# [I 2020-12-10 07:14:19,078] Trial 3 finished with value: 0.7102468086662047 and parameters: {'n_estimators': 175, 'max_depth': 6, 'learning_rate': 0.17728422832658178}. Best is trial 3 with value: 0.7102468086662047.
# [I 2020-12-10 07:14:20,981] Trial 4 finished with value: 0.7114395229326875 and parameters: {'n_estimators': 50, 'max_depth': 6, 'learning_rate': 0.32673808837755425}. Best is trial 4 with value: 0.7114395229326875.
# [I 2020-12-10 07:14:23,410] Trial 5 finished with value: 0.7149593221987431 and parameters: {'n_estimators': 119, 'max_depth': 3, 'learning_rate': 0.14859251865592407}. Best is trial 5 with value: 0.7149593221987431.
# [I 2020-12-10 07:14:29,285] Trial 6 finished with value: 0.6961054570574925 and parameters: {'n_estimators': 171, 'max_depth': 6, 'learning_rate': 0.46009410635917314}. Best is trial 5 with value: 0.7149593221987431.
# [I 2020-12-10 07:14:33,477] Trial 7 finished with value: 0.6805735290043237 and parameters: {'n_estimators': 104, 'max_depth': 7, 'learning_rate': 0.731987124020928}. Best is trial 5 with value: 0.7149593221987431.
# [I 2020-12-10 07:14:42,895] Trial 8 finished with value: 0.7119464966231452 and parameters: {'n_estimators': 238, 'max_depth': 6, 'learning_rate': 0.10796704905157432}. Best is trial 5 with value: 0.7149593221987431.
# [I 2020-12-10 07:14:47,792] Trial 9 finished with value: 0.7133811554870685 and parameters: {'n_estimators': 123, 'max_depth': 6, 'learning_rate': 0.14199558555689054}. Best is trial 5 with value: 0.7149593221987431.
# [I 2020-12-10 07:14:49,179] Trial 10 finished with value: 0.7083206385852054 and parameters: {'n_estimators': 56, 'max_depth': 3, 'learning_rate': 0.9839116413026999}. Best is trial 5 with value: 0.7149593221987431.
# [I 2020-12-10 07:14:51,718] Trial 11 finished with value: 0.7132591686431616 and parameters: {'n_estimators': 114, 'max_depth': 3, 'learning_rate': 0.019579001181485214}. Best is trial 5 with value: 0.7149593221987431.
# [I 2020-12-10 07:14:54,371] Trial 12 finished with value: 0.714305443514895 and parameters: {'n_estimators': 105, 'max_depth': 4, 'learning_rate': 0.23028557399619948}. Best is trial 5 with value: 0.7149593221987431.
# [I 2020-12-10 07:14:56,479] Trial 13 finished with value: 0.7136725570068054 and parameters: {'n_estimators': 80, 'max_depth': 4, 'learning_rate': 0.317247820266632}. Best is trial 5 with value: 0.7149593221987431.
# [I 2020-12-10 07:14:59,959] Trial 14 finished with value: 0.7131829599174753 and parameters: {'n_estimators': 134, 'max_depth': 4, 'learning_rate': 0.3011069975121505}. Best is trial 5 with value: 0.7149593221987431.
# [I 2020-12-10 07:15:06,993] Trial 15 finished with value: 0.715477430019662 and parameters: {'n_estimators': 292, 'max_depth': 4, 'learning_rate': 0.02373294632645573}. Best is trial 15 with value: 0.715477430019662.
# [I 2020-12-10 07:15:13,307] Trial 16 finished with value: 0.7145734558880926 and parameters: {'n_estimators': 285, 'max_depth': 3, 'learning_rate': 0.014086904153549433}. Best is trial 15 with value: 0.715477430019662.
# [I 2020-12-10 07:15:21,940] Trial 17 finished with value: 0.7152502753642332 and parameters: {'n_estimators': 294, 'max_depth': 5, 'learning_rate': 0.024478868232228043}. Best is trial 15 with value: 0.715477430019662.
# [I 2020-12-10 07:15:30,919] Trial 18 finished with value: 0.7147248444239505 and parameters: {'n_estimators': 293, 'max_depth': 5, 'learning_rate': 0.008899978199814819}. Best is trial 15 with value: 0.715477430019662.
# [I 2020-12-10 07:15:38,363] Trial 19 finished with value: 0.6972159040678262 and parameters: {'n_estimators': 263, 'max_depth': 5, 'learning_rate': 0.46954134834612427}. Best is trial 15 with value: 0.715477430019662.
# [I 2020-12-10 07:15:46,204] Trial 20 finished with value: 0.7144978794568567 and parameters: {'n_estimators': 214, 'max_depth': 5, 'learning_rate': 0.06762711751085204}. Best is trial 15 with value: 0.715477430019662.
# [I 2020-12-10 07:15:53,270] Trial 21 finished with value: 0.7130449472833124 and parameters: {'n_estimators': 269, 'max_depth': 4, 'learning_rate': 0.0016157580362452517}. Best is trial 15 with value: 0.715477430019662.
# [I 2020-12-10 07:16:00,350] Trial 22 finished with value: 0.7113945553009899 and parameters: {'n_estimators': 300, 'max_depth': 4, 'learning_rate': 0.2195452460028336}. Best is trial 15 with value: 0.715477430019662.
# [I 2020-12-10 07:16:05,447] Trial 23 finished with value: 0.715139957227005 and parameters: {'n_estimators': 258, 'max_depth': 3, 'learning_rate': 0.09190157323754294}. Best is trial 15 with value: 0.715477430019662.
# [I 2020-12-10 07:16:13,348] Trial 24 finished with value: 0.7144013165979937 and parameters: {'n_estimators': 252, 'max_depth': 5, 'learning_rate': 0.08752776734147667}. Best is trial 15 with value: 0.715477430019662.
# [I 2020-12-10 07:16:20,211] Trial 25 finished with value: 0.7064663603832347 and parameters: {'n_estimators': 283, 'max_depth': 4, 'learning_rate': 0.39536005599892793}. Best is trial 15 with value: 0.715477430019662.
# [I 2020-12-10 07:16:24,182] Trial 26 finished with value: 0.7080285817784925 and parameters: {'n_estimators': 205, 'max_depth': 3, 'learning_rate': 0.5745989173733403}. Best is trial 15 with value: 0.715477430019662.
# [I 2020-12-10 07:16:31,310] Trial 27 finished with value: 0.7078252646238499 and parameters: {'n_estimators': 248, 'max_depth': 5, 'learning_rate': 0.2475791043037187}. Best is trial 15 with value: 0.715477430019662.
# [I 2020-12-10 07:16:37,934] Trial 28 finished with value: 0.7147130032733309 and parameters: {'n_estimators': 271, 'max_depth': 4, 'learning_rate': 0.0805840467270981}. Best is trial 15 with value: 0.715477430019662.
# [I 2020-12-10 07:16:45,181] Trial 29 finished with value: 0.7039637217035299 and parameters: {'n_estimators': 298, 'max_depth': 3, 'learning_rate': 0.6503490766213482}. Best is trial 15 with value: 0.715477430019662.
# [I 2020-12-10 07:16:53,716] Trial 30 finished with value: 0.7149367147980699 and parameters: {'n_estimators': 281, 'max_depth': 5, 'learning_rate': 0.053321247153363234}. Best is trial 15 with value: 0.715477430019662.
# [I 2020-12-10 07:16:56,682] Trial 31 finished with value: 0.714888154584267 and parameters: {'n_estimators': 145, 'max_depth': 3, 'learning_rate': 0.16376716293201526}. Best is trial 15 with value: 0.715477430019662.
# [I 2020-12-10 07:16:58,422] Trial 32 finished with value: 0.7153085441719179 and parameters: {'n_estimators': 79, 'max_depth': 3, 'learning_rate': 0.13443728736875857}. Best is trial 15 with value: 0.715477430019662.
# [I 2020-12-10 07:17:03,913] Trial 33 finished with value: 0.7154021697356515 and parameters: {'n_estimators': 220, 'max_depth': 4, 'learning_rate': 0.022531610779112428}. Best is trial 15 with value: 0.715477430019662.
# [I 2020-12-10 07:17:08,812] Trial 34 finished with value: 0.7144577977368227 and parameters: {'n_estimators': 195, 'max_depth': 4, 'learning_rate': 0.013454001904481021}. Best is trial 15 with value: 0.715477430019662.
# [I 2020-12-10 07:17:14,498] Trial 35 finished with value: 0.7127199939207762 and parameters: {'n_estimators': 230, 'max_depth': 4, 'learning_rate': 0.20056683733114034}. Best is trial 15 with value: 0.715477430019662.
# [I 2020-12-10 07:17:19,730] Trial 36 finished with value: 0.6846658536509659 and parameters: {'n_estimators': 160, 'max_depth': 5, 'learning_rate': 0.9240357833121081}. Best is trial 15 with value: 0.715477430019662.
# [I 2020-12-10 07:17:25,083] Trial 37 finished with value: 0.714165183361367 and parameters: {'n_estimators': 218, 'max_depth': 4, 'learning_rate': 0.12219731407688952}. Best is trial 15 with value: 0.715477430019662.
# [I 2020-12-10 07:17:32,370] Trial 38 finished with value: 0.7009409461125331 and parameters: {'n_estimators': 185, 'max_depth': 7, 'learning_rate': 0.26324125716266317}. Best is trial 15 with value: 0.715477430019662.
# [I 2020-12-10 07:17:34,663] Trial 39 finished with value: 0.7145935800960144 and parameters: {'n_estimators': 72, 'max_depth': 5, 'learning_rate': 0.16610377736212306}. Best is trial 15 with value: 0.715477430019662.
# [I 2020-12-10 07:17:46,100] Trial 40 finished with value: 0.681888149640874 and parameters: {'n_estimators': 241, 'max_depth': 8, 'learning_rate': 0.3976248363356546}. Best is trial 15 with value: 0.715477430019662.
# [I 2020-12-10 07:17:52,062] Trial 41 finished with value: 0.7152889143032937 and parameters: {'n_estimators': 268, 'max_depth': 3, 'learning_rate': 0.055731757624876956}. Best is trial 15 with value: 0.715477430019662.
# [I 2020-12-10 07:17:57,452] Trial 42 finished with value: 0.7154813559933868 and parameters: {'n_estimators': 275, 'max_depth': 3, 'learning_rate': 0.036391785550043756}. Best is trial 42 with value: 0.7154813559933868.
# [I 2020-12-10 07:18:02,624] Trial 43 finished with value: 0.7145937410436929 and parameters: {'n_estimators': 273, 'max_depth': 3, 'learning_rate': 0.13812425361435732}. Best is trial 42 with value: 0.7154813559933868.
# [I 2020-12-10 07:18:07,261] Trial 44 finished with value: 0.7153904895327102 and parameters: {'n_estimators': 235, 'max_depth': 3, 'learning_rate': 0.04675355946329691}. Best is trial 42 with value: 0.7154813559933868.
# [I 2020-12-10 07:18:11,652] Trial 45 finished with value: 0.7150242760832095 and parameters: {'n_estimators': 226, 'max_depth': 3, 'learning_rate': 0.12544665796881205}. Best is trial 42 with value: 0.7154813559933868.
# [I 2020-12-10 07:18:16,423] Trial 46 finished with value: 0.7154079293632829 and parameters: {'n_estimators': 239, 'max_depth': 3, 'learning_rate': 0.054237333775848356}. Best is trial 42 with value: 0.7154813559933868.
# [I 2020-12-10 07:18:21,642] Trial 47 finished with value: 0.7153551960061063 and parameters: {'n_estimators': 233, 'max_depth': 3, 'learning_rate': 0.04927265089506841}. Best is trial 42 with value: 0.7154813559933868.
# [I 2020-12-10 07:18:26,409] Trial 48 finished with value: 0.7136929628731644 and parameters: {'n_estimators': 202, 'max_depth': 4, 'learning_rate': 0.19371449125416515}. Best is trial 42 with value: 0.7154813559933868.
# [I 2020-12-10 07:18:31,304] Trial 49 finished with value: 0.7129882592117541 and parameters: {'n_estimators': 247, 'max_depth': 3, 'learning_rate': 0.007950359634454267}. Best is trial 42 with value: 0.7154813559933868.
# [I 2020-12-10 07:18:36,650] Trial 50 finished with value: 0.7126266845042679 and parameters: {'n_estimators': 217, 'max_depth': 4, 'learning_rate': 0.0008603299982735471}. Best is trial 42 with value: 0.7154813559933868.
# [I 2020-12-10 07:18:41,688] Trial 51 finished with value: 0.7154305827490071 and parameters: {'n_estimators': 227, 'max_depth': 3, 'learning_rate': 0.048083973985090955}. Best is trial 42 with value: 0.7154813559933868.
# [I 2020-12-10 07:18:47,131] Trial 52 finished with value: 0.7153558397968196 and parameters: {'n_estimators': 256, 'max_depth': 3, 'learning_rate': 0.051069532991944715}. Best is trial 42 with value: 0.7154813559933868.
# [I 2020-12-10 07:18:52,374] Trial 53 finished with value: 0.7151205745280296 and parameters: {'n_estimators': 240, 'max_depth': 3, 'learning_rate': 0.09787574676053035}. Best is trial 42 with value: 0.7154813559933868.
# [I 2020-12-10 07:18:56,440] Trial 54 finished with value: 0.7153614499730354 and parameters: {'n_estimators': 194, 'max_depth': 3, 'learning_rate': 0.03158261751603758}. Best is trial 42 with value: 0.7154813559933868.
# [I 2020-12-10 07:19:01,589] Trial 55 finished with value: 0.7150745262476348 and parameters: {'n_estimators': 208, 'max_depth': 4, 'learning_rate': 0.09166400323882345}. Best is trial 42 with value: 0.7154813559933868.
# [I 2020-12-10 07:19:05,877] Trial 56 finished with value: 0.714419842825395 and parameters: {'n_estimators': 222, 'max_depth': 3, 'learning_rate': 0.16435040041196217}. Best is trial 42 with value: 0.7154813559933868.
# [I 2020-12-10 07:19:11,519] Trial 57 finished with value: 0.7153514597207167 and parameters: {'n_estimators': 279, 'max_depth': 3, 'learning_rate': 0.04145478615272721}. Best is trial 42 with value: 0.7154813559933868.
# [I 2020-12-10 07:19:16,163] Trial 58 finished with value: 0.711921750917603 and parameters: {'n_estimators': 183, 'max_depth': 4, 'learning_rate': 0.00017809965699531333}. Best is trial 42 with value: 0.7154813559933868.
# [I 2020-12-10 07:19:21,139] Trial 59 finished with value: 0.7147461814875912 and parameters: {'n_estimators': 260, 'max_depth': 3, 'learning_rate': 0.11298234249726724}. Best is trial 42 with value: 0.7154813559933868.
# [I 2020-12-10 07:19:27,517] Trial 60 finished with value: 0.7118155829312229 and parameters: {'n_estimators': 240, 'max_depth': 4, 'learning_rate': 0.2646276026300408}. Best is trial 42 with value: 0.7154813559933868.
# [I 2020-12-10 07:19:31,344] Trial 61 finished with value: 0.7154356813415311 and parameters: {'n_estimators': 193, 'max_depth': 3, 'learning_rate': 0.03192570586855471}. Best is trial 42 with value: 0.7154813559933868.
# [I 2020-12-10 07:19:34,868] Trial 62 finished with value: 0.7154371988482124 and parameters: {'n_estimators': 171, 'max_depth': 3, 'learning_rate': 0.07769956303310299}. Best is trial 42 with value: 0.7154813559933868.
# [I 2020-12-10 07:19:38,034] Trial 63 finished with value: 0.7153698594892279 and parameters: {'n_estimators': 158, 'max_depth': 3, 'learning_rate': 0.08221989768351595}. Best is trial 42 with value: 0.7154813559933868.
# [I 2020-12-10 07:19:41,976] Trial 64 finished with value: 0.7108176785849573 and parameters: {'n_estimators': 173, 'max_depth': 3, 'learning_rate': 0.0013142627840682097}. Best is trial 42 with value: 0.7154813559933868.
# [I 2020-12-10 07:19:49,368] Trial 65 finished with value: 0.7139860715879178 and parameters: {'n_estimators': 192, 'max_depth': 6, 'learning_rate': 0.0764452435635349}. Best is trial 42 with value: 0.7154813559933868.
# [I 2020-12-10 07:19:53,851] Trial 66 finished with value: 0.6951564175759923 and parameters: {'n_estimators': 181, 'max_depth': 4, 'learning_rate': 0.8466071027378285}. Best is trial 42 with value: 0.7154813559933868.
# [I 2020-12-10 07:19:58,018] Trial 67 finished with value: 0.7153898055050774 and parameters: {'n_estimators': 166, 'max_depth': 3, 'learning_rate': 0.032135308430174814}. Best is trial 42 with value: 0.7154813559933868.
# [I 2020-12-10 07:20:00,950] Trial 68 finished with value: 0.7145860615401842 and parameters: {'n_estimators': 146, 'max_depth': 3, 'learning_rate': 0.21196356660135632}. Best is trial 42 with value: 0.7154813559933868.
# [I 2020-12-10 07:20:07,887] Trial 69 finished with value: 0.7138200885465149 and parameters: {'n_estimators': 290, 'max_depth': 4, 'learning_rate': 0.11161780841985966}. Best is trial 42 with value: 0.7154813559933868.
# {'n_estimators': 275, 'max_depth': 3, 'learning_rate': 0.036391785550043756}
# CPU times: user 24min 14s, sys: 11.7 s, total: 24min 25s
# Wall time: 6min 19s

# %%
# %%time

model = xgb.XGBClassifier(**params)

model.fit(train_df[features], train_df[target])
print('XGB score: ', roc_auc_score(test_df[target].values, model.predict_proba(test_df[features])[:,1]))
# Out:
# XGB score:  0.7154813559933868
# CPU times: user 20.4 s, sys: 124 ms, total: 20.5 s
# Wall time: 5.29 s

# %% [markdown]
# # Submit

# %%
for (test_df, sample_prediction_df) in iter_test:
    test_df = test_df.merge(user_answers_df, how='left', on='user_id')
    test_df = test_df.merge(content_answers_df, how='left', on='content_id')
    test_df['prior_question_had_explanation'] = test_df['prior_question_had_explanation'].fillna(value=False).astype(bool)
    test_df.fillna(value = 0.5, inplace = True)

    test_df['answered_correctly'] = model.predict_proba(test_df[features])[:,1]
    env.predict(test_df.loc[test_df['content_type_id'] == 0, ['row_id', 'answered_correctly']])
